# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections #for storing different types of tuples and dictionares
import random  #random initialization
import re  # Regular expressions are text matching patterns described with a formal syntax
import numpy as np 
import os  #allows you to interface with the underlying operating system that Python is running on. 
import time #time dependent tasks
import json #load json files
from glob import glob #listing files under a specified folder
from PIL import Image #image manipulation
import pickle #serialize python objects

# %%
# Download caption annotation files
annotation_folder = '/annotation/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
    annotation_zip = tf.keras.utils.get_file('captions.zip',
                                             cache_subdir=os.path.abspath('.'),
                                             origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                             extract = True)
    annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
    os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
    image_zip = tf.keras.utils.get_file('train2014.zip',
                                        cache_subdir=os.path.abspath('.'),
                                        origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                        extract = True)
    PATH = os.path.dirname(image_zip) + image_folder
    os.remove(image_zip)
else:
    PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 85s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    caption = f"<start> {val['caption']} <end>"
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths[:64000]
print(len(train_image_paths))
# Out:
# 64000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    train_captions.extend(caption_list)
    img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A zebra leaned over eating some grass in a field. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x173C3EBD250>

# %% [markdown]
# ## Preprocess the images using VGG16

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (224, 224))
    img = tf.keras.applications.vgg16.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.VGG16(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %% [markdown]
# ## Caching the features extracted from VGG16

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in image_dataset:
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                                (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())

# %% [markdown]
# ## Preprocess and tokenize the captions

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
    capt_len = len(img_to_cap_vector[imgt])
    img_name_train.extend([imgt] * capt_len)
    cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
    capv_len = len(img_to_cap_vector[imgv])
    img_name_val.extend([imgv] * capv_len)
    cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (256129, 256129, 64028, 64028)

# %% [markdown]
# ## Create a tf.data dataset for training

# %%
# hyper parameters

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from VGG16 is (64, 2048)
# These two variables represent that vector shape
features_shape = 512
attention_features_shape = 49

# %%
# Load the numpy files
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

        # hidden shape == (batch_size, hidden_size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        # attention_hidden_layer shape == (batch_size, 64, units)
        attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                             self.W2(hidden_with_time_axis)))

        # score shape == (batch_size, 64, 1)
        # This gives you an unnormalized score for each image feature.
        score = self.V(attention_hidden_layer)

        # attention_weights shape == (batch_size, 64, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it using pickle
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

        # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

        # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/vgg_train2"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # restoring the latest checkpoint in checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

              # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.8891
# Epoch 1 Batch 100 Loss 1.0555
# Epoch 1 Batch 200 Loss 0.9541
# Epoch 1 Batch 300 Loss 0.8361
# Epoch 1 Batch 400 Loss 0.8369
# Epoch 1 Batch 500 Loss 0.7471
# Epoch 1 Batch 600 Loss 0.7711
# Epoch 1 Batch 700 Loss 0.7069
# Epoch 1 Batch 800 Loss 0.6870
# Epoch 1 Batch 900 Loss 0.7866
# Epoch 1 Batch 1000 Loss 0.7182
# Epoch 1 Batch 1100 Loss 0.7008
# Epoch 1 Batch 1200 Loss 0.6321
# Epoch 1 Batch 1300 Loss 0.6604
# Epoch 1 Batch 1400 Loss 0.7740
# Epoch 1 Batch 1500 Loss 0.6396
# Epoch 1 Batch 1600 Loss 0.6752
# Epoch 1 Batch 1700 Loss 0.6810
# Epoch 1 Batch 1800 Loss 0.6940
# Epoch 1 Batch 1900 Loss 0.6693
# Epoch 1 Batch 2000 Loss 0.7161
# Epoch 1 Batch 2100 Loss 0.7616
# Epoch 1 Batch 2200 Loss 0.6304
# Epoch 1 Batch 2300 Loss 0.7182
# Epoch 1 Batch 2400 Loss 0.6544
# Epoch 1 Batch 2500 Loss 0.7001
# Epoch 1 Batch 2600 Loss 0.6740
# Epoch 1 Batch 2700 Loss 0.6975
# Epoch 1 Batch 2800 Loss 0.6828
# Epoch 1 Batch 2900 Loss 0.6287
# Epoch 1 Batch 3000 Loss 0.6107
# Epoch 1 Batch 3100 Loss 0.5952
# Epoch 1 Batch 3200 Loss 0.7145
# Epoch 1 Batch 3300 Loss 0.6288
# Epoch 1 Batch 3400 Loss 0.7050
# Epoch 1 Batch 3500 Loss 0.6653
# Epoch 1 Batch 3600 Loss 0.7534
# Epoch 1 Batch 3700 Loss 0.7015
# Epoch 1 Batch 3800 Loss 0.6390
# Epoch 1 Batch 3900 Loss 0.6492
# Epoch 1 Batch 4000 Loss 0.6157
# Epoch 1 Loss 0.711027
# Time taken for 1 epoch 1428.3785247802734 sec
#
# Epoch 2 Batch 0 Loss 0.7007
# Epoch 2 Batch 100 Loss 0.6786
# Epoch 2 Batch 200 Loss 0.7361
# Epoch 2 Batch 300 Loss 0.5917
# Epoch 2 Batch 400 Loss 0.6793
# Epoch 2 Batch 500 Loss 0.5699
# Epoch 2 Batch 600 Loss 0.6358
# Epoch 2 Batch 700 Loss 0.6418
# Epoch 2 Batch 800 Loss 0.6275
# Epoch 2 Batch 900 Loss 0.6590
# Epoch 2 Batch 1000 Loss 0.6393
# Epoch 2 Batch 1100 Loss 0.6127
# Epoch 2 Batch 1200 Loss 0.5812
# Epoch 2 Batch 1300 Loss 0.6353
# Epoch 2 Batch 1400 Loss 0.5929
# Epoch 2 Batch 1500 Loss 0.5943
# Epoch 2 Batch 1600 Loss 0.6262
# Epoch 2 Batch 1700 Loss 0.6348
# Epoch 2 Batch 1800 Loss 0.6515
# Epoch 2 Batch 1900 Loss 0.5892
# Epoch 2 Batch 2000 Loss 0.6410
# Epoch 2 Batch 2100 Loss 0.6192
# Epoch 2 Batch 2200 Loss 0.6076
# Epoch 2 Batch 2300 Loss 0.6125
# Epoch 2 Batch 2400 Loss 0.5872
# Epoch 2 Batch 2500 Loss 0.6281
# Epoch 2 Batch 2600 Loss 0.6410
# Epoch 2 Batch 2700 Loss 0.6473
# Epoch 2 Batch 2800 Loss 0.6522
# Epoch 2 Batch 2900 Loss 0.6094
# Epoch 2 Batch 3000 Loss 0.5859
# Epoch 2 Batch 3100 Loss 0.5475
# Epoch 2 Batch 3200 Loss 0.5802
# Epoch 2 Batch 3300 Loss 0.5929
# Epoch 2 Batch 3400 Loss 0.6068
# Epoch 2 Batch 3500 Loss 0.5653
# Epoch 2 Batch 3600 Loss 0.5863
# Epoch 2 Batch 3700 Loss 0.5875
# Epoch 2 Batch 3800 Loss 0.5881
# Epoch 2 Batch 3900 Loss 0.5943
# Epoch 2 Batch 4000 Loss 0.5810
# Epoch 2 Loss 0.618856
# Time taken for 1 epoch 1334.1147022247314 sec
#
# Epoch 3 Batch 0 Loss 0.6028
# Epoch 3 Batch 100 Loss 0.5993
# Epoch 3 Batch 200 Loss 0.5649
# Epoch 3 Batch 300 Loss 0.5968
# Epoch 3 Batch 400 Loss 0.5889
# Epoch 3 Batch 500 Loss 0.5927
# Epoch 3 Batch 600 Loss 0.6039
# Epoch 3 Batch 700 Loss 0.6410
# Epoch 3 Batch 800 Loss 0.6236
# Epoch 3 Batch 900 Loss 0.5466
# Epoch 3 Batch 1000 Loss 0.5539
# Epoch 3 Batch 1100 Loss 0.6138
# Epoch 3 Batch 1200 Loss 0.5960
# Epoch 3 Batch 1300 Loss 0.6008
# Epoch 3 Batch 1400 Loss 0.6157
# Epoch 3 Batch 1500 Loss 0.6932
# Epoch 3 Batch 1600 Loss 0.6686
# Epoch 3 Batch 1700 Loss 0.6400
# Epoch 3 Batch 1800 Loss 0.5987
# Epoch 3 Batch 1900 Loss 0.6357
# Epoch 3 Batch 2000 Loss 0.6439
# Epoch 3 Batch 2100 Loss 0.6220
# Epoch 3 Batch 2200 Loss 0.6051
# Epoch 3 Batch 2300 Loss 0.6177
# Epoch 3 Batch 2400 Loss 0.5527
# Epoch 3 Batch 2500 Loss 0.5989
# Epoch 3 Batch 2600 Loss 0.5391
# Epoch 3 Batch 2700 Loss 0.5884
# Epoch 3 Batch 2800 Loss 0.5689
# Epoch 3 Batch 2900 Loss 0.6583
# Epoch 3 Batch 3000 Loss 0.5988
# Epoch 3 Batch 3100 Loss 0.5880
# Epoch 3 Batch 3200 Loss 0.6052
# Epoch 3 Batch 3300 Loss 0.5649
# Epoch 3 Batch 3400 Loss 0.6215
# Epoch 3 Batch 3500 Loss 0.6014
# Epoch 3 Batch 3600 Loss 0.6201
# Epoch 3 Batch 3700 Loss 0.6138
# Epoch 3 Batch 3800 Loss 0.6134
# Epoch 3 Batch 3900 Loss 0.6059
# Epoch 3 Batch 4000 Loss 0.5424
# Epoch 3 Loss 0.592727
# Time taken for 1 epoch 2082.9938173294067 sec
#
# Epoch 4 Batch 0 Loss 0.5914
# Epoch 4 Batch 100 Loss 0.5589
# Epoch 4 Batch 200 Loss 0.5587
# Epoch 4 Batch 300 Loss 0.5832
# Epoch 4 Batch 400 Loss 0.6204
# Epoch 4 Batch 500 Loss 0.6534
# Epoch 4 Batch 600 Loss 0.5605
# Epoch 4 Batch 700 Loss 0.5525
# Epoch 4 Batch 800 Loss 0.5759
# Epoch 4 Batch 900 Loss 0.5498
# Epoch 4 Batch 1000 Loss 0.5557
# Epoch 4 Batch 1100 Loss 0.5759
# Epoch 4 Batch 1200 Loss 0.5829
# Epoch 4 Batch 1300 Loss 0.5264
# Epoch 4 Batch 1400 Loss 0.6055
# Epoch 4 Batch 1500 Loss 0.5463
# Epoch 4 Batch 1600 Loss 0.5934
# Epoch 4 Batch 1700 Loss 0.5858
# Epoch 4 Batch 1800 Loss 0.5830
# Epoch 4 Batch 1900 Loss 0.6016
# Epoch 4 Batch 2000 Loss 0.5716
# Epoch 4 Batch 2100 Loss 0.5655
# Epoch 4 Batch 2200 Loss 0.5915
# Epoch 4 Batch 2300 Loss 0.5755
# Epoch 4 Batch 2400 Loss 0.5940
# Epoch 4 Batch 2500 Loss 0.5876
# Epoch 4 Batch 2600 Loss 0.5539
# Epoch 4 Batch 2700 Loss 0.5908
# Epoch 4 Batch 2800 Loss 0.5389
# Epoch 4 Batch 2900 Loss 0.5903
# Epoch 4 Batch 3000 Loss 0.5551
# Epoch 4 Batch 3100 Loss 0.5957
# Epoch 4 Batch 3200 Loss 0.6081
# Epoch 4 Batch 3300 Loss 0.5977
# Epoch 4 Batch 3400 Loss 0.6219
# Epoch 4 Batch 3500 Loss 0.5647
# Epoch 4 Batch 3600 Loss 0.5535
# Epoch 4 Batch 3700 Loss 0.5366
# Epoch 4 Batch 3800 Loss 0.5404
# Epoch 4 Batch 3900 Loss 0.5762
# Epoch 4 Batch 4000 Loss 0.5405
# Epoch 4 Loss 0.574931
# Time taken for 1 epoch 2043.2050426006317 sec
#
# Epoch 5 Batch 0 Loss 0.5857
# Epoch 5 Batch 100 Loss 0.5652
# Epoch 5 Batch 200 Loss 0.5493
# Epoch 5 Batch 300 Loss 0.5314
# Epoch 5 Batch 400 Loss 0.6001
# Epoch 5 Batch 500 Loss 0.5811
# Epoch 5 Batch 600 Loss 0.5826
# Epoch 5 Batch 700 Loss 0.5788
# Epoch 5 Batch 800 Loss 0.6036
# Epoch 5 Batch 900 Loss 0.5885
# Epoch 5 Batch 1000 Loss 0.5683
# Epoch 5 Batch 1100 Loss 0.5562
# Epoch 5 Batch 1200 Loss 0.5309
# Epoch 5 Batch 1300 Loss 0.5232
# Epoch 5 Batch 1400 Loss 0.5511
# Epoch 5 Batch 1500 Loss 0.5186
# Epoch 5 Batch 1600 Loss 0.6124
# Epoch 5 Batch 1700 Loss 0.6078
# Epoch 5 Batch 1800 Loss 0.5270
# Epoch 5 Batch 1900 Loss 0.5095
# Epoch 5 Batch 2000 Loss 0.5288
# Epoch 5 Batch 2100 Loss 0.6054
# Epoch 5 Batch 2200 Loss 0.5917
# Epoch 5 Batch 2300 Loss 0.5042
# Epoch 5 Batch 2400 Loss 0.5657
# Epoch 5 Batch 2500 Loss 0.5348
# Epoch 5 Batch 2600 Loss 0.5710
# Epoch 5 Batch 2700 Loss 0.5913
# Epoch 5 Batch 2800 Loss 0.5617
# Epoch 5 Batch 2900 Loss 0.5382
# Epoch 5 Batch 3000 Loss 0.5317
# Epoch 5 Batch 3100 Loss 0.5753
# Epoch 5 Batch 3200 Loss 0.5161
# Epoch 5 Batch 3300 Loss 0.5632
# Epoch 5 Batch 3400 Loss 0.5499
# Epoch 5 Batch 3500 Loss 0.4641
# Epoch 5 Batch 3600 Loss 0.5254
# Epoch 5 Batch 3700 Loss 0.5315
# Epoch 5 Batch 3800 Loss 0.5054
# Epoch 5 Batch 3900 Loss 0.5346
# Epoch 5 Batch 4000 Loss 0.5328
# Epoch 5 Loss 0.561086
# Time taken for 1 epoch 1335.1905076503754 sec
#
# Epoch 6 Batch 0 Loss 0.5617
# Epoch 6 Batch 100 Loss 0.6221
# Epoch 6 Batch 200 Loss 0.5494
# Epoch 6 Batch 300 Loss 0.6041
# Epoch 6 Batch 400 Loss 0.5401
# Epoch 6 Batch 500 Loss 0.5576
# Epoch 6 Batch 600 Loss 0.5217
# Epoch 6 Batch 700 Loss 0.6026
# Epoch 6 Batch 800 Loss 0.5711
# Epoch 6 Batch 900 Loss 0.5489
# Epoch 6 Batch 1000 Loss 0.5543
# Epoch 6 Batch 1100 Loss 0.5556
# Epoch 6 Batch 1200 Loss 0.5593
# Epoch 6 Batch 1300 Loss 0.5651
# Epoch 6 Batch 1400 Loss 0.5922
# Epoch 6 Batch 1500 Loss 0.5793
# Epoch 6 Batch 1600 Loss 0.5397
# Epoch 6 Batch 1700 Loss 0.5664
# Epoch 6 Batch 1800 Loss 0.5364
# Epoch 6 Batch 1900 Loss 0.5042
# Epoch 6 Batch 2000 Loss 0.5426
# Epoch 6 Batch 2100 Loss 0.5539
# Epoch 6 Batch 2200 Loss 0.5288
# Epoch 6 Batch 2300 Loss 0.5980
# Epoch 6 Batch 2400 Loss 0.6311
# Epoch 6 Batch 2500 Loss 0.5287
# Epoch 6 Batch 2600 Loss 0.4671
# Epoch 6 Batch 2700 Loss 0.6183
# Epoch 6 Batch 2800 Loss 0.5599
# Epoch 6 Batch 2900 Loss 0.6007
# Epoch 6 Batch 3000 Loss 0.5450
# Epoch 6 Batch 3100 Loss 0.5786
# Epoch 6 Batch 3200 Loss 0.5208
# Epoch 6 Batch 3300 Loss 0.5563
# Epoch 6 Batch 3400 Loss 0.5492
# Epoch 6 Batch 3500 Loss 0.5765
# Epoch 6 Batch 3600 Loss 0.5645
# Epoch 6 Batch 3700 Loss 0.5164
# Epoch 6 Batch 3800 Loss 0.5111
# Epoch 6 Batch 3900 Loss 0.5343
# Epoch 6 Batch 4000 Loss 0.5855
# Epoch 6 Loss 0.549935
# Time taken for 1 epoch 1342.2235898971558 sec
#
# Epoch 7 Batch 0 Loss 0.5614
# Epoch 7 Batch 100 Loss 0.5603
# Epoch 7 Batch 200 Loss 0.5174
# Epoch 7 Batch 300 Loss 0.5823
# Epoch 7 Batch 400 Loss 0.6100
# Epoch 7 Batch 500 Loss 0.5683
# Epoch 7 Batch 600 Loss 0.5056
# Epoch 7 Batch 700 Loss 0.5852
# Epoch 7 Batch 800 Loss 0.5159
# Epoch 7 Batch 900 Loss 0.5655
# Epoch 7 Batch 1000 Loss 0.5441
# Epoch 7 Batch 1100 Loss 0.5668
# Epoch 7 Batch 1200 Loss 0.5304
# Epoch 7 Batch 1300 Loss 0.6104
# Epoch 7 Batch 1400 Loss 0.5215
# Epoch 7 Batch 1500 Loss 0.5470
# Epoch 7 Batch 1600 Loss 0.5736
# Epoch 7 Batch 1700 Loss 0.4979
# Epoch 7 Batch 1800 Loss 0.5722
# Epoch 7 Batch 1900 Loss 0.5320
# Epoch 7 Batch 2000 Loss 0.5521
# Epoch 7 Batch 2100 Loss 0.5782
# Epoch 7 Batch 2200 Loss 0.5230
# Epoch 7 Batch 2300 Loss 0.4950
# Epoch 7 Batch 2400 Loss 0.5286
# Epoch 7 Batch 2500 Loss 0.5500
# Epoch 7 Batch 2600 Loss 0.5077
# Epoch 7 Batch 2700 Loss 0.5706
# Epoch 7 Batch 2800 Loss 0.5417
# Epoch 7 Batch 2900 Loss 0.5374
# Epoch 7 Batch 3000 Loss 0.5608
# Epoch 7 Batch 3100 Loss 0.5627
# Epoch 7 Batch 3200 Loss 0.5040
# Epoch 7 Batch 3300 Loss 0.5403
# Epoch 7 Batch 3400 Loss 0.5487
# Epoch 7 Batch 3500 Loss 0.5683
# Epoch 7 Batch 3600 Loss 0.5113
# Epoch 7 Batch 3700 Loss 0.5760
# Epoch 7 Batch 3800 Loss 0.5279
# Epoch 7 Batch 3900 Loss 0.5434
# Epoch 7 Batch 4000 Loss 0.5669
# Epoch 7 Loss 0.540159
# Time taken for 1 epoch 1307.9130790233612 sec
#
# Epoch 8 Batch 0 Loss 0.6229
# Epoch 8 Batch 100 Loss 0.5358
# Epoch 8 Batch 200 Loss 0.5194
# Epoch 8 Batch 300 Loss 0.5650
# Epoch 8 Batch 400 Loss 0.5794
# Epoch 8 Batch 500 Loss 0.5120
# Epoch 8 Batch 600 Loss 0.5610
# Epoch 8 Batch 700 Loss 0.5189
# Epoch 8 Batch 800 Loss 0.5838
# Epoch 8 Batch 900 Loss 0.5572
# Epoch 8 Batch 1000 Loss 0.5577
# Epoch 8 Batch 1100 Loss 0.5263
# Epoch 8 Batch 1200 Loss 0.5230
# Epoch 8 Batch 1300 Loss 0.5122
# Epoch 8 Batch 1400 Loss 0.4739
# Epoch 8 Batch 1500 Loss 0.5117
# Epoch 8 Batch 1600 Loss 0.5266
# Epoch 8 Batch 1700 Loss 0.5234
# Epoch 8 Batch 1800 Loss 0.4894
# Epoch 8 Batch 1900 Loss 0.5403
# Epoch 8 Batch 2000 Loss 0.5378
# Epoch 8 Batch 2100 Loss 0.5095
# Epoch 8 Batch 2200 Loss 0.4873
# Epoch 8 Batch 2300 Loss 0.5404
# Epoch 8 Batch 2400 Loss 0.5767
# Epoch 8 Batch 2500 Loss 0.6044
# Epoch 8 Batch 2600 Loss 0.5377
# Epoch 8 Batch 2700 Loss 0.4789
# Epoch 8 Batch 2800 Loss 0.5556
# Epoch 8 Batch 2900 Loss 0.6000
# Epoch 8 Batch 3000 Loss 0.4836
# Epoch 8 Batch 3100 Loss 0.5844
# Epoch 8 Batch 3200 Loss 0.5289
# Epoch 8 Batch 3300 Loss 0.4950
# Epoch 8 Batch 3400 Loss 0.5611
# Epoch 8 Batch 3500 Loss 0.5325
# Epoch 8 Batch 3600 Loss 0.5314
# Epoch 8 Batch 3700 Loss 0.5026
# Epoch 8 Batch 3800 Loss 0.4984
# Epoch 8 Batch 3900 Loss 0.5206
# Epoch 8 Batch 4000 Loss 0.5384
# Epoch 8 Loss 0.531524
# Time taken for 1 epoch 1328.5584366321564 sec
#
# Epoch 9 Batch 0 Loss 0.5509
# Epoch 9 Batch 100 Loss 0.5457
# Epoch 9 Batch 200 Loss 0.4908
# Epoch 9 Batch 300 Loss 0.5261
# Epoch 9 Batch 400 Loss 0.5102
# Epoch 9 Batch 500 Loss 0.5473
# Epoch 9 Batch 600 Loss 0.5399
# Epoch 9 Batch 700 Loss 0.5364
# Epoch 9 Batch 800 Loss 0.5726
# Epoch 9 Batch 900 Loss 0.4525
# Epoch 9 Batch 1000 Loss 0.4955
# Epoch 9 Batch 1100 Loss 0.4891
# Epoch 9 Batch 1200 Loss 0.5436
# Epoch 9 Batch 1300 Loss 0.5168
# Epoch 9 Batch 1400 Loss 0.5132
# Epoch 9 Batch 1500 Loss 0.5592
# Epoch 9 Batch 1600 Loss 0.5640
# Epoch 9 Batch 1700 Loss 0.5117
# Epoch 9 Batch 1800 Loss 0.4894
# Epoch 9 Batch 1900 Loss 0.4961
# Epoch 9 Batch 2000 Loss 0.5427
# Epoch 9 Batch 2100 Loss 0.5590
# Epoch 9 Batch 2200 Loss 0.5011
# Epoch 9 Batch 2300 Loss 0.4622
# Epoch 9 Batch 2400 Loss 0.5351
# Epoch 9 Batch 2500 Loss 0.5617
# Epoch 9 Batch 2600 Loss 0.5339
# Epoch 9 Batch 2700 Loss 0.5415
# Epoch 9 Batch 2800 Loss 0.5128
# Epoch 9 Batch 2900 Loss 0.5688
# Epoch 9 Batch 3000 Loss 0.5266
# Epoch 9 Batch 3100 Loss 0.5556
# Epoch 9 Batch 3200 Loss 0.4878
# Epoch 9 Batch 3300 Loss 0.5406
# Epoch 9 Batch 3400 Loss 0.5069
# Epoch 9 Batch 3500 Loss 0.4927
# Epoch 9 Batch 3600 Loss 0.5169
# Epoch 9 Batch 3700 Loss 0.5333
# Epoch 9 Batch 3800 Loss 0.4835
# Epoch 9 Batch 3900 Loss 0.4863
# Epoch 9 Batch 4000 Loss 0.5427
# Epoch 9 Loss 0.523254
# Time taken for 1 epoch 2677.8483502864838 sec
#
# Epoch 10 Batch 0 Loss 0.5613
# Epoch 10 Batch 100 Loss 0.5354
# Epoch 10 Batch 200 Loss 0.5878
# Epoch 10 Batch 300 Loss 0.5177
# Epoch 10 Batch 400 Loss 0.5163
# Epoch 10 Batch 500 Loss 0.5557
# Epoch 10 Batch 600 Loss 0.5192
# Epoch 10 Batch 700 Loss 0.5146
# Epoch 10 Batch 800 Loss 0.5137
# Epoch 10 Batch 900 Loss 0.5020
# Epoch 10 Batch 1000 Loss 0.5413
# Epoch 10 Batch 1100 Loss 0.4389
# Epoch 10 Batch 1200 Loss 0.4971
# Epoch 10 Batch 1300 Loss 0.5097
# Epoch 10 Batch 1400 Loss 0.5225
# Epoch 10 Batch 1500 Loss 0.5131
# Epoch 10 Batch 1600 Loss 0.5307
# Epoch 10 Batch 1700 Loss 0.5198
# Epoch 10 Batch 1800 Loss 0.5379
# Epoch 10 Batch 1900 Loss 0.5420
# Epoch 10 Batch 2000 Loss 0.5308
# Epoch 10 Batch 2100 Loss 0.5827
# Epoch 10 Batch 2200 Loss 0.5273
# Epoch 10 Batch 2300 Loss 0.5196
# Epoch 10 Batch 2400 Loss 0.5624
# Epoch 10 Batch 2500 Loss 0.5436
# Epoch 10 Batch 2600 Loss 0.4809
# Epoch 10 Batch 2700 Loss 0.4847
# Epoch 10 Batch 2800 Loss 0.5321
# Epoch 10 Batch 2900 Loss 0.5131
# Epoch 10 Batch 3000 Loss 0.5252
# Epoch 10 Batch 3100 Loss 0.5028
# Epoch 10 Batch 3200 Loss 0.4909
# Epoch 10 Batch 3300 Loss 0.5612
# Epoch 10 Batch 3400 Loss 0.5486
# Epoch 10 Batch 3500 Loss 0.4632
# Epoch 10 Batch 3600 Loss 0.5676
# Epoch 10 Batch 3700 Loss 0.5300
# Epoch 10 Batch 3800 Loss 0.5373
# Epoch 10 Batch 3900 Loss 0.5329
# Epoch 10 Batch 4000 Loss 0.5059
# Epoch 10 Loss 0.516850
# Time taken for 1 epoch 1336.002162694931 sec
#
# Epoch 11 Batch 0 Loss 0.5235
# Epoch 11 Batch 100 Loss 0.4937
# Epoch 11 Batch 200 Loss 0.5164
# Epoch 11 Batch 300 Loss 0.5233
# Epoch 11 Batch 400 Loss 0.5379
# Epoch 11 Batch 500 Loss 0.4848
# Epoch 11 Batch 600 Loss 0.4932
# Epoch 11 Batch 700 Loss 0.5363
# Epoch 11 Batch 800 Loss 0.5084
# Epoch 11 Batch 900 Loss 0.4915
# Epoch 11 Batch 1000 Loss 0.4932
# Epoch 11 Batch 1100 Loss 0.5487
# Epoch 11 Batch 1200 Loss 0.4772
# Epoch 11 Batch 1300 Loss 0.4731
# Epoch 11 Batch 1400 Loss 0.5375
# Epoch 11 Batch 1500 Loss 0.4984
# Epoch 11 Batch 1600 Loss 0.4903
# Epoch 11 Batch 1700 Loss 0.5312
# Epoch 11 Batch 1800 Loss 0.5365
# Epoch 11 Batch 1900 Loss 0.4931
# Epoch 11 Batch 2000 Loss 0.4663
# Epoch 11 Batch 2100 Loss 0.5702
# Epoch 11 Batch 2200 Loss 0.5534
# Epoch 11 Batch 2300 Loss 0.4908
# Epoch 11 Batch 2400 Loss 0.4389
# Epoch 11 Batch 2500 Loss 0.5265
# Epoch 11 Batch 2600 Loss 0.4907
# Epoch 11 Batch 2700 Loss 0.4951
# Epoch 11 Batch 2800 Loss 0.4617
# Epoch 11 Batch 2900 Loss 0.5285
# Epoch 11 Batch 3000 Loss 0.5063
# Epoch 11 Batch 3100 Loss 0.4891
# Epoch 11 Batch 3200 Loss 0.4912
# Epoch 11 Batch 3300 Loss 0.5276
# Epoch 11 Batch 3400 Loss 0.5131
# Epoch 11 Batch 3500 Loss 0.4866
# Epoch 11 Batch 3600 Loss 0.4958
# Epoch 11 Batch 3700 Loss 0.4941
# Epoch 11 Batch 3800 Loss 0.4632
# Epoch 11 Batch 3900 Loss 0.5008
# Epoch 11 Batch 4000 Loss 0.5376
# Epoch 11 Loss 0.510174
# Time taken for 1 epoch 1292.3950514793396 sec
#
# Epoch 12 Batch 0 Loss 0.4768
# Epoch 12 Batch 100 Loss 0.5572
# Epoch 12 Batch 200 Loss 0.4658
# Epoch 12 Batch 300 Loss 0.5158
# Epoch 12 Batch 400 Loss 0.4901
# Epoch 12 Batch 500 Loss 0.5107
# Epoch 12 Batch 600 Loss 0.5647
# Epoch 12 Batch 700 Loss 0.5459
# Epoch 12 Batch 800 Loss 0.5421
# Epoch 12 Batch 900 Loss 0.4663
# Epoch 12 Batch 1000 Loss 0.5340
# Epoch 12 Batch 1100 Loss 0.4627
# Epoch 12 Batch 1200 Loss 0.4841
# Epoch 12 Batch 1300 Loss 0.4849
# Epoch 12 Batch 1400 Loss 0.4969
# Epoch 12 Batch 1500 Loss 0.5037
# Epoch 12 Batch 1600 Loss 0.4988
# Epoch 12 Batch 1700 Loss 0.5183
# Epoch 12 Batch 1800 Loss 0.5364
# Epoch 12 Batch 1900 Loss 0.4824
# Epoch 12 Batch 2000 Loss 0.5269
# Epoch 12 Batch 2100 Loss 0.4917
# Epoch 12 Batch 2200 Loss 0.5426
# Epoch 12 Batch 2300 Loss 0.5176
# Epoch 12 Batch 2400 Loss 0.4807
# Epoch 12 Batch 2500 Loss 0.5107
# Epoch 12 Batch 2600 Loss 0.5110
# Epoch 12 Batch 2700 Loss 0.5868
# Epoch 12 Batch 2800 Loss 0.4606
# Epoch 12 Batch 2900 Loss 0.5071
# Epoch 12 Batch 3000 Loss 0.4415
# Epoch 12 Batch 3100 Loss 0.4881
# Epoch 12 Batch 3200 Loss 0.4961
# Epoch 12 Batch 3300 Loss 0.4493
# Epoch 12 Batch 3400 Loss 0.4408
# Epoch 12 Batch 3500 Loss 0.4971
# Epoch 12 Batch 3600 Loss 0.4672
# Epoch 12 Batch 3700 Loss 0.5134
# Epoch 12 Batch 3800 Loss 0.4741
# Epoch 12 Batch 3900 Loss 0.4745
# Epoch 12 Batch 4000 Loss 0.5102
# Epoch 12 Loss 0.504200
# Time taken for 1 epoch 1283.5437512397766 sec
#
# Epoch 13 Batch 0 Loss 0.5272
# Epoch 13 Batch 100 Loss 0.5033
# Epoch 13 Batch 200 Loss 0.5033
# Epoch 13 Batch 300 Loss 0.5133
# Epoch 13 Batch 400 Loss 0.4943
# Epoch 13 Batch 500 Loss 0.4886
# Epoch 13 Batch 600 Loss 0.5060
# Epoch 13 Batch 700 Loss 0.4999
# Epoch 13 Batch 800 Loss 0.4715
# Epoch 13 Batch 900 Loss 0.5161
# Epoch 13 Batch 1000 Loss 0.4693
# Epoch 13 Batch 1100 Loss 0.5245
# Epoch 13 Batch 1200 Loss 0.5582
# Epoch 13 Batch 1300 Loss 0.4701
# Epoch 13 Batch 1400 Loss 0.5056
# Epoch 13 Batch 1500 Loss 0.5169
# Epoch 13 Batch 1600 Loss 0.4581
# Epoch 13 Batch 1700 Loss 0.4977
# Epoch 13 Batch 1800 Loss 0.4916
# Epoch 13 Batch 1900 Loss 0.5249
# Epoch 13 Batch 2000 Loss 0.5278
# Epoch 13 Batch 2100 Loss 0.4932
# Epoch 13 Batch 2200 Loss 0.4495
# Epoch 13 Batch 2300 Loss 0.5097
# Epoch 13 Batch 2400 Loss 0.5125
# Epoch 13 Batch 2500 Loss 0.5055
# Epoch 13 Batch 2600 Loss 0.4842
# Epoch 13 Batch 2700 Loss 0.4733
# Epoch 13 Batch 2800 Loss 0.4928
# Epoch 13 Batch 2900 Loss 0.5049
# Epoch 13 Batch 3000 Loss 0.4614
# Epoch 13 Batch 3100 Loss 0.4903
# Epoch 13 Batch 3200 Loss 0.4988
# Epoch 13 Batch 3300 Loss 0.5046
# Epoch 13 Batch 3400 Loss 0.5272
# Epoch 13 Batch 3500 Loss 0.4789
# Epoch 13 Batch 3600 Loss 0.4916
# Epoch 13 Batch 3700 Loss 0.4994
# Epoch 13 Batch 3800 Loss 0.4796
# Epoch 13 Batch 3900 Loss 0.4988
# Epoch 13 Batch 4000 Loss 0.4846
# Epoch 13 Loss 0.498799
# Time taken for 1 epoch 2427.3845720291138 sec
#
# Epoch 14 Batch 0 Loss 0.4921
# Epoch 14 Batch 100 Loss 0.5865
# Epoch 14 Batch 200 Loss 0.4961
# Epoch 14 Batch 300 Loss 0.4824
# Epoch 14 Batch 400 Loss 0.5009
# Epoch 14 Batch 500 Loss 0.4519
# Epoch 14 Batch 600 Loss 0.4950
# Epoch 14 Batch 700 Loss 0.4980
# Epoch 14 Batch 800 Loss 0.5386
# Epoch 14 Batch 900 Loss 0.4917
# Epoch 14 Batch 1000 Loss 0.5640
# Epoch 14 Batch 1100 Loss 0.4744
# Epoch 14 Batch 1200 Loss 0.4950
# Epoch 14 Batch 1300 Loss 0.4900
# Epoch 14 Batch 1400 Loss 0.5275
# Epoch 14 Batch 1500 Loss 0.5137
# Epoch 14 Batch 1600 Loss 0.5313
# Epoch 14 Batch 1700 Loss 0.4618
# Epoch 14 Batch 1800 Loss 0.5290
# Epoch 14 Batch 1900 Loss 0.4661
# Epoch 14 Batch 2000 Loss 0.4947
# Epoch 14 Batch 2100 Loss 0.5227
# Epoch 14 Batch 2200 Loss 0.4871
# Epoch 14 Batch 2300 Loss 0.5145
# Epoch 14 Batch 2400 Loss 0.4854
# Epoch 14 Batch 2500 Loss 0.4438
# Epoch 14 Batch 2600 Loss 0.5044
# Epoch 14 Batch 2700 Loss 0.4743
# Epoch 14 Batch 2800 Loss 0.4559
# Epoch 14 Batch 2900 Loss 0.4804
# Epoch 14 Batch 3000 Loss 0.4721
# Epoch 14 Batch 3100 Loss 0.5059
# Epoch 14 Batch 3200 Loss 0.4835
# Epoch 14 Batch 3300 Loss 0.4740
# Epoch 14 Batch 3400 Loss 0.4946
# Epoch 14 Batch 3500 Loss 0.4542
# Epoch 14 Batch 3600 Loss 0.4908
# Epoch 14 Batch 3700 Loss 0.4914
# Epoch 14 Batch 3800 Loss 0.4591
# Epoch 14 Batch 3900 Loss 0.5151
# Epoch 14 Batch 4000 Loss 0.5049
# Epoch 14 Loss 0.494422
# Time taken for 1 epoch 1302.9557132720947 sec
#
# Epoch 15 Batch 0 Loss 0.4843
# Epoch 15 Batch 100 Loss 0.5340
# Epoch 15 Batch 200 Loss 0.5119
# Epoch 15 Batch 300 Loss 0.5104
# Epoch 15 Batch 400 Loss 0.5422
# Epoch 15 Batch 500 Loss 0.4585
# Epoch 15 Batch 600 Loss 0.5108
# Epoch 15 Batch 700 Loss 0.5270
# Epoch 15 Batch 800 Loss 0.4654
# Epoch 15 Batch 900 Loss 0.4890
# Epoch 15 Batch 1000 Loss 0.4654
# Epoch 15 Batch 1100 Loss 0.4954
# Epoch 15 Batch 1200 Loss 0.5231
# Epoch 15 Batch 1300 Loss 0.4690
# Epoch 15 Batch 1400 Loss 0.4278
# Epoch 15 Batch 1500 Loss 0.5338
# Epoch 15 Batch 1600 Loss 0.5119
# Epoch 15 Batch 1700 Loss 0.4896
# Epoch 15 Batch 1800 Loss 0.4526
# Epoch 15 Batch 1900 Loss 0.4744
# Epoch 15 Batch 2000 Loss 0.4884
# Epoch 15 Batch 2100 Loss 0.4948
# Epoch 15 Batch 2200 Loss 0.5254
# Epoch 15 Batch 2300 Loss 0.4977
# Epoch 15 Batch 2400 Loss 0.4695
# Epoch 15 Batch 2500 Loss 0.5031
# Epoch 15 Batch 2600 Loss 0.4999
# Epoch 15 Batch 2700 Loss 0.4909
# Epoch 15 Batch 2800 Loss 0.5044
# Epoch 15 Batch 2900 Loss 0.5032
# Epoch 15 Batch 3000 Loss 0.4762
# Epoch 15 Batch 3100 Loss 0.4954
# Epoch 15 Batch 3200 Loss 0.4740
# Epoch 15 Batch 3300 Loss 0.4881
# Epoch 15 Batch 3400 Loss 0.4813
# Epoch 15 Batch 3500 Loss 0.4376
# Epoch 15 Batch 3600 Loss 0.5481
# Epoch 15 Batch 3700 Loss 0.5041
# Epoch 15 Batch 3800 Loss 0.4419
# Epoch 15 Batch 3900 Loss 0.4379
# Epoch 15 Batch 4000 Loss 0.5288
# Epoch 15 Loss 0.489719
# Time taken for 1 epoch 2213.973288297653 sec
#
# Epoch 16 Batch 0 Loss 0.5225
# Epoch 16 Batch 100 Loss 0.5327
# Epoch 16 Batch 200 Loss 0.4671
# Epoch 16 Batch 300 Loss 0.5127
# Epoch 16 Batch 400 Loss 0.5035
# Epoch 16 Batch 500 Loss 0.4972
# Epoch 16 Batch 600 Loss 0.4836
# Epoch 16 Batch 700 Loss 0.5387
# Epoch 16 Batch 800 Loss 0.5167
# Epoch 16 Batch 900 Loss 0.4846
# Epoch 16 Batch 1000 Loss 0.4655
# Epoch 16 Batch 1100 Loss 0.5072
# Epoch 16 Batch 1200 Loss 0.4680
# Epoch 16 Batch 1300 Loss 0.4983
# Epoch 16 Batch 1400 Loss 0.5601
# Epoch 16 Batch 1500 Loss 0.4864
# Epoch 16 Batch 1600 Loss 0.4890
# Epoch 16 Batch 1700 Loss 0.5247
# Epoch 16 Batch 1800 Loss 0.5047
# Epoch 16 Batch 1900 Loss 0.4850
# Epoch 16 Batch 2000 Loss 0.4818
# Epoch 16 Batch 2100 Loss 0.4954
# Epoch 16 Batch 2200 Loss 0.4955
# Epoch 16 Batch 2300 Loss 0.4652
# Epoch 16 Batch 2400 Loss 0.5405
# Epoch 16 Batch 2500 Loss 0.4736
# Epoch 16 Batch 2600 Loss 0.4770
# Epoch 16 Batch 2700 Loss 0.5054
# Epoch 16 Batch 2800 Loss 0.4592
# Epoch 16 Batch 2900 Loss 0.4934
# Epoch 16 Batch 3000 Loss 0.4650
# Epoch 16 Batch 3100 Loss 0.4841
# Epoch 16 Batch 3200 Loss 0.5006
# Epoch 16 Batch 3300 Loss 0.5094
# Epoch 16 Batch 3400 Loss 0.4935
# Epoch 16 Batch 3500 Loss 0.4706
# Epoch 16 Batch 3600 Loss 0.5482
# Epoch 16 Batch 3700 Loss 0.5177
# Epoch 16 Batch 3800 Loss 0.5276
# Epoch 16 Batch 3900 Loss 0.4694
# Epoch 16 Batch 4000 Loss 0.5148
# Epoch 16 Loss 0.485757
# Time taken for 1 epoch 1378.930659532547 sec
#
# Epoch 17 Batch 0 Loss 0.4817
# Epoch 17 Batch 100 Loss 0.4621
# Epoch 17 Batch 200 Loss 0.5377
# Epoch 17 Batch 300 Loss 0.4484
# Epoch 17 Batch 400 Loss 0.5065
# Epoch 17 Batch 500 Loss 0.4730
# Epoch 17 Batch 600 Loss 0.5078
# Epoch 17 Batch 700 Loss 0.4866
# Epoch 17 Batch 800 Loss 0.4673
# Epoch 17 Batch 900 Loss 0.4932
# Epoch 17 Batch 1000 Loss 0.4785
# Epoch 17 Batch 1100 Loss 0.5196
# Epoch 17 Batch 1200 Loss 0.4761
# Epoch 17 Batch 1300 Loss 0.4601
# Epoch 17 Batch 1400 Loss 0.4647
# Epoch 17 Batch 1500 Loss 0.4369
# Epoch 17 Batch 1600 Loss 0.4858
# Epoch 17 Batch 1700 Loss 0.4576
# Epoch 17 Batch 1800 Loss 0.4959
# Epoch 17 Batch 1900 Loss 0.5445
# Epoch 17 Batch 2000 Loss 0.4925
# Epoch 17 Batch 2100 Loss 0.4810
# Epoch 17 Batch 2200 Loss 0.4547
# Epoch 17 Batch 2300 Loss 0.5126
# Epoch 17 Batch 2400 Loss 0.5284
# Epoch 17 Batch 2500 Loss 0.4865
# Epoch 17 Batch 2600 Loss 0.4630
# Epoch 17 Batch 2700 Loss 0.4806
# Epoch 17 Batch 2800 Loss 0.4664
# Epoch 17 Batch 2900 Loss 0.4615
# Epoch 17 Batch 3000 Loss 0.5073
# Epoch 17 Batch 3100 Loss 0.4714
# Epoch 17 Batch 3200 Loss 0.4725
# Epoch 17 Batch 3300 Loss 0.4499
# Epoch 17 Batch 3400 Loss 0.5229
# Epoch 17 Batch 3500 Loss 0.4829
# Epoch 17 Batch 3600 Loss 0.5080
# Epoch 17 Batch 3700 Loss 0.4439
# Epoch 17 Batch 3800 Loss 0.4557
# Epoch 17 Batch 3900 Loss 0.4393
# Epoch 17 Batch 4000 Loss 0.4799
# Epoch 17 Loss 0.481459
# Time taken for 1 epoch 1338.6978843212128 sec
#
# Epoch 18 Batch 0 Loss 0.5113
# Epoch 18 Batch 100 Loss 0.4752
# Epoch 18 Batch 200 Loss 0.4712
# Epoch 18 Batch 300 Loss 0.4622
# Epoch 18 Batch 400 Loss 0.5074
# Epoch 18 Batch 500 Loss 0.4497
# Epoch 18 Batch 600 Loss 0.5020
# Epoch 18 Batch 700 Loss 0.5050
# Epoch 18 Batch 800 Loss 0.4939
# Epoch 18 Batch 900 Loss 0.4602
# Epoch 18 Batch 1000 Loss 0.4776
# Epoch 18 Batch 1100 Loss 0.4413
# Epoch 18 Batch 1200 Loss 0.4939
# Epoch 18 Batch 1300 Loss 0.4728
# Epoch 18 Batch 1400 Loss 0.4643
# Epoch 18 Batch 1500 Loss 0.4282
# Epoch 18 Batch 1600 Loss 0.4692
# Epoch 18 Batch 1700 Loss 0.4867
# Epoch 18 Batch 1800 Loss 0.4808
# Epoch 18 Batch 1900 Loss 0.4473
# Epoch 18 Batch 2000 Loss 0.4504
# Epoch 18 Batch 2100 Loss 0.4910
# Epoch 18 Batch 2200 Loss 0.4723
# Epoch 18 Batch 2300 Loss 0.4662
# Epoch 18 Batch 2400 Loss 0.5216
# Epoch 18 Batch 2500 Loss 0.4560
# Epoch 18 Batch 2600 Loss 0.4783
# Epoch 18 Batch 2700 Loss 0.4853
# Epoch 18 Batch 2800 Loss 0.4393
# Epoch 18 Batch 2900 Loss 0.4671
# Epoch 18 Batch 3000 Loss 0.4575
# Epoch 18 Batch 3100 Loss 0.4713
# Epoch 18 Batch 3200 Loss 0.4337
# Epoch 18 Batch 3300 Loss 0.4634
# Epoch 18 Batch 3400 Loss 0.4504
# Epoch 18 Batch 3500 Loss 0.4604
# Epoch 18 Batch 3600 Loss 0.4636
# Epoch 18 Batch 3700 Loss 0.4933
# Epoch 18 Batch 3800 Loss 0.5047
# Epoch 18 Batch 3900 Loss 0.5242
# Epoch 18 Batch 4000 Loss 0.4645
# Epoch 18 Loss 0.478200
# Time taken for 1 epoch 1338.2345039844513 sec
#
# Epoch 19 Batch 0 Loss 0.4502
# Epoch 19 Batch 100 Loss 0.4539
# Epoch 19 Batch 200 Loss 0.4821
# Epoch 19 Batch 300 Loss 0.4615
# Epoch 19 Batch 400 Loss 0.5382
# Epoch 19 Batch 500 Loss 0.4759
# Epoch 19 Batch 600 Loss 0.4995
# Epoch 19 Batch 700 Loss 0.5115
# Epoch 19 Batch 800 Loss 0.4584
# Epoch 19 Batch 900 Loss 0.4378
# Epoch 19 Batch 1000 Loss 0.4452
# Epoch 19 Batch 1100 Loss 0.4839
# Epoch 19 Batch 1200 Loss 0.4875
# Epoch 19 Batch 1300 Loss 0.4684
# Epoch 19 Batch 1400 Loss 0.5000
# Epoch 19 Batch 1500 Loss 0.4492
# Epoch 19 Batch 1600 Loss 0.4281
# Epoch 19 Batch 1700 Loss 0.4965
# Epoch 19 Batch 1800 Loss 0.4692
# Epoch 19 Batch 1900 Loss 0.4706
# Epoch 19 Batch 2000 Loss 0.5061
# Epoch 19 Batch 2100 Loss 0.4753
# Epoch 19 Batch 2200 Loss 0.5270
# Epoch 19 Batch 2300 Loss 0.4880
# Epoch 19 Batch 2400 Loss 0.4990
# Epoch 19 Batch 2500 Loss 0.4636
# Epoch 19 Batch 2600 Loss 0.5032
# Epoch 19 Batch 2700 Loss 0.4512
# Epoch 19 Batch 2800 Loss 0.5346
# Epoch 19 Batch 2900 Loss 0.4957
# Epoch 19 Batch 3000 Loss 0.4641
# Epoch 19 Batch 3100 Loss 0.4758
# Epoch 19 Batch 3200 Loss 0.3980
# Epoch 19 Batch 3300 Loss 0.4630
# Epoch 19 Batch 3400 Loss 0.4766
# Epoch 19 Batch 3500 Loss 0.4681
# Epoch 19 Batch 3600 Loss 0.4655
# Epoch 19 Batch 3700 Loss 0.4795
# Epoch 19 Batch 3800 Loss 0.4550
# Epoch 19 Batch 3900 Loss 0.4547
# Epoch 19 Batch 4000 Loss 0.4337
# Epoch 19 Loss 0.474742
# Time taken for 1 epoch 1835.1295993328094 sec
#
# Epoch 20 Batch 0 Loss 0.4407
# Epoch 20 Batch 100 Loss 0.4419
# Epoch 20 Batch 200 Loss 0.4607
# Epoch 20 Batch 300 Loss 0.4899
# Epoch 20 Batch 400 Loss 0.4233
# Epoch 20 Batch 500 Loss 0.4313
# Epoch 20 Batch 600 Loss 0.4683
# Epoch 20 Batch 700 Loss 0.4715
# Epoch 20 Batch 800 Loss 0.4799
# Epoch 20 Batch 900 Loss 0.4662
# Epoch 20 Batch 1000 Loss 0.4350
# Epoch 20 Batch 1100 Loss 0.4969
# Epoch 20 Batch 1200 Loss 0.4925
# Epoch 20 Batch 1300 Loss 0.5097
# Epoch 20 Batch 1400 Loss 0.5022
# Epoch 20 Batch 1500 Loss 0.4978
# Epoch 20 Batch 1600 Loss 0.4764
# Epoch 20 Batch 1700 Loss 0.4617
# Epoch 20 Batch 1800 Loss 0.4606
# Epoch 20 Batch 1900 Loss 0.4605
# Epoch 20 Batch 2000 Loss 0.4844
# Epoch 20 Batch 2100 Loss 0.4444
# Epoch 20 Batch 2200 Loss 0.4630
# Epoch 20 Batch 2300 Loss 0.4620
# Epoch 20 Batch 2400 Loss 0.4537
# Epoch 20 Batch 2500 Loss 0.4736
# Epoch 20 Batch 2600 Loss 0.4498
# Epoch 20 Batch 2700 Loss 0.5522
# Epoch 20 Batch 2800 Loss 0.4858
# Epoch 20 Batch 2900 Loss 0.5280
# Epoch 20 Batch 3000 Loss 0.4356
# Epoch 20 Batch 3100 Loss 0.4818
# Epoch 20 Batch 3200 Loss 0.4244
# Epoch 20 Batch 3300 Loss 0.4579
# Epoch 20 Batch 3400 Loss 0.4391
# Epoch 20 Batch 3500 Loss 0.5131
# Epoch 20 Batch 3600 Loss 0.4985
# Epoch 20 Batch 3700 Loss 0.4895
# Epoch 20 Batch 3800 Loss 0.4339
# Epoch 20 Batch 3900 Loss 0.4971
# Epoch 20 Batch 4000 Loss 0.4622
# Epoch 20 Loss 0.471374
# Time taken for 1 epoch 1284.0814850330353 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (7, 7))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print ('Real Caption:', real_caption)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a bunch of bananas sit on sale at a store <end>
# Prediction Caption: the bananas hanging on a lot with green bananas at a line for sale <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a man riding a wave <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x1757B7A74C0>
