# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections #for storing different types of tuples and dictionares
import random  #random initialization
import re  # Regular expressions are text matching patterns described with a formal syntax
import numpy as np 
import os  #allows you to interface with the underlying operating system that Python is running on. 
import time #time dependent tasks
import json #load json files
from glob import glob #listing files under a specified folder
from PIL import Image #image manipulation
import pickle #serialize python objects

# %%
# Download caption annotation files
annotation_folder = '/annotation/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
    annotation_zip = tf.keras.utils.get_file('captions.zip',
                                             cache_subdir=os.path.abspath('.'),
                                             origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                             extract = True)
    annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
    os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
    image_zip = tf.keras.utils.get_file('train2014.zip',
                                        cache_subdir=os.path.abspath('.'),
                                        origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                        extract = True)
    PATH = os.path.dirname(image_zip) + image_folder
    os.remove(image_zip)
else:
    PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 68s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    caption = f"<start> {val['caption']} <end>"
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths[:64000]
print(len(train_image_paths))
# Out:
# 64000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    train_captions.extend(caption_list)
    img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A pink boat that has been trransformed into a car. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x284F7106460>

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (224, 224))
    img = tf.keras.applications.vgg19.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.VGG19(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in image_dataset:
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                                (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
    capt_len = len(img_to_cap_vector[imgt])
    img_name_train.extend([imgt] * capt_len)
    cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
    capv_len = len(img_to_cap_vector[imgv])
    img_name_val.extend([imgv] * capv_len)
    cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (256123, 256123, 64030, 64030)

# %%
# hyper parameters

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from VGG16 is (64, 2048)
# These two variables represent that vector shape
features_shape = 512
attention_features_shape = 49

# %%
# Load the numpy files
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

        # hidden shape == (batch_size, hidden_size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        # attention_hidden_layer shape == (batch_size, 64, units)
        attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                             self.W2(hidden_with_time_axis)))

        # score shape == (batch_size, 64, 1)
        # This gives you an unnormalized score for each image feature.
        score = self.V(attention_hidden_layer)

        # attention_weights shape == (batch_size, 64, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it using pickle
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

        # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

        # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/vgg19_2"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # restoring the latest checkpoint in checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

              # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.9156
# Epoch 1 Batch 100 Loss 1.0098
# Epoch 1 Batch 200 Loss 0.8992
# Epoch 1 Batch 300 Loss 0.8671
# Epoch 1 Batch 400 Loss 0.7587
# Epoch 1 Batch 500 Loss 0.7292
# Epoch 1 Batch 600 Loss 0.7814
# Epoch 1 Batch 700 Loss 0.7733
# Epoch 1 Batch 800 Loss 0.7150
# Epoch 1 Batch 900 Loss 0.7596
# Epoch 1 Batch 1000 Loss 0.7572
# Epoch 1 Batch 1100 Loss 0.6856
# Epoch 1 Batch 1200 Loss 0.6867
# Epoch 1 Batch 1300 Loss 0.6544
# Epoch 1 Batch 1400 Loss 0.7114
# Epoch 1 Batch 1500 Loss 0.6766
# Epoch 1 Batch 1600 Loss 0.6882
# Epoch 1 Batch 1700 Loss 0.6881
# Epoch 1 Batch 1800 Loss 0.6850
# Epoch 1 Batch 1900 Loss 0.6119
# Epoch 1 Batch 2000 Loss 0.6675
# Epoch 1 Batch 2100 Loss 0.7083
# Epoch 1 Batch 2200 Loss 0.6446
# Epoch 1 Batch 2300 Loss 0.6705
# Epoch 1 Batch 2400 Loss 0.6784
# Epoch 1 Batch 2500 Loss 0.6414
# Epoch 1 Batch 2600 Loss 0.6971
# Epoch 1 Batch 2700 Loss 0.6533
# Epoch 1 Batch 2800 Loss 0.6110
# Epoch 1 Batch 2900 Loss 0.5687
# Epoch 1 Batch 3000 Loss 0.6109
# Epoch 1 Batch 3100 Loss 0.6035
# Epoch 1 Batch 3200 Loss 0.6106
# Epoch 1 Batch 3300 Loss 0.6118
# Epoch 1 Batch 3400 Loss 0.6491
# Epoch 1 Batch 3500 Loss 0.6350
# Epoch 1 Batch 3600 Loss 0.6686
# Epoch 1 Batch 3700 Loss 0.6171
# Epoch 1 Batch 3800 Loss 0.6319
# Epoch 1 Batch 3900 Loss 0.5826
# Epoch 1 Batch 4000 Loss 0.5720
# Epoch 1 Loss 0.704750
# Time taken for 1 epoch 1493.5508716106415 sec
#
# Epoch 2 Batch 0 Loss 0.6619
# Epoch 2 Batch 100 Loss 0.6194
# Epoch 2 Batch 200 Loss 0.6299
# Epoch 2 Batch 300 Loss 0.6081
# Epoch 2 Batch 400 Loss 0.6181
# Epoch 2 Batch 500 Loss 0.5789
# Epoch 2 Batch 600 Loss 0.6658
# Epoch 2 Batch 700 Loss 0.6536
# Epoch 2 Batch 800 Loss 0.6039
# Epoch 2 Batch 900 Loss 0.6369
# Epoch 2 Batch 1000 Loss 0.6062
# Epoch 2 Batch 1100 Loss 0.6016
# Epoch 2 Batch 1200 Loss 0.6012
# Epoch 2 Batch 1300 Loss 0.6045
# Epoch 2 Batch 1400 Loss 0.6133
# Epoch 2 Batch 1500 Loss 0.5846
# Epoch 2 Batch 1600 Loss 0.6064
# Epoch 2 Batch 1700 Loss 0.5728
# Epoch 2 Batch 1800 Loss 0.5813
# Epoch 2 Batch 1900 Loss 0.6260
# Epoch 2 Batch 2000 Loss 0.6148
# Epoch 2 Batch 2100 Loss 0.6226
# Epoch 2 Batch 2200 Loss 0.6100
# Epoch 2 Batch 2300 Loss 0.6168
# Epoch 2 Batch 2400 Loss 0.5554
# Epoch 2 Batch 2500 Loss 0.5854
# Epoch 2 Batch 2600 Loss 0.5568
# Epoch 2 Batch 2700 Loss 0.5874
# Epoch 2 Batch 2800 Loss 0.5825
# Epoch 2 Batch 2900 Loss 0.5795
# Epoch 2 Batch 3000 Loss 0.6101
# Epoch 2 Batch 3100 Loss 0.5752
# Epoch 2 Batch 3200 Loss 0.6224
# Epoch 2 Batch 3300 Loss 0.6241
# Epoch 2 Batch 3400 Loss 0.6058
# Epoch 2 Batch 3500 Loss 0.5361
# Epoch 2 Batch 3600 Loss 0.6208
# Epoch 2 Batch 3700 Loss 0.6584
# Epoch 2 Batch 3800 Loss 0.6520
# Epoch 2 Batch 3900 Loss 0.6556
# Epoch 2 Batch 4000 Loss 0.6669
# Epoch 2 Loss 0.609168
# Time taken for 1 epoch 1356.47674036026 sec
#
# Epoch 3 Batch 0 Loss 0.6254
# Epoch 3 Batch 100 Loss 0.6302
# Epoch 3 Batch 200 Loss 0.5798
# Epoch 3 Batch 300 Loss 0.5705
# Epoch 3 Batch 400 Loss 0.6123
# Epoch 3 Batch 500 Loss 0.5384
# Epoch 3 Batch 600 Loss 0.5839
# Epoch 3 Batch 700 Loss 0.5828
# Epoch 3 Batch 800 Loss 0.6036
# Epoch 3 Batch 900 Loss 0.5215
# Epoch 3 Batch 1000 Loss 0.5411
# Epoch 3 Batch 1100 Loss 0.5812
# Epoch 3 Batch 1200 Loss 0.5250
# Epoch 3 Batch 1300 Loss 0.5593
# Epoch 3 Batch 1400 Loss 0.5413
# Epoch 3 Batch 1500 Loss 0.6074
# Epoch 3 Batch 1600 Loss 0.5627
# Epoch 3 Batch 1700 Loss 0.5577
# Epoch 3 Batch 1800 Loss 0.5627
# Epoch 3 Batch 1900 Loss 0.5904
# Epoch 3 Batch 2000 Loss 0.6487
# Epoch 3 Batch 2100 Loss 0.5906
# Epoch 3 Batch 2200 Loss 0.6153
# Epoch 3 Batch 2300 Loss 0.5628
# Epoch 3 Batch 2400 Loss 0.5614
# Epoch 3 Batch 2500 Loss 0.6316
# Epoch 3 Batch 2600 Loss 0.5288
# Epoch 3 Batch 2700 Loss 0.6134
# Epoch 3 Batch 2800 Loss 0.5974
# Epoch 3 Batch 2900 Loss 0.5909
# Epoch 3 Batch 3000 Loss 0.5385
# Epoch 3 Batch 3100 Loss 0.5542
# Epoch 3 Batch 3200 Loss 0.5924
# Epoch 3 Batch 3300 Loss 0.6222
# Epoch 3 Batch 3400 Loss 0.6573
# Epoch 3 Batch 3500 Loss 0.6049
# Epoch 3 Batch 3600 Loss 0.5752
# Epoch 3 Batch 3700 Loss 0.5645
# Epoch 3 Batch 3800 Loss 0.6201
# Epoch 3 Batch 3900 Loss 0.6224
# Epoch 3 Batch 4000 Loss 0.5609
# Epoch 3 Loss 0.583220
# Time taken for 1 epoch 1361.2181503772736 sec
#
# Epoch 4 Batch 0 Loss 0.5840
# Epoch 4 Batch 100 Loss 0.5903
# Epoch 4 Batch 200 Loss 0.5404
# Epoch 4 Batch 300 Loss 0.5563
# Epoch 4 Batch 400 Loss 0.6265
# Epoch 4 Batch 500 Loss 0.6551
# Epoch 4 Batch 600 Loss 0.5884
# Epoch 4 Batch 700 Loss 0.5566
# Epoch 4 Batch 800 Loss 0.5510
# Epoch 4 Batch 900 Loss 0.5651
# Epoch 4 Batch 1000 Loss 0.5732
# Epoch 4 Batch 1100 Loss 0.5529
# Epoch 4 Batch 1200 Loss 0.5256
# Epoch 4 Batch 1300 Loss 0.5752
# Epoch 4 Batch 1400 Loss 0.5699
# Epoch 4 Batch 1500 Loss 0.5568
# Epoch 4 Batch 1600 Loss 0.5411
# Epoch 4 Batch 1700 Loss 0.5565
# Epoch 4 Batch 1800 Loss 0.5391
# Epoch 4 Batch 1900 Loss 0.5638
# Epoch 4 Batch 2000 Loss 0.5162
# Epoch 4 Batch 2100 Loss 0.5629
# Epoch 4 Batch 2200 Loss 0.5300
# Epoch 4 Batch 2300 Loss 0.5339
# Epoch 4 Batch 2400 Loss 0.5218
# Epoch 4 Batch 2500 Loss 0.5810
# Epoch 4 Batch 2600 Loss 0.5617
# Epoch 4 Batch 2700 Loss 0.5418
# Epoch 4 Batch 2800 Loss 0.5716
# Epoch 4 Batch 2900 Loss 0.4977
# Epoch 4 Batch 3000 Loss 0.5331
# Epoch 4 Batch 3100 Loss 0.5523
# Epoch 4 Batch 3200 Loss 0.5434
# Epoch 4 Batch 3300 Loss 0.5163
# Epoch 4 Batch 3400 Loss 0.5543
# Epoch 4 Batch 3500 Loss 0.6150
# Epoch 4 Batch 3600 Loss 0.5921
# Epoch 4 Batch 3700 Loss 0.6036
# Epoch 4 Batch 3800 Loss 0.5988
# Epoch 4 Batch 3900 Loss 0.6216
# Epoch 4 Batch 4000 Loss 0.5491
# Epoch 4 Loss 0.565038
# Time taken for 1 epoch 2224.260197877884 sec
#
# Epoch 5 Batch 0 Loss 0.6641
# Epoch 5 Batch 100 Loss 0.5466
# Epoch 5 Batch 200 Loss 0.5944
# Epoch 5 Batch 300 Loss 0.4953
# Epoch 5 Batch 400 Loss 0.5454
# Epoch 5 Batch 500 Loss 0.6123
# Epoch 5 Batch 600 Loss 0.5384
# Epoch 5 Batch 700 Loss 0.5071
# Epoch 5 Batch 800 Loss 0.5652
# Epoch 5 Batch 900 Loss 0.5829
# Epoch 5 Batch 1000 Loss 0.5469
# Epoch 5 Batch 1100 Loss 0.5355
# Epoch 5 Batch 1200 Loss 0.5524
# Epoch 5 Batch 1300 Loss 0.5038
# Epoch 5 Batch 1400 Loss 0.5174
# Epoch 5 Batch 1500 Loss 0.5174
# Epoch 5 Batch 1600 Loss 0.5162
# Epoch 5 Batch 1700 Loss 0.5831
# Epoch 5 Batch 1800 Loss 0.5364
# Epoch 5 Batch 1900 Loss 0.5694
# Epoch 5 Batch 2000 Loss 0.5762
# Epoch 5 Batch 2100 Loss 0.5180
# Epoch 5 Batch 2200 Loss 0.5358
# Epoch 5 Batch 2300 Loss 0.5713
# Epoch 5 Batch 2400 Loss 0.5259
# Epoch 5 Batch 2500 Loss 0.6093
# Epoch 5 Batch 2600 Loss 0.5300
# Epoch 5 Batch 2700 Loss 0.5817
# Epoch 5 Batch 2800 Loss 0.5531
# Epoch 5 Batch 2900 Loss 0.5050
# Epoch 5 Batch 3000 Loss 0.5536
# Epoch 5 Batch 3100 Loss 0.5652
# Epoch 5 Batch 3200 Loss 0.5696
# Epoch 5 Batch 3300 Loss 0.5196
# Epoch 5 Batch 3400 Loss 0.5095
# Epoch 5 Batch 3500 Loss 0.5242
# Epoch 5 Batch 3600 Loss 0.5598
# Epoch 5 Batch 3700 Loss 0.5287
# Epoch 5 Batch 3800 Loss 0.4921
# Epoch 5 Batch 3900 Loss 0.5105
# Epoch 5 Batch 4000 Loss 0.5772
# Epoch 5 Loss 0.551614
# Time taken for 1 epoch 1288.239738225937 sec
#
# Epoch 6 Batch 0 Loss 0.5969
# Epoch 6 Batch 100 Loss 0.5330
# Epoch 6 Batch 200 Loss 0.5350
# Epoch 6 Batch 300 Loss 0.5160
# Epoch 6 Batch 400 Loss 0.5713
# Epoch 6 Batch 500 Loss 0.6120
# Epoch 6 Batch 600 Loss 0.5966
# Epoch 6 Batch 700 Loss 0.5488
# Epoch 6 Batch 800 Loss 0.5166
# Epoch 6 Batch 900 Loss 0.5099
# Epoch 6 Batch 1000 Loss 0.5141
# Epoch 6 Batch 1100 Loss 0.5523
# Epoch 6 Batch 1200 Loss 0.5392
# Epoch 6 Batch 1300 Loss 0.5209
# Epoch 6 Batch 1400 Loss 0.5208
# Epoch 6 Batch 1500 Loss 0.5539
# Epoch 6 Batch 1600 Loss 0.5248
# Epoch 6 Batch 1700 Loss 0.5793
# Epoch 6 Batch 1800 Loss 0.5050
# Epoch 6 Batch 1900 Loss 0.5557
# Epoch 6 Batch 2000 Loss 0.5432
# Epoch 6 Batch 2100 Loss 0.5913
# Epoch 6 Batch 2200 Loss 0.5717
# Epoch 6 Batch 2300 Loss 0.4855
# Epoch 6 Batch 2400 Loss 0.5708
# Epoch 6 Batch 2500 Loss 0.5458
# Epoch 6 Batch 2600 Loss 0.5451
# Epoch 6 Batch 2700 Loss 0.5622
# Epoch 6 Batch 2800 Loss 0.5007
# Epoch 6 Batch 2900 Loss 0.5738
# Epoch 6 Batch 3000 Loss 0.4787
# Epoch 6 Batch 3100 Loss 0.5620
# Epoch 6 Batch 3200 Loss 0.5288
# Epoch 6 Batch 3300 Loss 0.5267
# Epoch 6 Batch 3400 Loss 0.5375
# Epoch 6 Batch 3500 Loss 0.5219
# Epoch 6 Batch 3600 Loss 0.5240
# Epoch 6 Batch 3700 Loss 0.5547
# Epoch 6 Batch 3800 Loss 0.5654
# Epoch 6 Batch 3900 Loss 0.5648
# Epoch 6 Batch 4000 Loss 0.5191
# Epoch 6 Loss 0.540805
# Time taken for 1 epoch 1431.3902642726898 sec
#
# Epoch 7 Batch 0 Loss 0.6148
# Epoch 7 Batch 100 Loss 0.5413
# Epoch 7 Batch 200 Loss 0.5047
# Epoch 7 Batch 300 Loss 0.4979
# Epoch 7 Batch 400 Loss 0.5724
# Epoch 7 Batch 500 Loss 0.5693
# Epoch 7 Batch 600 Loss 0.5296
# Epoch 7 Batch 700 Loss 0.5090
# Epoch 7 Batch 800 Loss 0.5158
# Epoch 7 Batch 900 Loss 0.5381
# Epoch 7 Batch 1000 Loss 0.5070
# Epoch 7 Batch 1100 Loss 0.5150
# Epoch 7 Batch 1200 Loss 0.5483
# Epoch 7 Batch 1300 Loss 0.5947
# Epoch 7 Batch 1400 Loss 0.5128
# Epoch 7 Batch 1500 Loss 0.5808
# Epoch 7 Batch 1600 Loss 0.5336
# Epoch 7 Batch 1700 Loss 0.5431
# Epoch 7 Batch 1800 Loss 0.5307
# Epoch 7 Batch 1900 Loss 0.5099
# Epoch 7 Batch 2000 Loss 0.5297
# Epoch 7 Batch 2100 Loss 0.5034
# Epoch 7 Batch 2200 Loss 0.5710
# Epoch 7 Batch 2300 Loss 0.4646
# Epoch 7 Batch 2400 Loss 0.5249
# Epoch 7 Batch 2500 Loss 0.5029
# Epoch 7 Batch 2600 Loss 0.5167
# Epoch 7 Batch 2700 Loss 0.5241
# Epoch 7 Batch 2800 Loss 0.4953
# Epoch 7 Batch 2900 Loss 0.5385
# Epoch 7 Batch 3000 Loss 0.5195
# Epoch 7 Batch 3100 Loss 0.5626
# Epoch 7 Batch 3200 Loss 0.5229
# Epoch 7 Batch 3300 Loss 0.5496
# Epoch 7 Batch 3400 Loss 0.5454
# Epoch 7 Batch 3500 Loss 0.5504
# Epoch 7 Batch 3600 Loss 0.5173
# Epoch 7 Batch 3700 Loss 0.6018
# Epoch 7 Batch 3800 Loss 0.4908
# Epoch 7 Batch 3900 Loss 0.5492
# Epoch 7 Batch 4000 Loss 0.5461
# Epoch 7 Loss 0.531619
# Time taken for 1 epoch 1331.8629975318909 sec
#
# Epoch 8 Batch 0 Loss 0.5521
# Epoch 8 Batch 100 Loss 0.5908
# Epoch 8 Batch 200 Loss 0.5147
# Epoch 8 Batch 300 Loss 0.4902
# Epoch 8 Batch 400 Loss 0.4919
# Epoch 8 Batch 500 Loss 0.5398
# Epoch 8 Batch 600 Loss 0.5286
# Epoch 8 Batch 700 Loss 0.5430
# Epoch 8 Batch 800 Loss 0.5746
# Epoch 8 Batch 900 Loss 0.4978
# Epoch 8 Batch 1000 Loss 0.5377
# Epoch 8 Batch 1100 Loss 0.6134
# Epoch 8 Batch 1200 Loss 0.5790
# Epoch 8 Batch 1300 Loss 0.5027
# Epoch 8 Batch 1400 Loss 0.5150
# Epoch 8 Batch 1500 Loss 0.4890
# Epoch 8 Batch 1600 Loss 0.5331
# Epoch 8 Batch 1700 Loss 0.5178
# Epoch 8 Batch 1800 Loss 0.4710
# Epoch 8 Batch 1900 Loss 0.5843
# Epoch 8 Batch 2000 Loss 0.5189
# Epoch 8 Batch 2100 Loss 0.5160
# Epoch 8 Batch 2200 Loss 0.5963
# Epoch 8 Batch 2300 Loss 0.4833
# Epoch 8 Batch 2400 Loss 0.4784
# Epoch 8 Batch 2500 Loss 0.5604
# Epoch 8 Batch 2600 Loss 0.5340
# Epoch 8 Batch 2700 Loss 0.4881
# Epoch 8 Batch 2800 Loss 0.4817
# Epoch 8 Batch 2900 Loss 0.5379
# Epoch 8 Batch 3000 Loss 0.5704
# Epoch 8 Batch 3100 Loss 0.4784
# Epoch 8 Batch 3200 Loss 0.6307
# Epoch 8 Batch 3300 Loss 0.5074
# Epoch 8 Batch 3400 Loss 0.4892
# Epoch 8 Batch 3500 Loss 0.5479
# Epoch 8 Batch 3600 Loss 0.4875
# Epoch 8 Batch 3700 Loss 0.5196
# Epoch 8 Batch 3800 Loss 0.4845
# Epoch 8 Batch 3900 Loss 0.5288
# Epoch 8 Batch 4000 Loss 0.5390
# Epoch 8 Loss 0.522187
# Time taken for 1 epoch 2312.3494744300842 sec
#
# Epoch 9 Batch 0 Loss 0.4918
# Epoch 9 Batch 100 Loss 0.5244
# Epoch 9 Batch 200 Loss 0.5096
# Epoch 9 Batch 300 Loss 0.5613
# Epoch 9 Batch 400 Loss 0.5148
# Epoch 9 Batch 500 Loss 0.5240
# Epoch 9 Batch 600 Loss 0.5725
# Epoch 9 Batch 700 Loss 0.4855
# Epoch 9 Batch 800 Loss 0.5035
# Epoch 9 Batch 900 Loss 0.5467
# Epoch 9 Batch 1000 Loss 0.5275
# Epoch 9 Batch 1100 Loss 0.5220
# Epoch 9 Batch 1200 Loss 0.5631
# Epoch 9 Batch 1300 Loss 0.5343
# Epoch 9 Batch 1400 Loss 0.4928
# Epoch 9 Batch 1500 Loss 0.5132
# Epoch 9 Batch 1600 Loss 0.4715
# Epoch 9 Batch 1700 Loss 0.4965
# Epoch 9 Batch 1800 Loss 0.5279
# Epoch 9 Batch 1900 Loss 0.5376
# Epoch 9 Batch 2000 Loss 0.5569
# Epoch 9 Batch 2100 Loss 0.5001
# Epoch 9 Batch 2200 Loss 0.5623
# Epoch 9 Batch 2300 Loss 0.4950
# Epoch 9 Batch 2400 Loss 0.4692
# Epoch 9 Batch 2500 Loss 0.5597
# Epoch 9 Batch 2600 Loss 0.5558
# Epoch 9 Batch 2700 Loss 0.4837
# Epoch 9 Batch 2800 Loss 0.5076
# Epoch 9 Batch 2900 Loss 0.5440
# Epoch 9 Batch 3000 Loss 0.4670
# Epoch 9 Batch 3100 Loss 0.4566
# Epoch 9 Batch 3200 Loss 0.5276
# Epoch 9 Batch 3300 Loss 0.4996
# Epoch 9 Batch 3400 Loss 0.5308
# Epoch 9 Batch 3500 Loss 0.5062
# Epoch 9 Batch 3600 Loss 0.4781
# Epoch 9 Batch 3700 Loss 0.5229
# Epoch 9 Batch 3800 Loss 0.5120
# Epoch 9 Batch 3900 Loss 0.5090
# Epoch 9 Batch 4000 Loss 0.5230
# Epoch 9 Loss 0.514590
# Time taken for 1 epoch 1531.8651661872864 sec
#
# Epoch 10 Batch 0 Loss 0.5268
# Epoch 10 Batch 100 Loss 0.5561
# Epoch 10 Batch 200 Loss 0.5101
# Epoch 10 Batch 300 Loss 0.5133
# Epoch 10 Batch 400 Loss 0.5138
# Epoch 10 Batch 500 Loss 0.5179
# Epoch 10 Batch 600 Loss 0.5043
# Epoch 10 Batch 700 Loss 0.4847
# Epoch 10 Batch 800 Loss 0.5061
# Epoch 10 Batch 900 Loss 0.5279
# Epoch 10 Batch 1000 Loss 0.5708
# Epoch 10 Batch 1100 Loss 0.4706
# Epoch 10 Batch 1200 Loss 0.5358
# Epoch 10 Batch 1300 Loss 0.5554
# Epoch 10 Batch 1400 Loss 0.4936
# Epoch 10 Batch 1500 Loss 0.4927
# Epoch 10 Batch 1600 Loss 0.5259
# Epoch 10 Batch 1700 Loss 0.4770
# Epoch 10 Batch 1800 Loss 0.5011
# Epoch 10 Batch 1900 Loss 0.5401
# Epoch 10 Batch 2000 Loss 0.4946
# Epoch 10 Batch 2100 Loss 0.5144
# Epoch 10 Batch 2200 Loss 0.4593
# Epoch 10 Batch 2300 Loss 0.4863
# Epoch 10 Batch 2400 Loss 0.4771
# Epoch 10 Batch 2500 Loss 0.5022
# Epoch 10 Batch 2600 Loss 0.4831
# Epoch 10 Batch 2700 Loss 0.5057
# Epoch 10 Batch 2800 Loss 0.5063
# Epoch 10 Batch 2900 Loss 0.5159
# Epoch 10 Batch 3000 Loss 0.4627
# Epoch 10 Batch 3100 Loss 0.5224
# Epoch 10 Batch 3200 Loss 0.5378
# Epoch 10 Batch 3300 Loss 0.5432
# Epoch 10 Batch 3400 Loss 0.4510
# Epoch 10 Batch 3500 Loss 0.5336
# Epoch 10 Batch 3600 Loss 0.4774
# Epoch 10 Batch 3700 Loss 0.5458
# Epoch 10 Batch 3800 Loss 0.5116
# Epoch 10 Batch 3900 Loss 0.5311
# Epoch 10 Batch 4000 Loss 0.4981
# Epoch 10 Loss 0.507584
# Time taken for 1 epoch 1367.7347521781921 sec
#
# Epoch 11 Batch 0 Loss 0.5356
# Epoch 11 Batch 100 Loss 0.4511
# Epoch 11 Batch 200 Loss 0.4903
# Epoch 11 Batch 300 Loss 0.5037
# Epoch 11 Batch 400 Loss 0.4983
# Epoch 11 Batch 500 Loss 0.5234
# Epoch 11 Batch 600 Loss 0.5428
# Epoch 11 Batch 700 Loss 0.5498
# Epoch 11 Batch 800 Loss 0.4890
# Epoch 11 Batch 900 Loss 0.5247
# Epoch 11 Batch 1000 Loss 0.5171
# Epoch 11 Batch 1100 Loss 0.4996
# Epoch 11 Batch 1200 Loss 0.5124
# Epoch 11 Batch 1300 Loss 0.5267
# Epoch 11 Batch 1400 Loss 0.4846
# Epoch 11 Batch 1500 Loss 0.5161
# Epoch 11 Batch 1600 Loss 0.5541
# Epoch 11 Batch 1700 Loss 0.4735
# Epoch 11 Batch 1800 Loss 0.4782
# Epoch 11 Batch 1900 Loss 0.5069
# Epoch 11 Batch 2000 Loss 0.5308
# Epoch 11 Batch 2100 Loss 0.4997
# Epoch 11 Batch 2200 Loss 0.5445
# Epoch 11 Batch 2300 Loss 0.4983
# Epoch 11 Batch 2400 Loss 0.5081
# Epoch 11 Batch 2500 Loss 0.5672
# Epoch 11 Batch 2600 Loss 0.4692
# Epoch 11 Batch 2700 Loss 0.4716
# Epoch 11 Batch 2800 Loss 0.4813
# Epoch 11 Batch 2900 Loss 0.5203
# Epoch 11 Batch 3000 Loss 0.4936
# Epoch 11 Batch 3100 Loss 0.4866
# Epoch 11 Batch 3200 Loss 0.5073
# Epoch 11 Batch 3300 Loss 0.4643
# Epoch 11 Batch 3400 Loss 0.5039
# Epoch 11 Batch 3500 Loss 0.4366
# Epoch 11 Batch 3600 Loss 0.4880
# Epoch 11 Batch 3700 Loss 0.4921
# Epoch 11 Batch 3800 Loss 0.5144
# Epoch 11 Batch 3900 Loss 0.5321
# Epoch 11 Batch 4000 Loss 0.4821
# Epoch 11 Loss 0.501411
# Time taken for 1 epoch 2298.2275772094727 sec
#
# Epoch 12 Batch 0 Loss 0.5146
# Epoch 12 Batch 100 Loss 0.4770
# Epoch 12 Batch 200 Loss 0.4423
# Epoch 12 Batch 300 Loss 0.5070
# Epoch 12 Batch 400 Loss 0.5020
# Epoch 12 Batch 500 Loss 0.5247
# Epoch 12 Batch 600 Loss 0.4519
# Epoch 12 Batch 700 Loss 0.5041
# Epoch 12 Batch 800 Loss 0.4820
# Epoch 12 Batch 900 Loss 0.5113
# Epoch 12 Batch 1000 Loss 0.4649
# Epoch 12 Batch 1100 Loss 0.4566
# Epoch 12 Batch 1200 Loss 0.4650
# Epoch 12 Batch 1300 Loss 0.4482
# Epoch 12 Batch 1400 Loss 0.5062
# Epoch 12 Batch 1500 Loss 0.4855
# Epoch 12 Batch 1600 Loss 0.5145
# Epoch 12 Batch 1700 Loss 0.5379
# Epoch 12 Batch 1800 Loss 0.4830
# Epoch 12 Batch 1900 Loss 0.5044
# Epoch 12 Batch 2000 Loss 0.5076
# Epoch 12 Batch 2100 Loss 0.5444
# Epoch 12 Batch 2200 Loss 0.5273
# Epoch 12 Batch 2300 Loss 0.5195
# Epoch 12 Batch 2400 Loss 0.4839
# Epoch 12 Batch 2500 Loss 0.4712
# Epoch 12 Batch 2600 Loss 0.4826
# Epoch 12 Batch 2700 Loss 0.4657
# Epoch 12 Batch 2800 Loss 0.4767
# Epoch 12 Batch 2900 Loss 0.5136
# Epoch 12 Batch 3000 Loss 0.4885
# Epoch 12 Batch 3100 Loss 0.4824
# Epoch 12 Batch 3200 Loss 0.4734
# Epoch 12 Batch 3300 Loss 0.4980
# Epoch 12 Batch 3400 Loss 0.5498
# Epoch 12 Batch 3500 Loss 0.4902
# Epoch 12 Batch 3600 Loss 0.5269
# Epoch 12 Batch 3700 Loss 0.5273
# Epoch 12 Batch 3800 Loss 0.4792
# Epoch 12 Batch 3900 Loss 0.5179
# Epoch 12 Batch 4000 Loss 0.4730
# Epoch 12 Loss 0.495597
# Time taken for 1 epoch 1439.389170885086 sec
#
# Epoch 13 Batch 0 Loss 0.5350
# Epoch 13 Batch 100 Loss 0.4921
# Epoch 13 Batch 200 Loss 0.4879
# Epoch 13 Batch 300 Loss 0.4897
# Epoch 13 Batch 400 Loss 0.5350
# Epoch 13 Batch 500 Loss 0.5377
# Epoch 13 Batch 600 Loss 0.5105
# Epoch 13 Batch 700 Loss 0.4931
# Epoch 13 Batch 800 Loss 0.4575
# Epoch 13 Batch 900 Loss 0.4749
# Epoch 13 Batch 1000 Loss 0.4867
# Epoch 13 Batch 1100 Loss 0.5266
# Epoch 13 Batch 1200 Loss 0.4703
# Epoch 13 Batch 1300 Loss 0.5004
# Epoch 13 Batch 1400 Loss 0.4619
# Epoch 13 Batch 1500 Loss 0.4476
# Epoch 13 Batch 1600 Loss 0.4811
# Epoch 13 Batch 1700 Loss 0.5183
# Epoch 13 Batch 1800 Loss 0.4805
# Epoch 13 Batch 1900 Loss 0.4576
# Epoch 13 Batch 2000 Loss 0.5107
# Epoch 13 Batch 2100 Loss 0.5010
# Epoch 13 Batch 2200 Loss 0.4589
# Epoch 13 Batch 2300 Loss 0.5037
# Epoch 13 Batch 2400 Loss 0.4846
# Epoch 13 Batch 2500 Loss 0.5350
# Epoch 13 Batch 2600 Loss 0.4694
# Epoch 13 Batch 2700 Loss 0.4511
# Epoch 13 Batch 2800 Loss 0.5034
# Epoch 13 Batch 2900 Loss 0.5529
# Epoch 13 Batch 3000 Loss 0.4415
# Epoch 13 Batch 3100 Loss 0.4751
# Epoch 13 Batch 3200 Loss 0.4505
# Epoch 13 Batch 3300 Loss 0.5075
# Epoch 13 Batch 3400 Loss 0.4452
# Epoch 13 Batch 3500 Loss 0.4477
# Epoch 13 Batch 3600 Loss 0.4477
# Epoch 13 Batch 3700 Loss 0.4759
# Epoch 13 Batch 3800 Loss 0.4606
# Epoch 13 Batch 3900 Loss 0.4867
# Epoch 13 Batch 4000 Loss 0.4796
# Epoch 13 Loss 0.490367
# Time taken for 1 epoch 2038.8290374279022 sec
#
# Epoch 14 Batch 0 Loss 0.4986
# Epoch 14 Batch 100 Loss 0.4701
# Epoch 14 Batch 200 Loss 0.4831
# Epoch 14 Batch 300 Loss 0.5608
# Epoch 14 Batch 400 Loss 0.5126
# Epoch 14 Batch 500 Loss 0.5055
# Epoch 14 Batch 600 Loss 0.4821
# Epoch 14 Batch 700 Loss 0.4616
# Epoch 14 Batch 800 Loss 0.4755
# Epoch 14 Batch 900 Loss 0.4759
# Epoch 14 Batch 1000 Loss 0.4683
# Epoch 14 Batch 1100 Loss 0.5072
# Epoch 14 Batch 1200 Loss 0.4601
# Epoch 14 Batch 1300 Loss 0.5011
# Epoch 14 Batch 1400 Loss 0.4753
# Epoch 14 Batch 1500 Loss 0.4929
# Epoch 14 Batch 1600 Loss 0.4685
# Epoch 14 Batch 1700 Loss 0.4654
# Epoch 14 Batch 1800 Loss 0.4192
# Epoch 14 Batch 1900 Loss 0.4817
# Epoch 14 Batch 2000 Loss 0.4928
# Epoch 14 Batch 2100 Loss 0.4910
# Epoch 14 Batch 2200 Loss 0.5030
# Epoch 14 Batch 2300 Loss 0.4955
# Epoch 14 Batch 2400 Loss 0.5130
# Epoch 14 Batch 2500 Loss 0.5164
# Epoch 14 Batch 2600 Loss 0.4556
# Epoch 14 Batch 2700 Loss 0.4712
# Epoch 14 Batch 2800 Loss 0.4978
# Epoch 14 Batch 2900 Loss 0.5144
# Epoch 14 Batch 3000 Loss 0.4492
# Epoch 14 Batch 3100 Loss 0.4876
# Epoch 14 Batch 3200 Loss 0.4920
# Epoch 14 Batch 3300 Loss 0.4723
# Epoch 14 Batch 3400 Loss 0.4713
# Epoch 14 Batch 3500 Loss 0.4426
# Epoch 14 Batch 3600 Loss 0.4268
# Epoch 14 Batch 3700 Loss 0.5219
# Epoch 14 Batch 3800 Loss 0.4825
# Epoch 14 Batch 3900 Loss 0.4526
# Epoch 14 Batch 4000 Loss 0.5428
# Epoch 14 Loss 0.485534
# Time taken for 1 epoch 1845.306767463684 sec
#
# Epoch 15 Batch 0 Loss 0.4882
# Epoch 15 Batch 100 Loss 0.5322
# Epoch 15 Batch 200 Loss 0.4695
# Epoch 15 Batch 300 Loss 0.5180
# Epoch 15 Batch 400 Loss 0.5118
# Epoch 15 Batch 500 Loss 0.4589
# Epoch 15 Batch 600 Loss 0.4971
# Epoch 15 Batch 700 Loss 0.4749
# Epoch 15 Batch 800 Loss 0.4857
# Epoch 15 Batch 900 Loss 0.4459
# Epoch 15 Batch 1000 Loss 0.4283
# Epoch 15 Batch 1100 Loss 0.5301
# Epoch 15 Batch 1200 Loss 0.4977
# Epoch 15 Batch 1300 Loss 0.4931
# Epoch 15 Batch 1400 Loss 0.4878
# Epoch 15 Batch 1500 Loss 0.5495
# Epoch 15 Batch 1600 Loss 0.4724
# Epoch 15 Batch 1700 Loss 0.4978
# Epoch 15 Batch 1800 Loss 0.4591
# Epoch 15 Batch 1900 Loss 0.4840
# Epoch 15 Batch 2000 Loss 0.4889
# Epoch 15 Batch 2100 Loss 0.4597
# Epoch 15 Batch 2200 Loss 0.4976
# Epoch 15 Batch 2300 Loss 0.4690
# Epoch 15 Batch 2400 Loss 0.4742
# Epoch 15 Batch 2500 Loss 0.5240
# Epoch 15 Batch 2600 Loss 0.4727
# Epoch 15 Batch 2700 Loss 0.4443
# Epoch 15 Batch 2800 Loss 0.4742
# Epoch 15 Batch 2900 Loss 0.4705
# Epoch 15 Batch 3000 Loss 0.4619
# Epoch 15 Batch 3100 Loss 0.4626
# Epoch 15 Batch 3200 Loss 0.5038
# Epoch 15 Batch 3300 Loss 0.4217
# Epoch 15 Batch 3400 Loss 0.4756
# Epoch 15 Batch 3500 Loss 0.4562
# Epoch 15 Batch 3600 Loss 0.4715
# Epoch 15 Batch 3700 Loss 0.4654
# Epoch 15 Batch 3800 Loss 0.4813
# Epoch 15 Batch 3900 Loss 0.4901
# Epoch 15 Batch 4000 Loss 0.5398
# Epoch 15 Loss 0.481445
# Time taken for 1 epoch 1367.4708256721497 sec
#
# Epoch 16 Batch 0 Loss 0.4941
# Epoch 16 Batch 100 Loss 0.4639
# Epoch 16 Batch 200 Loss 0.4706
# Epoch 16 Batch 300 Loss 0.4465
# Epoch 16 Batch 400 Loss 0.4738
# Epoch 16 Batch 500 Loss 0.5061
# Epoch 16 Batch 600 Loss 0.4587
# Epoch 16 Batch 700 Loss 0.4574
# Epoch 16 Batch 800 Loss 0.4673
# Epoch 16 Batch 900 Loss 0.4863
# Epoch 16 Batch 1000 Loss 0.4792
# Epoch 16 Batch 1100 Loss 0.4670
# Epoch 16 Batch 1200 Loss 0.4886
# Epoch 16 Batch 1300 Loss 0.4236
# Epoch 16 Batch 1400 Loss 0.4748
# Epoch 16 Batch 1500 Loss 0.4825
# Epoch 16 Batch 1600 Loss 0.5134
# Epoch 16 Batch 1700 Loss 0.5028
# Epoch 16 Batch 1800 Loss 0.4671
# Epoch 16 Batch 1900 Loss 0.4937
# Epoch 16 Batch 2000 Loss 0.4827
# Epoch 16 Batch 2100 Loss 0.4955
# Epoch 16 Batch 2200 Loss 0.4617
# Epoch 16 Batch 2300 Loss 0.4826
# Epoch 16 Batch 2400 Loss 0.4887
# Epoch 16 Batch 2500 Loss 0.4798
# Epoch 16 Batch 2600 Loss 0.4631
# Epoch 16 Batch 2700 Loss 0.5318
# Epoch 16 Batch 2800 Loss 0.4639
# Epoch 16 Batch 2900 Loss 0.4855
# Epoch 16 Batch 3000 Loss 0.4779
# Epoch 16 Batch 3100 Loss 0.5081
# Epoch 16 Batch 3200 Loss 0.5361
# Epoch 16 Batch 3300 Loss 0.5100
# Epoch 16 Batch 3400 Loss 0.4745
# Epoch 16 Batch 3500 Loss 0.4693
# Epoch 16 Batch 3600 Loss 0.4738
# Epoch 16 Batch 3700 Loss 0.5073
# Epoch 16 Batch 3800 Loss 0.5085
# Epoch 16 Batch 3900 Loss 0.4828
# Epoch 16 Batch 4000 Loss 0.4571
# Epoch 16 Loss 0.476915
# Time taken for 1 epoch 3086.1882271766663 sec
#
# Epoch 17 Batch 0 Loss 0.5048
# Epoch 17 Batch 100 Loss 0.4299
# Epoch 17 Batch 200 Loss 0.4542
# Epoch 17 Batch 300 Loss 0.5207
# Epoch 17 Batch 400 Loss 0.4720
# Epoch 17 Batch 500 Loss 0.4866
# Epoch 17 Batch 600 Loss 0.4776
# Epoch 17 Batch 700 Loss 0.4351
# Epoch 17 Batch 800 Loss 0.5149
# Epoch 17 Batch 900 Loss 0.5117
# Epoch 17 Batch 1000 Loss 0.4738
# Epoch 17 Batch 1100 Loss 0.4876
# Epoch 17 Batch 1200 Loss 0.4834
# Epoch 17 Batch 1300 Loss 0.4722
# Epoch 17 Batch 1400 Loss 0.5000
# Epoch 17 Batch 1500 Loss 0.4206
# Epoch 17 Batch 1600 Loss 0.4477
# Epoch 17 Batch 1700 Loss 0.4770
# Epoch 17 Batch 1800 Loss 0.4873
# Epoch 17 Batch 1900 Loss 0.4493
# Epoch 17 Batch 2000 Loss 0.5183
# Epoch 17 Batch 2100 Loss 0.4690
# Epoch 17 Batch 2200 Loss 0.4645
# Epoch 17 Batch 2300 Loss 0.5043
# Epoch 17 Batch 2400 Loss 0.4525
# Epoch 17 Batch 2500 Loss 0.5029
# Epoch 17 Batch 2600 Loss 0.4473
# Epoch 17 Batch 2700 Loss 0.4372
# Epoch 17 Batch 2800 Loss 0.4992
# Epoch 17 Batch 2900 Loss 0.4161
# Epoch 17 Batch 3000 Loss 0.4635
# Epoch 17 Batch 3100 Loss 0.5015
# Epoch 17 Batch 3200 Loss 0.4902
# Epoch 17 Batch 3300 Loss 0.4618
# Epoch 17 Batch 3400 Loss 0.4905
# Epoch 17 Batch 3500 Loss 0.4661
# Epoch 17 Batch 3600 Loss 0.4893
# Epoch 17 Batch 3700 Loss 0.4930
# Epoch 17 Batch 3800 Loss 0.4679
# Epoch 17 Batch 3900 Loss 0.5011
# Epoch 17 Batch 4000 Loss 0.4862
# Epoch 17 Loss 0.474072
# Time taken for 1 epoch 1424.0320925712585 sec
#
# Epoch 18 Batch 0 Loss 0.4662
# Epoch 18 Batch 100 Loss 0.4753
# Epoch 18 Batch 200 Loss 0.5013
# Epoch 18 Batch 300 Loss 0.4890
# Epoch 18 Batch 400 Loss 0.4178
# Epoch 18 Batch 500 Loss 0.4538
# Epoch 18 Batch 600 Loss 0.4556
# Epoch 18 Batch 700 Loss 0.4283
# Epoch 18 Batch 800 Loss 0.4667
# Epoch 18 Batch 900 Loss 0.4434
# Epoch 18 Batch 1000 Loss 0.4649
# Epoch 18 Batch 1100 Loss 0.4966
# Epoch 18 Batch 1200 Loss 0.4768
# Epoch 18 Batch 1300 Loss 0.4788
# Epoch 18 Batch 1400 Loss 0.5309
# Epoch 18 Batch 1500 Loss 0.4203
# Epoch 18 Batch 1600 Loss 0.4945
# Epoch 18 Batch 1700 Loss 0.4726
# Epoch 18 Batch 1800 Loss 0.4719
# Epoch 18 Batch 1900 Loss 0.5032
# Epoch 18 Batch 2000 Loss 0.4719
# Epoch 18 Batch 2100 Loss 0.4502
# Epoch 18 Batch 2200 Loss 0.5097
# Epoch 18 Batch 2300 Loss 0.4934
# Epoch 18 Batch 2400 Loss 0.4069
# Epoch 18 Batch 2500 Loss 0.4691
# Epoch 18 Batch 2600 Loss 0.4683
# Epoch 18 Batch 2700 Loss 0.4815
# Epoch 18 Batch 2800 Loss 0.5495
# Epoch 18 Batch 2900 Loss 0.4502
# Epoch 18 Batch 3000 Loss 0.4304
# Epoch 18 Batch 3100 Loss 0.4421
# Epoch 18 Batch 3200 Loss 0.4505
# Epoch 18 Batch 3300 Loss 0.5091
# Epoch 18 Batch 3400 Loss 0.4505
# Epoch 18 Batch 3500 Loss 0.4629
# Epoch 18 Batch 3600 Loss 0.4437
# Epoch 18 Batch 3700 Loss 0.4620
# Epoch 18 Batch 3800 Loss 0.4744
# Epoch 18 Batch 3900 Loss 0.4519
# Epoch 18 Batch 4000 Loss 0.4774
# Epoch 18 Loss 0.470417
# Time taken for 1 epoch 1376.5583848953247 sec
#
# Epoch 19 Batch 0 Loss 0.5162
# Epoch 19 Batch 100 Loss 0.5060
# Epoch 19 Batch 200 Loss 0.4232
# Epoch 19 Batch 300 Loss 0.4142
# Epoch 19 Batch 400 Loss 0.4621
# Epoch 19 Batch 500 Loss 0.4559
# Epoch 19 Batch 600 Loss 0.4855
# Epoch 19 Batch 700 Loss 0.4226
# Epoch 19 Batch 800 Loss 0.5201
# Epoch 19 Batch 900 Loss 0.4359
# Epoch 19 Batch 1000 Loss 0.4771
# Epoch 19 Batch 1100 Loss 0.4500
# Epoch 19 Batch 1200 Loss 0.4239
# Epoch 19 Batch 1300 Loss 0.4197
# Epoch 19 Batch 1400 Loss 0.4500
# Epoch 19 Batch 1500 Loss 0.4498
# Epoch 19 Batch 1600 Loss 0.4462
# Epoch 19 Batch 1700 Loss 0.4930
# Epoch 19 Batch 1800 Loss 0.4558
# Epoch 19 Batch 1900 Loss 0.4839
# Epoch 19 Batch 2000 Loss 0.4469
# Epoch 19 Batch 2100 Loss 0.4616
# Epoch 19 Batch 2200 Loss 0.4764
# Epoch 19 Batch 2300 Loss 0.4964
# Epoch 19 Batch 2400 Loss 0.4070
# Epoch 19 Batch 2500 Loss 0.4204
# Epoch 19 Batch 2600 Loss 0.4632
# Epoch 19 Batch 2700 Loss 0.5248
# Epoch 19 Batch 2800 Loss 0.4916
# Epoch 19 Batch 2900 Loss 0.4673
# Epoch 19 Batch 3000 Loss 0.4731
# Epoch 19 Batch 3100 Loss 0.4522
# Epoch 19 Batch 3200 Loss 0.5066
# Epoch 19 Batch 3300 Loss 0.4694
# Epoch 19 Batch 3400 Loss 0.4988
# Epoch 19 Batch 3500 Loss 0.4744
# Epoch 19 Batch 3600 Loss 0.4428
# Epoch 19 Batch 3700 Loss 0.4797
# Epoch 19 Batch 3800 Loss 0.4549
# Epoch 19 Batch 3900 Loss 0.4143
# Epoch 19 Batch 4000 Loss 0.4555
# Epoch 19 Loss 0.467000
# Time taken for 1 epoch 1392.6776373386383 sec
#
# Epoch 20 Batch 0 Loss 0.4975
# Epoch 20 Batch 100 Loss 0.5077
# Epoch 20 Batch 200 Loss 0.5024
# Epoch 20 Batch 300 Loss 0.4967
# Epoch 20 Batch 400 Loss 0.5489
# Epoch 20 Batch 500 Loss 0.4718
# Epoch 20 Batch 600 Loss 0.4707
# Epoch 20 Batch 700 Loss 0.4358
# Epoch 20 Batch 800 Loss 0.5031
# Epoch 20 Batch 900 Loss 0.4649
# Epoch 20 Batch 1000 Loss 0.4480
# Epoch 20 Batch 1100 Loss 0.5027
# Epoch 20 Batch 1200 Loss 0.4285
# Epoch 20 Batch 1300 Loss 0.4688
# Epoch 20 Batch 1400 Loss 0.4970
# Epoch 20 Batch 1500 Loss 0.4664
# Epoch 20 Batch 1600 Loss 0.4616
# Epoch 20 Batch 1700 Loss 0.4658
# Epoch 20 Batch 1800 Loss 0.5205
# Epoch 20 Batch 1900 Loss 0.4011
# Epoch 20 Batch 2000 Loss 0.4547
# Epoch 20 Batch 2100 Loss 0.4861
# Epoch 20 Batch 2200 Loss 0.4475
# Epoch 20 Batch 2300 Loss 0.4681
# Epoch 20 Batch 2400 Loss 0.4317
# Epoch 20 Batch 2500 Loss 0.5061
# Epoch 20 Batch 2600 Loss 0.4834
# Epoch 20 Batch 2700 Loss 0.5034
# Epoch 20 Batch 2800 Loss 0.4858
# Epoch 20 Batch 2900 Loss 0.4560
# Epoch 20 Batch 3000 Loss 0.4644
# Epoch 20 Batch 3100 Loss 0.4610
# Epoch 20 Batch 3200 Loss 0.4489
# Epoch 20 Batch 3300 Loss 0.4299
# Epoch 20 Batch 3400 Loss 0.4603
# Epoch 20 Batch 3500 Loss 0.4581
# Epoch 20 Batch 3600 Loss 0.4191
# Epoch 20 Batch 3700 Loss 0.4597
# Epoch 20 Batch 3800 Loss 0.4401
# Epoch 20 Batch 3900 Loss 0.4182
# Epoch 20 Batch 4000 Loss 0.4498
# Epoch 20 Loss 0.465677
# Time taken for 1 epoch 1352.5695395469666 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (7, 7))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print ('Real Caption:', real_caption)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a city street with multiple buildings and people walking on the sidewalks <end>
# Prediction Caption: stop pedestrians stop signs hang over <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a man riding a surfboard riding a wave on his surf board rides a wave on a brown wet suit with makeup is on a large breaking wave in a body of water with his feet of an ocean wave <end>
# <ipython-input-34-7869991c3d36>:14: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x285F5C8CAF0>
