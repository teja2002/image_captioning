# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections #for storing different types of tuples and dictionares
import random  #random initialization
import re  # Regular expressions are text matching patterns described with a formal syntax
import numpy as np 
import os  #allows you to interface with the underlying operating system that Python is running on. 
import time #time dependent tasks
import json #load json files
from glob import glob #listing files under a specified folder
from PIL import Image #image manipulation
import pickle #serialize python objects

# %%
# Download caption annotation files
annotation_folder = '/annotation/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
    annotation_zip = tf.keras.utils.get_file('captions.zip',
                                             cache_subdir=os.path.abspath('.'),
                                             origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                             extract = True)
    annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
    os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
    image_zip = tf.keras.utils.get_file('train2014.zip',
                                        cache_subdir=os.path.abspath('.'),
                                        origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                        extract = True)
    PATH = os.path.dirname(image_zip) + image_folder
    os.remove(image_zip)
else:
    PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 41s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    caption = f"<start> {val['caption']} <end>"
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths[:64000]
print(len(train_image_paths))
# Out:
# 64000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    train_captions.extend(caption_list)
    img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A woman holds a monkey made from balloons. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x25D74E60AC0>

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (224, 224))
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.resnet50.ResNet50(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in image_dataset:
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                                (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
    capt_len = len(img_to_cap_vector[imgt])
    img_name_train.extend([imgt] * capt_len)
    cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
    capv_len = len(img_to_cap_vector[imgv])
    img_name_val.extend([imgv] * capv_len)
    cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (256115, 256115, 64033, 64033)

# %%
# hyper parameters

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from VGG16 is (64, 2048)
# These two variables represent that vector shape
features_shape = 512
attention_features_shape = 49

# %%
# Load the numpy files
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

        # hidden shape == (batch_size, hidden_size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        # attention_hidden_layer shape == (batch_size, 64, units)
        attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                             self.W2(hidden_with_time_axis)))

        # score shape == (batch_size, 64, 1)
        # This gives you an unnormalized score for each image feature.
        score = self.V(attention_hidden_layer)

        # attention_weights shape == (batch_size, 64, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it using pickle
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

        # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

        # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/resnet_1"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # restoring the latest checkpoint in checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

              # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.9247
# Epoch 1 Batch 100 Loss 1.0364
# Epoch 1 Batch 200 Loss 0.8245
# Epoch 1 Batch 300 Loss 0.7970
# Epoch 1 Batch 400 Loss 0.8856
# Epoch 1 Batch 500 Loss 0.7268
# Epoch 1 Batch 600 Loss 0.7495
# Epoch 1 Batch 700 Loss 0.7297
# Epoch 1 Batch 800 Loss 0.6911
# Epoch 1 Batch 900 Loss 0.7526
# Epoch 1 Batch 1000 Loss 0.6834
# Epoch 1 Batch 1100 Loss 0.6962
# Epoch 1 Batch 1200 Loss 0.6637
# Epoch 1 Batch 1300 Loss 0.6589
# Epoch 1 Batch 1400 Loss 0.6680
# Epoch 1 Batch 1500 Loss 0.6172
# Epoch 1 Batch 1600 Loss 0.7176
# Epoch 1 Batch 1700 Loss 0.6406
# Epoch 1 Batch 1800 Loss 0.5829
# Epoch 1 Batch 1900 Loss 0.6818
# Epoch 1 Batch 2000 Loss 0.6805
# Epoch 1 Batch 2100 Loss 0.6184
# Epoch 1 Batch 2200 Loss 0.6925
# Epoch 1 Batch 2300 Loss 0.6251
# Epoch 1 Batch 2400 Loss 0.6784
# Epoch 1 Batch 2500 Loss 0.6479
# Epoch 1 Batch 2600 Loss 0.5937
# Epoch 1 Batch 2700 Loss 0.6503
# Epoch 1 Batch 2800 Loss 0.6623
# Epoch 1 Batch 2900 Loss 0.6560
# Epoch 1 Batch 3000 Loss 0.6637
# Epoch 1 Batch 3100 Loss 0.6489
# Epoch 1 Batch 3200 Loss 0.5967
# Epoch 1 Batch 3300 Loss 0.6736
# Epoch 1 Batch 3400 Loss 0.6656
# Epoch 1 Batch 3500 Loss 0.6228
# Epoch 1 Batch 3600 Loss 0.6887
# Epoch 1 Batch 3700 Loss 0.6330
# Epoch 1 Batch 3800 Loss 0.6481
# Epoch 1 Batch 3900 Loss 0.5297
# Epoch 1 Batch 4000 Loss 0.6314
# Epoch 1 Loss 0.686905
# Time taken for 1 epoch 2276.178126811981 sec
#
# Epoch 2 Batch 0 Loss 0.6309
# Epoch 2 Batch 100 Loss 0.6501
# Epoch 2 Batch 200 Loss 0.5808
# Epoch 2 Batch 300 Loss 0.5815
# Epoch 2 Batch 400 Loss 0.5846
# Epoch 2 Batch 500 Loss 0.7092
# Epoch 2 Batch 600 Loss 0.6446
# Epoch 2 Batch 700 Loss 0.6321
# Epoch 2 Batch 800 Loss 0.5787
# Epoch 2 Batch 900 Loss 0.5727
# Epoch 2 Batch 1000 Loss 0.5792
# Epoch 2 Batch 1100 Loss 0.5778
# Epoch 2 Batch 1200 Loss 0.6125
# Epoch 2 Batch 1300 Loss 0.6350
# Epoch 2 Batch 1400 Loss 0.5649
# Epoch 2 Batch 1500 Loss 0.5765
# Epoch 2 Batch 1600 Loss 0.5741
# Epoch 2 Batch 1700 Loss 0.5687
# Epoch 2 Batch 1800 Loss 0.5699
# Epoch 2 Batch 1900 Loss 0.5660
# Epoch 2 Batch 2000 Loss 0.6259
# Epoch 2 Batch 2100 Loss 0.5636
# Epoch 2 Batch 2200 Loss 0.5301
# Epoch 2 Batch 2300 Loss 0.5394
# Epoch 2 Batch 2400 Loss 0.5934
# Epoch 2 Batch 2500 Loss 0.5304
# Epoch 2 Batch 2600 Loss 0.5775
# Epoch 2 Batch 2700 Loss 0.5703
# Epoch 2 Batch 2800 Loss 0.5939
# Epoch 2 Batch 2900 Loss 0.6137
# Epoch 2 Batch 3000 Loss 0.6444
# Epoch 2 Batch 3100 Loss 0.6037
# Epoch 2 Batch 3200 Loss 0.5613
# Epoch 2 Batch 3300 Loss 0.6021
# Epoch 2 Batch 3400 Loss 0.5481
# Epoch 2 Batch 3500 Loss 0.5558
# Epoch 2 Batch 3600 Loss 0.5946
# Epoch 2 Batch 3700 Loss 0.5951
# Epoch 2 Batch 3800 Loss 0.5903
# Epoch 2 Batch 3900 Loss 0.6037
# Epoch 2 Batch 4000 Loss 0.5845
# Epoch 2 Loss 0.594294
# Time taken for 1 epoch 2327.558784723282 sec
#
# Epoch 3 Batch 0 Loss 0.5875
# Epoch 3 Batch 100 Loss 0.5547
# Epoch 3 Batch 200 Loss 0.6016
# Epoch 3 Batch 300 Loss 0.5523
# Epoch 3 Batch 400 Loss 0.5686
# Epoch 3 Batch 500 Loss 0.5501
# Epoch 3 Batch 600 Loss 0.5647
# Epoch 3 Batch 700 Loss 0.6760
# Epoch 3 Batch 800 Loss 0.5523
# Epoch 3 Batch 900 Loss 0.5977
# Epoch 3 Batch 1000 Loss 0.5552
# Epoch 3 Batch 1100 Loss 0.5461
# Epoch 3 Batch 1200 Loss 0.5515
# Epoch 3 Batch 1300 Loss 0.5692
# Epoch 3 Batch 1400 Loss 0.5922
# Epoch 3 Batch 1500 Loss 0.5364
# Epoch 3 Batch 1600 Loss 0.4936
# Epoch 3 Batch 1700 Loss 0.5449
# Epoch 3 Batch 1800 Loss 0.5688
# Epoch 3 Batch 1900 Loss 0.5807
# Epoch 3 Batch 2000 Loss 0.5600
# Epoch 3 Batch 2100 Loss 0.5592
# Epoch 3 Batch 2200 Loss 0.5800
# Epoch 3 Batch 2300 Loss 0.5650
# Epoch 3 Batch 2400 Loss 0.6142
# Epoch 3 Batch 2500 Loss 0.5638
# Epoch 3 Batch 2600 Loss 0.5348
# Epoch 3 Batch 2700 Loss 0.5168
# Epoch 3 Batch 2800 Loss 0.5602
# Epoch 3 Batch 2900 Loss 0.5609
# Epoch 3 Batch 3000 Loss 0.5330
# Epoch 3 Batch 3100 Loss 0.5279
# Epoch 3 Batch 3200 Loss 0.5592
# Epoch 3 Batch 3300 Loss 0.5888
# Epoch 3 Batch 3400 Loss 0.5371
# Epoch 3 Batch 3500 Loss 0.6424
# Epoch 3 Batch 3600 Loss 0.5508
# Epoch 3 Batch 3700 Loss 0.5300
# Epoch 3 Batch 3800 Loss 0.5834
# Epoch 3 Batch 3900 Loss 0.5140
# Epoch 3 Batch 4000 Loss 0.5463
# Epoch 3 Loss 0.565165
# Time taken for 1 epoch 1916.0103278160095 sec
#
# Epoch 4 Batch 0 Loss 0.5374
# Epoch 4 Batch 100 Loss 0.5817
# Epoch 4 Batch 200 Loss 0.5208
# Epoch 4 Batch 300 Loss 0.5334
# Epoch 4 Batch 400 Loss 0.5178
# Epoch 4 Batch 500 Loss 0.5608
# Epoch 4 Batch 600 Loss 0.5629
# Epoch 4 Batch 700 Loss 0.5639
# Epoch 4 Batch 800 Loss 0.5519
# Epoch 4 Batch 900 Loss 0.5597
# Epoch 4 Batch 1000 Loss 0.6028
# Epoch 4 Batch 1100 Loss 0.5178
# Epoch 4 Batch 1200 Loss 0.5470
# Epoch 4 Batch 1300 Loss 0.4944
# Epoch 4 Batch 1400 Loss 0.6032
# Epoch 4 Batch 1500 Loss 0.5907
# Epoch 4 Batch 1600 Loss 0.5340
# Epoch 4 Batch 1700 Loss 0.5701
# Epoch 4 Batch 1800 Loss 0.5558
# Epoch 4 Batch 1900 Loss 0.5520
# Epoch 4 Batch 2000 Loss 0.5128
# Epoch 4 Batch 2100 Loss 0.5520
# Epoch 4 Batch 2200 Loss 0.5304
# Epoch 4 Batch 2300 Loss 0.5412
# Epoch 4 Batch 2400 Loss 0.4880
# Epoch 4 Batch 2500 Loss 0.5268
# Epoch 4 Batch 2600 Loss 0.5470
# Epoch 4 Batch 2700 Loss 0.5353
# Epoch 4 Batch 2800 Loss 0.5349
# Epoch 4 Batch 2900 Loss 0.5356
# Epoch 4 Batch 3000 Loss 0.5548
# Epoch 4 Batch 3100 Loss 0.5107
# Epoch 4 Batch 3200 Loss 0.5564
# Epoch 4 Batch 3300 Loss 0.5320
# Epoch 4 Batch 3400 Loss 0.5629
# Epoch 4 Batch 3500 Loss 0.5736
# Epoch 4 Batch 3600 Loss 0.5150
# Epoch 4 Batch 3700 Loss 0.6163
# Epoch 4 Batch 3800 Loss 0.5246
# Epoch 4 Batch 3900 Loss 0.5093
# Epoch 4 Batch 4000 Loss 0.5395
# Epoch 4 Loss 0.544575
# Time taken for 1 epoch 2686.435848236084 sec
#
# Epoch 5 Batch 0 Loss 0.4907
# Epoch 5 Batch 100 Loss 0.4810
# Epoch 5 Batch 200 Loss 0.5821
# Epoch 5 Batch 300 Loss 0.5315
# Epoch 5 Batch 400 Loss 0.5420
# Epoch 5 Batch 500 Loss 0.4813
# Epoch 5 Batch 600 Loss 0.5785
# Epoch 5 Batch 700 Loss 0.5560
# Epoch 5 Batch 800 Loss 0.4918
# Epoch 5 Batch 900 Loss 0.5668
# Epoch 5 Batch 1000 Loss 0.4936
# Epoch 5 Batch 1100 Loss 0.5494
# Epoch 5 Batch 1200 Loss 0.5409
# Epoch 5 Batch 1300 Loss 0.5172
# Epoch 5 Batch 1400 Loss 0.5420
# Epoch 5 Batch 1500 Loss 0.5235
# Epoch 5 Batch 1600 Loss 0.5685
# Epoch 5 Batch 1700 Loss 0.5102
# Epoch 5 Batch 1800 Loss 0.5113
# Epoch 5 Batch 1900 Loss 0.5496
# Epoch 5 Batch 2000 Loss 0.5791
# Epoch 5 Batch 2100 Loss 0.5324
# Epoch 5 Batch 2200 Loss 0.4925
# Epoch 5 Batch 2300 Loss 0.4975
# Epoch 5 Batch 2400 Loss 0.5443
# Epoch 5 Batch 2500 Loss 0.5129
# Epoch 5 Batch 2600 Loss 0.5132
# Epoch 5 Batch 2700 Loss 0.5037
# Epoch 5 Batch 2800 Loss 0.5027
# Epoch 5 Batch 2900 Loss 0.5483
# Epoch 5 Batch 3000 Loss 0.5623
# Epoch 5 Batch 3100 Loss 0.4996
# Epoch 5 Batch 3200 Loss 0.4889
# Epoch 5 Batch 3300 Loss 0.5081
# Epoch 5 Batch 3400 Loss 0.5361
# Epoch 5 Batch 3500 Loss 0.5324
# Epoch 5 Batch 3600 Loss 0.5283
# Epoch 5 Batch 3700 Loss 0.4711
# Epoch 5 Batch 3800 Loss 0.5138
# Epoch 5 Batch 3900 Loss 0.5025
# Epoch 5 Batch 4000 Loss 0.5395
# Epoch 5 Loss 0.528037
# Time taken for 1 epoch 2654.4065117836 sec
#
# Epoch 6 Batch 0 Loss 0.5277
# Epoch 6 Batch 100 Loss 0.5210
# Epoch 6 Batch 200 Loss 0.5324
# Epoch 6 Batch 300 Loss 0.5259
# Epoch 6 Batch 400 Loss 0.5438
# Epoch 6 Batch 500 Loss 0.4846
# Epoch 6 Batch 600 Loss 0.4734
# Epoch 6 Batch 700 Loss 0.5587
# Epoch 6 Batch 800 Loss 0.4795
# Epoch 6 Batch 900 Loss 0.5000
# Epoch 6 Batch 1000 Loss 0.4637
# Epoch 6 Batch 1100 Loss 0.5491
# Epoch 6 Batch 1200 Loss 0.5586
# Epoch 6 Batch 1300 Loss 0.5219
# Epoch 6 Batch 1400 Loss 0.5427
# Epoch 6 Batch 1500 Loss 0.5253
# Epoch 6 Batch 1600 Loss 0.4983
# Epoch 6 Batch 1700 Loss 0.5141
# Epoch 6 Batch 1800 Loss 0.5563
# Epoch 6 Batch 1900 Loss 0.4713
# Epoch 6 Batch 2000 Loss 0.5473
# Epoch 6 Batch 2100 Loss 0.4852
# Epoch 6 Batch 2200 Loss 0.5329
# Epoch 6 Batch 2300 Loss 0.5226
# Epoch 6 Batch 2400 Loss 0.5023
# Epoch 6 Batch 2500 Loss 0.4734
# Epoch 6 Batch 2600 Loss 0.5276
# Epoch 6 Batch 2700 Loss 0.5195
# Epoch 6 Batch 2800 Loss 0.5443
# Epoch 6 Batch 2900 Loss 0.5228
# Epoch 6 Batch 3000 Loss 0.4816
# Epoch 6 Batch 3100 Loss 0.5303
# Epoch 6 Batch 3200 Loss 0.4906
# Epoch 6 Batch 3300 Loss 0.4997
# Epoch 6 Batch 3400 Loss 0.5218
# Epoch 6 Batch 3500 Loss 0.4926
# Epoch 6 Batch 3600 Loss 0.4970
# Epoch 6 Batch 3700 Loss 0.5232
# Epoch 6 Batch 3800 Loss 0.4956
# Epoch 6 Batch 3900 Loss 0.5210
# Epoch 6 Batch 4000 Loss 0.5405
# Epoch 6 Loss 0.514365
# Time taken for 1 epoch 2302.26221036911 sec
#
# Epoch 7 Batch 0 Loss 0.5222
# Epoch 7 Batch 100 Loss 0.5017
# Epoch 7 Batch 200 Loss 0.4438
# Epoch 7 Batch 300 Loss 0.5149
# Epoch 7 Batch 400 Loss 0.5311
# Epoch 7 Batch 500 Loss 0.5205
# Epoch 7 Batch 600 Loss 0.4886
# Epoch 7 Batch 700 Loss 0.4513
# Epoch 7 Batch 800 Loss 0.4997
# Epoch 7 Batch 900 Loss 0.5039
# Epoch 7 Batch 1000 Loss 0.5447
# Epoch 7 Batch 1100 Loss 0.5383
# Epoch 7 Batch 1200 Loss 0.5059
# Epoch 7 Batch 1300 Loss 0.5164
# Epoch 7 Batch 1400 Loss 0.5187
# Epoch 7 Batch 1500 Loss 0.5013
# Epoch 7 Batch 1600 Loss 0.5087
# Epoch 7 Batch 1700 Loss 0.5136
# Epoch 7 Batch 1800 Loss 0.5664
# Epoch 7 Batch 1900 Loss 0.4996
# Epoch 7 Batch 2000 Loss 0.4821
# Epoch 7 Batch 2100 Loss 0.4691
# Epoch 7 Batch 2200 Loss 0.5056
# Epoch 7 Batch 2300 Loss 0.4730
# Epoch 7 Batch 2400 Loss 0.5177
# Epoch 7 Batch 2500 Loss 0.4728
# Epoch 7 Batch 2600 Loss 0.5331
# Epoch 7 Batch 2700 Loss 0.5809
# Epoch 7 Batch 2800 Loss 0.4778
# Epoch 7 Batch 2900 Loss 0.5529
# Epoch 7 Batch 3000 Loss 0.5001
# Epoch 7 Batch 3100 Loss 0.4828
# Epoch 7 Batch 3200 Loss 0.4655
# Epoch 7 Batch 3300 Loss 0.5288
# Epoch 7 Batch 3400 Loss 0.5217
# Epoch 7 Batch 3500 Loss 0.5058
# Epoch 7 Batch 3600 Loss 0.4890
# Epoch 7 Batch 3700 Loss 0.4434
# Epoch 7 Batch 3800 Loss 0.5107
# Epoch 7 Batch 3900 Loss 0.5319
# Epoch 7 Batch 4000 Loss 0.4404
# Epoch 7 Loss 0.502318
# Time taken for 1 epoch 1974.6708641052246 sec
#
# Epoch 8 Batch 0 Loss 0.4680
# Epoch 8 Batch 100 Loss 0.4985
# Epoch 8 Batch 200 Loss 0.5208
# Epoch 8 Batch 300 Loss 0.4984
# Epoch 8 Batch 400 Loss 0.5251
# Epoch 8 Batch 500 Loss 0.4806
# Epoch 8 Batch 600 Loss 0.5225
# Epoch 8 Batch 700 Loss 0.4863
# Epoch 8 Batch 800 Loss 0.4831
# Epoch 8 Batch 900 Loss 0.4623
# Epoch 8 Batch 1000 Loss 0.4772
# Epoch 8 Batch 1100 Loss 0.4497
# Epoch 8 Batch 1200 Loss 0.4686
# Epoch 8 Batch 1300 Loss 0.4897
# Epoch 8 Batch 1400 Loss 0.4193
# Epoch 8 Batch 1500 Loss 0.4589
# Epoch 8 Batch 1600 Loss 0.4666
# Epoch 8 Batch 1700 Loss 0.5181
# Epoch 8 Batch 1800 Loss 0.4972
# Epoch 8 Batch 1900 Loss 0.4688
# Epoch 8 Batch 2000 Loss 0.5070
# Epoch 8 Batch 2100 Loss 0.4945
# Epoch 8 Batch 2200 Loss 0.5259
# Epoch 8 Batch 2300 Loss 0.5131
# Epoch 8 Batch 2400 Loss 0.5300
# Epoch 8 Batch 2500 Loss 0.4580
# Epoch 8 Batch 2600 Loss 0.4855
# Epoch 8 Batch 2700 Loss 0.5178
# Epoch 8 Batch 2800 Loss 0.5347
# Epoch 8 Batch 2900 Loss 0.4788
# Epoch 8 Batch 3000 Loss 0.4466
# Epoch 8 Batch 3100 Loss 0.5192
# Epoch 8 Batch 3200 Loss 0.5062
# Epoch 8 Batch 3300 Loss 0.4621
# Epoch 8 Batch 3400 Loss 0.5138
# Epoch 8 Batch 3500 Loss 0.5277
# Epoch 8 Batch 3600 Loss 0.4915
# Epoch 8 Batch 3700 Loss 0.4816
# Epoch 8 Batch 3800 Loss 0.5173
# Epoch 8 Batch 3900 Loss 0.4843
# Epoch 8 Batch 4000 Loss 0.5033
# Epoch 8 Loss 0.491804
# Time taken for 1 epoch 3114.6799681186676 sec
#
# Epoch 9 Batch 0 Loss 0.4683
# Epoch 9 Batch 100 Loss 0.5095
# Epoch 9 Batch 200 Loss 0.4762
# Epoch 9 Batch 300 Loss 0.4825
# Epoch 9 Batch 400 Loss 0.4793
# Epoch 9 Batch 500 Loss 0.4647
# Epoch 9 Batch 600 Loss 0.5017
# Epoch 9 Batch 700 Loss 0.5453
# Epoch 9 Batch 800 Loss 0.5349
# Epoch 9 Batch 900 Loss 0.4621
# Epoch 9 Batch 1000 Loss 0.4496
# Epoch 9 Batch 1100 Loss 0.4990
# Epoch 9 Batch 1200 Loss 0.4770
# Epoch 9 Batch 1300 Loss 0.4641
# Epoch 9 Batch 1400 Loss 0.4618
# Epoch 9 Batch 1500 Loss 0.4591
# Epoch 9 Batch 1600 Loss 0.5119
# Epoch 9 Batch 1700 Loss 0.5244
# Epoch 9 Batch 1800 Loss 0.4942
# Epoch 9 Batch 1900 Loss 0.5774
# Epoch 9 Batch 2000 Loss 0.5505
# Epoch 9 Batch 2100 Loss 0.5615
# Epoch 9 Batch 2200 Loss 0.4249
# Epoch 9 Batch 2300 Loss 0.5166
# Epoch 9 Batch 2400 Loss 0.5151
# Epoch 9 Batch 2500 Loss 0.5151
# Epoch 9 Batch 2600 Loss 0.4672
# Epoch 9 Batch 2700 Loss 0.4608
# Epoch 9 Batch 2800 Loss 0.4270
# Epoch 9 Batch 2900 Loss 0.4536
# Epoch 9 Batch 3000 Loss 0.5064
# Epoch 9 Batch 3100 Loss 0.4712
# Epoch 9 Batch 3200 Loss 0.4865
# Epoch 9 Batch 3300 Loss 0.4493
# Epoch 9 Batch 3400 Loss 0.4768
# Epoch 9 Batch 3500 Loss 0.4692
# Epoch 9 Batch 3600 Loss 0.4805
# Epoch 9 Batch 3700 Loss 0.4167
# Epoch 9 Batch 3800 Loss 0.4702
# Epoch 9 Batch 3900 Loss 0.4540
# Epoch 9 Batch 4000 Loss 0.4582
# Epoch 9 Loss 0.482453
# Time taken for 1 epoch 1947.4716737270355 sec
#
# Epoch 10 Batch 0 Loss 0.5267
# Epoch 10 Batch 100 Loss 0.4593
# Epoch 10 Batch 200 Loss 0.4834
# Epoch 10 Batch 300 Loss 0.3963
# Epoch 10 Batch 400 Loss 0.4777
# Epoch 10 Batch 500 Loss 0.5059
# Epoch 10 Batch 600 Loss 0.4875
# Epoch 10 Batch 700 Loss 0.5035
# Epoch 10 Batch 800 Loss 0.4304
# Epoch 10 Batch 900 Loss 0.5024
# Epoch 10 Batch 1000 Loss 0.4697
# Epoch 10 Batch 1100 Loss 0.5092
# Epoch 10 Batch 1200 Loss 0.4585
# Epoch 10 Batch 1300 Loss 0.4880
# Epoch 10 Batch 1400 Loss 0.4791
# Epoch 10 Batch 1500 Loss 0.5005
# Epoch 10 Batch 1600 Loss 0.4582
# Epoch 10 Batch 1700 Loss 0.4109
# Epoch 10 Batch 1800 Loss 0.4737
# Epoch 10 Batch 1900 Loss 0.4798
# Epoch 10 Batch 2000 Loss 0.4680
# Epoch 10 Batch 2100 Loss 0.4650
# Epoch 10 Batch 2200 Loss 0.4561
# Epoch 10 Batch 2300 Loss 0.4613
# Epoch 10 Batch 2400 Loss 0.4923
# Epoch 10 Batch 2500 Loss 0.4866
# Epoch 10 Batch 2600 Loss 0.5178
# Epoch 10 Batch 2700 Loss 0.4760
# Epoch 10 Batch 2800 Loss 0.4454
# Epoch 10 Batch 2900 Loss 0.4403
# Epoch 10 Batch 3000 Loss 0.4195
# Epoch 10 Batch 3100 Loss 0.4873
# Epoch 10 Batch 3200 Loss 0.4605
# Epoch 10 Batch 3300 Loss 0.5112
# Epoch 10 Batch 3400 Loss 0.4429
# Epoch 10 Batch 3500 Loss 0.4629
# Epoch 10 Batch 3600 Loss 0.4633
# Epoch 10 Batch 3700 Loss 0.4576
# Epoch 10 Batch 3800 Loss 0.4627
# Epoch 10 Batch 3900 Loss 0.5051
# Epoch 10 Batch 4000 Loss 0.5209
# Epoch 10 Loss 0.474048
# Time taken for 1 epoch 2430.9181776046753 sec
#
# Epoch 11 Batch 0 Loss 0.4678
# Epoch 11 Batch 100 Loss 0.4753
# Epoch 11 Batch 200 Loss 0.4554
# Epoch 11 Batch 300 Loss 0.4849
# Epoch 11 Batch 400 Loss 0.4818
# Epoch 11 Batch 500 Loss 0.4765
# Epoch 11 Batch 600 Loss 0.4265
# Epoch 11 Batch 700 Loss 0.5116
# Epoch 11 Batch 800 Loss 0.4747
# Epoch 11 Batch 900 Loss 0.4688
# Epoch 11 Batch 1000 Loss 0.4465
# Epoch 11 Batch 1100 Loss 0.5038
# Epoch 11 Batch 1200 Loss 0.4499
# Epoch 11 Batch 1300 Loss 0.4514
# Epoch 11 Batch 1400 Loss 0.4877
# Epoch 11 Batch 1500 Loss 0.4382
# Epoch 11 Batch 1600 Loss 0.4352
# Epoch 11 Batch 1700 Loss 0.4999
# Epoch 11 Batch 1800 Loss 0.4739
# Epoch 11 Batch 1900 Loss 0.4946
# Epoch 11 Batch 2000 Loss 0.4795
# Epoch 11 Batch 2100 Loss 0.4863
# Epoch 11 Batch 2200 Loss 0.4441
# Epoch 11 Batch 2300 Loss 0.4433
# Epoch 11 Batch 2400 Loss 0.5327
# Epoch 11 Batch 2500 Loss 0.4637
# Epoch 11 Batch 2600 Loss 0.5327
# Epoch 11 Batch 2700 Loss 0.4174
# Epoch 11 Batch 2800 Loss 0.4935
# Epoch 11 Batch 2900 Loss 0.4234
# Epoch 11 Batch 3000 Loss 0.4444
# Epoch 11 Batch 3100 Loss 0.4510
# Epoch 11 Batch 3200 Loss 0.4517
# Epoch 11 Batch 3300 Loss 0.4767
# Epoch 11 Batch 3400 Loss 0.4622
# Epoch 11 Batch 3500 Loss 0.4652
# Epoch 11 Batch 3600 Loss 0.4783
# Epoch 11 Batch 3700 Loss 0.4946
# Epoch 11 Batch 3800 Loss 0.4856
# Epoch 11 Batch 3900 Loss 0.4774
# Epoch 11 Batch 4000 Loss 0.5060
# Epoch 11 Loss 0.466541
# Time taken for 1 epoch 2564.9355170726776 sec
#
# Epoch 12 Batch 0 Loss 0.4783
# Epoch 12 Batch 100 Loss 0.4769
# Epoch 12 Batch 200 Loss 0.4651
# Epoch 12 Batch 300 Loss 0.4163
# Epoch 12 Batch 400 Loss 0.4705
# Epoch 12 Batch 500 Loss 0.4467
# Epoch 12 Batch 600 Loss 0.4796
# Epoch 12 Batch 700 Loss 0.4328
# Epoch 12 Batch 800 Loss 0.4421
# Epoch 12 Batch 900 Loss 0.4776
# Epoch 12 Batch 1000 Loss 0.4973
# Epoch 12 Batch 1100 Loss 0.4434
# Epoch 12 Batch 1200 Loss 0.4533
# Epoch 12 Batch 1300 Loss 0.4563
# Epoch 12 Batch 1400 Loss 0.4668
# Epoch 12 Batch 1500 Loss 0.4901
# Epoch 12 Batch 1600 Loss 0.4439
# Epoch 12 Batch 1700 Loss 0.4721
# Epoch 12 Batch 1800 Loss 0.4847
# Epoch 12 Batch 1900 Loss 0.5154
# Epoch 12 Batch 2000 Loss 0.4721
# Epoch 12 Batch 2100 Loss 0.4917
# Epoch 12 Batch 2200 Loss 0.4449
# Epoch 12 Batch 2300 Loss 0.4312
# Epoch 12 Batch 2400 Loss 0.4437
# Epoch 12 Batch 2500 Loss 0.4505
# Epoch 12 Batch 2600 Loss 0.4824
# Epoch 12 Batch 2700 Loss 0.4815
# Epoch 12 Batch 2800 Loss 0.4981
# Epoch 12 Batch 2900 Loss 0.4553
# Epoch 12 Batch 3000 Loss 0.4414
# Epoch 12 Batch 3100 Loss 0.5606
# Epoch 12 Batch 3200 Loss 0.4638
# Epoch 12 Batch 3300 Loss 0.4563
# Epoch 12 Batch 3400 Loss 0.4539
# Epoch 12 Batch 3500 Loss 0.4430
# Epoch 12 Batch 3600 Loss 0.4640
# Epoch 12 Batch 3700 Loss 0.4518
# Epoch 12 Batch 3800 Loss 0.4459
# Epoch 12 Batch 3900 Loss 0.4686
# Epoch 12 Batch 4000 Loss 0.4495
# Epoch 12 Loss 0.462065
# Time taken for 1 epoch 2503.673848390579 sec
#
# Epoch 13 Batch 0 Loss 0.5142
# Epoch 13 Batch 100 Loss 0.4411
# Epoch 13 Batch 200 Loss 0.4316
# Epoch 13 Batch 300 Loss 0.4559
# Epoch 13 Batch 400 Loss 0.4777
# Epoch 13 Batch 500 Loss 0.5045
# Epoch 13 Batch 600 Loss 0.4494
# Epoch 13 Batch 700 Loss 0.4706
# Epoch 13 Batch 800 Loss 0.4279
# Epoch 13 Batch 900 Loss 0.4140
# Epoch 13 Batch 1000 Loss 0.4523
# Epoch 13 Batch 1100 Loss 0.4294
# Epoch 13 Batch 1200 Loss 0.4248
# Epoch 13 Batch 1300 Loss 0.4833
# Epoch 13 Batch 1400 Loss 0.4532
# Epoch 13 Batch 1500 Loss 0.4194
# Epoch 13 Batch 1600 Loss 0.4228
# Epoch 13 Batch 1700 Loss 0.4667
# Epoch 13 Batch 1800 Loss 0.4348
# Epoch 13 Batch 1900 Loss 0.4746
# Epoch 13 Batch 2000 Loss 0.4973
# Epoch 13 Batch 2100 Loss 0.4573
# Epoch 13 Batch 2200 Loss 0.4529
# Epoch 13 Batch 2300 Loss 0.4011
# Epoch 13 Batch 2400 Loss 0.4727
# Epoch 13 Batch 2500 Loss 0.4813
# Epoch 13 Batch 2600 Loss 0.4297
# Epoch 13 Batch 2700 Loss 0.4376
# Epoch 13 Batch 2800 Loss 0.4250
# Epoch 13 Batch 2900 Loss 0.4830
# Epoch 13 Batch 3000 Loss 0.4141
# Epoch 13 Batch 3100 Loss 0.4620
# Epoch 13 Batch 3200 Loss 0.4245
# Epoch 13 Batch 3300 Loss 0.4536
# Epoch 13 Batch 3400 Loss 0.4021
# Epoch 13 Batch 3500 Loss 0.4409
# Epoch 13 Batch 3600 Loss 0.4339
# Epoch 13 Batch 3700 Loss 0.4507
# Epoch 13 Batch 3800 Loss 0.4535
# Epoch 13 Batch 3900 Loss 0.4729
# Epoch 13 Batch 4000 Loss 0.4730
# Epoch 13 Loss 0.454240
# Time taken for 1 epoch 1962.9093947410583 sec
#
# Epoch 14 Batch 0 Loss 0.4560
# Epoch 14 Batch 100 Loss 0.4699
# Epoch 14 Batch 200 Loss 0.4163
# Epoch 14 Batch 300 Loss 0.4831
# Epoch 14 Batch 400 Loss 0.4200
# Epoch 14 Batch 500 Loss 0.4731
# Epoch 14 Batch 600 Loss 0.4407
# Epoch 14 Batch 700 Loss 0.4765
# Epoch 14 Batch 800 Loss 0.4025
# Epoch 14 Batch 900 Loss 0.4887
# Epoch 14 Batch 1000 Loss 0.4217
# Epoch 14 Batch 1100 Loss 0.4331
# Epoch 14 Batch 1200 Loss 0.4372
# Epoch 14 Batch 1300 Loss 0.4480
# Epoch 14 Batch 1400 Loss 0.4364
# Epoch 14 Batch 1500 Loss 0.4475
# Epoch 14 Batch 1600 Loss 0.4068
# Epoch 14 Batch 1700 Loss 0.4479
# Epoch 14 Batch 1800 Loss 0.4077
# Epoch 14 Batch 1900 Loss 0.4425
# Epoch 14 Batch 2000 Loss 0.4247
# Epoch 14 Batch 2100 Loss 0.4130
# Epoch 14 Batch 2200 Loss 0.4458
# Epoch 14 Batch 2300 Loss 0.4629
# Epoch 14 Batch 2400 Loss 0.4697
# Epoch 14 Batch 2500 Loss 0.4811
# Epoch 14 Batch 2600 Loss 0.4736
# Epoch 14 Batch 2700 Loss 0.4186
# Epoch 14 Batch 2800 Loss 0.4647
# Epoch 14 Batch 2900 Loss 0.4089
# Epoch 14 Batch 3000 Loss 0.4345
# Epoch 14 Batch 3100 Loss 0.4662
# Epoch 14 Batch 3200 Loss 0.4506
# Epoch 14 Batch 3300 Loss 0.4290
# Epoch 14 Batch 3400 Loss 0.4603
# Epoch 14 Batch 3500 Loss 0.4375
# Epoch 14 Batch 3600 Loss 0.4727
# Epoch 14 Batch 3700 Loss 0.4842
# Epoch 14 Batch 3800 Loss 0.4561
# Epoch 14 Batch 3900 Loss 0.4835
# Epoch 14 Batch 4000 Loss 0.4255
# Epoch 14 Loss 0.447658
# Time taken for 1 epoch 2412.573565006256 sec
#
# Epoch 15 Batch 0 Loss 0.4344
# Epoch 15 Batch 100 Loss 0.4182
# Epoch 15 Batch 200 Loss 0.4551
# Epoch 15 Batch 300 Loss 0.4746
# Epoch 15 Batch 400 Loss 0.4455
# Epoch 15 Batch 500 Loss 0.4695
# Epoch 15 Batch 600 Loss 0.4191
# Epoch 15 Batch 700 Loss 0.4412
# Epoch 15 Batch 800 Loss 0.4467
# Epoch 15 Batch 900 Loss 0.4003
# Epoch 15 Batch 1000 Loss 0.4717
# Epoch 15 Batch 1100 Loss 0.4570
# Epoch 15 Batch 1200 Loss 0.4518
# Epoch 15 Batch 1300 Loss 0.4646
# Epoch 15 Batch 1400 Loss 0.4293
# Epoch 15 Batch 1500 Loss 0.5171
# Epoch 15 Batch 1600 Loss 0.4359
# Epoch 15 Batch 1700 Loss 0.4677
# Epoch 15 Batch 1800 Loss 0.4564
# Epoch 15 Batch 1900 Loss 0.4676
# Epoch 15 Batch 2000 Loss 0.4307
# Epoch 15 Batch 2100 Loss 0.4689
# Epoch 15 Batch 2200 Loss 0.4419
# Epoch 15 Batch 2300 Loss 0.4553
# Epoch 15 Batch 2400 Loss 0.4141
# Epoch 15 Batch 2500 Loss 0.4537
# Epoch 15 Batch 2600 Loss 0.4364
# Epoch 15 Batch 2700 Loss 0.3927
# Epoch 15 Batch 2800 Loss 0.4364
# Epoch 15 Batch 2900 Loss 0.4274
# Epoch 15 Batch 3000 Loss 0.4117
# Epoch 15 Batch 3100 Loss 0.4457
# Epoch 15 Batch 3200 Loss 0.4044
# Epoch 15 Batch 3300 Loss 0.4227
# Epoch 15 Batch 3400 Loss 0.4317
# Epoch 15 Batch 3500 Loss 0.4156
# Epoch 15 Batch 3600 Loss 0.4075
# Epoch 15 Batch 3700 Loss 0.4551
# Epoch 15 Batch 3800 Loss 0.4604
# Epoch 15 Batch 3900 Loss 0.4137
# Epoch 15 Batch 4000 Loss 0.4253
# Epoch 15 Loss 0.442709
# Time taken for 1 epoch 1927.253541469574 sec
#
# Epoch 16 Batch 0 Loss 0.4344
# Epoch 16 Batch 100 Loss 0.4473
# Epoch 16 Batch 200 Loss 0.4591
# Epoch 16 Batch 300 Loss 0.4262
# Epoch 16 Batch 400 Loss 0.4459
# Epoch 16 Batch 500 Loss 0.4239
# Epoch 16 Batch 600 Loss 0.4417
# Epoch 16 Batch 700 Loss 0.4174
# Epoch 16 Batch 800 Loss 0.4541
# Epoch 16 Batch 900 Loss 0.4505
# Epoch 16 Batch 1000 Loss 0.4078
# Epoch 16 Batch 1100 Loss 0.4170
# Epoch 16 Batch 1200 Loss 0.4736
# Epoch 16 Batch 1300 Loss 0.4590
# Epoch 16 Batch 1400 Loss 0.4892
# Epoch 16 Batch 1500 Loss 0.3975
# Epoch 16 Batch 1600 Loss 0.4313
# Epoch 16 Batch 1700 Loss 0.4381
# Epoch 16 Batch 1800 Loss 0.5066
# Epoch 16 Batch 1900 Loss 0.4260
# Epoch 16 Batch 2000 Loss 0.4407
# Epoch 16 Batch 2100 Loss 0.4169
# Epoch 16 Batch 2200 Loss 0.4800
# Epoch 16 Batch 2300 Loss 0.4522
# Epoch 16 Batch 2400 Loss 0.4422
# Epoch 16 Batch 2500 Loss 0.4128
# Epoch 16 Batch 2600 Loss 0.4311
# Epoch 16 Batch 2700 Loss 0.4434
# Epoch 16 Batch 2800 Loss 0.4243
# Epoch 16 Batch 2900 Loss 0.4114
# Epoch 16 Batch 3000 Loss 0.4356
# Epoch 16 Batch 3100 Loss 0.4803
# Epoch 16 Batch 3200 Loss 0.4121
# Epoch 16 Batch 3300 Loss 0.4258
# Epoch 16 Batch 3400 Loss 0.4189
# Epoch 16 Batch 3500 Loss 0.4163
# Epoch 16 Batch 3600 Loss 0.4572
# Epoch 16 Batch 3700 Loss 0.4210
# Epoch 16 Batch 3800 Loss 0.4346
# Epoch 16 Batch 3900 Loss 0.4285
# Epoch 16 Batch 4000 Loss 0.4664
# Epoch 16 Loss 0.437373
# Time taken for 1 epoch 2678.329563140869 sec
#
# Epoch 17 Batch 0 Loss 0.4313
# Epoch 17 Batch 100 Loss 0.4381
# Epoch 17 Batch 200 Loss 0.4327
# Epoch 17 Batch 300 Loss 0.4488
# Epoch 17 Batch 400 Loss 0.4335
# Epoch 17 Batch 500 Loss 0.4932
# Epoch 17 Batch 600 Loss 0.4038
# Epoch 17 Batch 700 Loss 0.4579
# Epoch 17 Batch 800 Loss 0.4434
# Epoch 17 Batch 900 Loss 0.4208
# Epoch 17 Batch 1000 Loss 0.4089
# Epoch 17 Batch 1100 Loss 0.4665
# Epoch 17 Batch 1200 Loss 0.4008
# Epoch 17 Batch 1300 Loss 0.3997
# Epoch 17 Batch 1400 Loss 0.3990
# Epoch 17 Batch 1500 Loss 0.3929
# Epoch 17 Batch 1600 Loss 0.4112
# Epoch 17 Batch 1700 Loss 0.4396
# Epoch 17 Batch 1800 Loss 0.4265
# Epoch 17 Batch 1900 Loss 0.3852
# Epoch 17 Batch 2000 Loss 0.4171
# Epoch 17 Batch 2100 Loss 0.4251
# Epoch 17 Batch 2200 Loss 0.4041
# Epoch 17 Batch 2300 Loss 0.4440
# Epoch 17 Batch 2400 Loss 0.3966
# Epoch 17 Batch 2500 Loss 0.4046
# Epoch 17 Batch 2600 Loss 0.4144
# Epoch 17 Batch 2700 Loss 0.3922
# Epoch 17 Batch 2800 Loss 0.4201
# Epoch 17 Batch 2900 Loss 0.4053
# Epoch 17 Batch 3000 Loss 0.4042
# Epoch 17 Batch 3100 Loss 0.4035
# Epoch 17 Batch 3200 Loss 0.4208
# Epoch 17 Batch 3300 Loss 0.4744
# Epoch 17 Batch 3400 Loss 0.4499
# Epoch 17 Batch 3500 Loss 0.4350
# Epoch 17 Batch 3600 Loss 0.4695
# Epoch 17 Batch 3700 Loss 0.4457
# Epoch 17 Batch 3800 Loss 0.4348
# Epoch 17 Batch 3900 Loss 0.4279
# Epoch 17 Batch 4000 Loss 0.4429
# Epoch 17 Loss 0.433114
# Time taken for 1 epoch 2256.8420984745026 sec
#
# Epoch 18 Batch 0 Loss 0.4355
# Epoch 18 Batch 100 Loss 0.4471
# Epoch 18 Batch 200 Loss 0.3928
# Epoch 18 Batch 300 Loss 0.4108
# Epoch 18 Batch 400 Loss 0.4119
# Epoch 18 Batch 500 Loss 0.4230
# Epoch 18 Batch 600 Loss 0.4076
# Epoch 18 Batch 700 Loss 0.3939
# Epoch 18 Batch 800 Loss 0.4223
# Epoch 18 Batch 900 Loss 0.4339
# Epoch 18 Batch 1000 Loss 0.4259
# Epoch 18 Batch 1100 Loss 0.4324
# Epoch 18 Batch 1200 Loss 0.3975
# Epoch 18 Batch 1300 Loss 0.4498
# Epoch 18 Batch 1400 Loss 0.4104
# Epoch 18 Batch 1500 Loss 0.4078
# Epoch 18 Batch 1600 Loss 0.3974
# Epoch 18 Batch 1700 Loss 0.4133
# Epoch 18 Batch 1800 Loss 0.4469
# Epoch 18 Batch 1900 Loss 0.4697
# Epoch 18 Batch 2000 Loss 0.4347
# Epoch 18 Batch 2100 Loss 0.4356
# Epoch 18 Batch 2200 Loss 0.4615
# Epoch 18 Batch 2300 Loss 0.4516
# Epoch 18 Batch 2400 Loss 0.4488
# Epoch 18 Batch 2500 Loss 0.3751
# Epoch 18 Batch 2600 Loss 0.4327
# Epoch 18 Batch 2700 Loss 0.4242
# Epoch 18 Batch 2800 Loss 0.4667
# Epoch 18 Batch 2900 Loss 0.4030
# Epoch 18 Batch 3000 Loss 0.3955
# Epoch 18 Batch 3100 Loss 0.4245
# Epoch 18 Batch 3200 Loss 0.4038
# Epoch 18 Batch 3300 Loss 0.3998
# Epoch 18 Batch 3400 Loss 0.4250
# Epoch 18 Batch 3500 Loss 0.4360
# Epoch 18 Batch 3600 Loss 0.3829
# Epoch 18 Batch 3700 Loss 0.4442
# Epoch 18 Batch 3800 Loss 0.4564
# Epoch 18 Batch 3900 Loss 0.4282
# Epoch 18 Batch 4000 Loss 0.4300
# Epoch 18 Loss 0.428890
# Time taken for 1 epoch 2350.1446187496185 sec
#
# Epoch 19 Batch 0 Loss 0.4212
# Epoch 19 Batch 100 Loss 0.4282
# Epoch 19 Batch 200 Loss 0.4513
# Epoch 19 Batch 300 Loss 0.4018
# Epoch 19 Batch 400 Loss 0.4379
# Epoch 19 Batch 500 Loss 0.4133
# Epoch 19 Batch 600 Loss 0.4601
# Epoch 19 Batch 700 Loss 0.4832
# Epoch 19 Batch 800 Loss 0.4318
# Epoch 19 Batch 900 Loss 0.4281
# Epoch 19 Batch 1000 Loss 0.4093
# Epoch 19 Batch 1100 Loss 0.4200
# Epoch 19 Batch 1200 Loss 0.3816
# Epoch 19 Batch 1300 Loss 0.4861
# Epoch 19 Batch 1400 Loss 0.4189
# Epoch 19 Batch 1500 Loss 0.4843
# Epoch 19 Batch 1600 Loss 0.4119
# Epoch 19 Batch 1700 Loss 0.4427
# Epoch 19 Batch 1800 Loss 0.4132
# Epoch 19 Batch 1900 Loss 0.4229
# Epoch 19 Batch 2000 Loss 0.4142
# Epoch 19 Batch 2100 Loss 0.4266
# Epoch 19 Batch 2200 Loss 0.4159
# Epoch 19 Batch 2300 Loss 0.4412
# Epoch 19 Batch 2400 Loss 0.4201
# Epoch 19 Batch 2500 Loss 0.4068
# Epoch 19 Batch 2600 Loss 0.4126
# Epoch 19 Batch 2700 Loss 0.3622
# Epoch 19 Batch 2800 Loss 0.4450
# Epoch 19 Batch 2900 Loss 0.3888
# Epoch 19 Batch 3000 Loss 0.4018
# Epoch 19 Batch 3100 Loss 0.4270
# Epoch 19 Batch 3200 Loss 0.3957
# Epoch 19 Batch 3300 Loss 0.4313
# Epoch 19 Batch 3400 Loss 0.4136
# Epoch 19 Batch 3500 Loss 0.4071
# Epoch 19 Batch 3600 Loss 0.4481
# Epoch 19 Batch 3700 Loss 0.4388
# Epoch 19 Batch 3800 Loss 0.4014
# Epoch 19 Batch 3900 Loss 0.4061
# Epoch 19 Batch 4000 Loss 0.4508
# Epoch 19 Loss 0.425485
# Time taken for 1 epoch 1965.1267938613892 sec
#
# Epoch 20 Batch 0 Loss 0.4056
# Epoch 20 Batch 100 Loss 0.4225
# Epoch 20 Batch 200 Loss 0.4155
# Epoch 20 Batch 300 Loss 0.4235
# Epoch 20 Batch 400 Loss 0.4575
# Epoch 20 Batch 500 Loss 0.4078
# Epoch 20 Batch 600 Loss 0.4364
# Epoch 20 Batch 700 Loss 0.4235
# Epoch 20 Batch 800 Loss 0.4493
# Epoch 20 Batch 900 Loss 0.4084
# Epoch 20 Batch 1000 Loss 0.4155
# Epoch 20 Batch 1100 Loss 0.4163
# Epoch 20 Batch 1200 Loss 0.4053
# Epoch 20 Batch 1300 Loss 0.4032
# Epoch 20 Batch 1400 Loss 0.3811
# Epoch 20 Batch 1500 Loss 0.4272
# Epoch 20 Batch 1600 Loss 0.4083
# Epoch 20 Batch 1700 Loss 0.4494
# Epoch 20 Batch 1800 Loss 0.4274
# Epoch 20 Batch 1900 Loss 0.4467
# Epoch 20 Batch 2000 Loss 0.3877
# Epoch 20 Batch 2100 Loss 0.4477
# Epoch 20 Batch 2200 Loss 0.4674
# Epoch 20 Batch 2300 Loss 0.4246
# Epoch 20 Batch 2400 Loss 0.3876
# Epoch 20 Batch 2500 Loss 0.4431
# Epoch 20 Batch 2600 Loss 0.4028
# Epoch 20 Batch 2700 Loss 0.4239
# Epoch 20 Batch 2800 Loss 0.4121
# Epoch 20 Batch 2900 Loss 0.4317
# Epoch 20 Batch 3000 Loss 0.4287
# Epoch 20 Batch 3100 Loss 0.4320
# Epoch 20 Batch 3200 Loss 0.3954
# Epoch 20 Batch 3300 Loss 0.4527
# Epoch 20 Batch 3400 Loss 0.4206
# Epoch 20 Batch 3500 Loss 0.4100
# Epoch 20 Batch 3600 Loss 0.4154
# Epoch 20 Batch 3700 Loss 0.4202
# Epoch 20 Batch 3800 Loss 0.4268
# Epoch 20 Batch 3900 Loss 0.3817
# Epoch 20 Batch 4000 Loss 0.4609
# Epoch 20 Loss 0.421476
# Time taken for 1 epoch 2421.23641204834 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (7, 7))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print ('Real Caption:', real_caption)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a gentle man playing badminton ready to kick the ball <end>
# Prediction Caption: a man in a short yellow shirt and red shorts <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a surfer on a surfboard on top of a surfboard <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x25E95C39CD0>
