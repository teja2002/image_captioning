# %% [markdown]
# ## IMAGE CAPTIONING

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections #for storing different types of tuples and dictionares
import random  #random initialization
import re  # Regular expressions are text matching patterns described with a formal syntax
import numpy as np 
import os  #allows you to interface with the underlying operating system that Python is running on. 
import time #time dependent tasks
import json #load json files
from glob import glob #listing files under a specified folder
from PIL import Image #image manipulation
import pickle #serialize python objects

# %%
# Download caption annotation files
annotation_folder = '/annotation/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
    annotation_zip = tf.keras.utils.get_file('captions.zip',
                                             cache_subdir=os.path.abspath('.'),
                                             origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                             extract = True)
    annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
    os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
    image_zip = tf.keras.utils.get_file('train2014.zip',
                                        cache_subdir=os.path.abspath('.'),
                                        origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                        extract = True)
    PATH = os.path.dirname(image_zip) + image_folder
    os.remove(image_zip)
else:
    PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 42s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    caption = f"<start> {val['caption']} <end>"
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths[:64000]
print(len(train_image_paths))
# Out:
# 64000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    train_captions.extend(caption_list)
    img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A young woman looks at a laptop computer on a picnic bench. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x1E43975CB20>

# %% [markdown]
# ## Preprocess the images using InceptionV3

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %% [markdown]
# ## Caching the features extracted from InceptionV3

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in image_dataset:
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                                (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())

# %% [markdown]
# ## Preprocess and tokenize the captions

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
    capt_len = len(img_to_cap_vector[imgt])
    img_name_train.extend([imgt] * capt_len)
    cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
    capv_len = len(img_to_cap_vector[imgv])
    img_name_val.extend([imgv] * capv_len)
    cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (256113, 256113, 64031, 64031)

# %% [markdown]
# ## Create a tf.data dataset for training

# %%
# hyper parameters

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
# Load the numpy files
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Model
# `we extract the features from the lower convolutional layer of InceptionV3 giving us a vector of shape (8, 8, 2048).`

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

        # hidden shape == (batch_size, hidden_size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        # attention_hidden_layer shape == (batch_size, 64, units)
        attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                             self.W2(hidden_with_time_axis)))

        # score shape == (batch_size, 64, 1)
        # This gives you an unnormalized score for each image feature.
        score = self.V(attention_hidden_layer)

        # attention_weights shape == (batch_size, 64, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it using pickle
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

        # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

        # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/inception_train1"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # restoring the latest checkpoint in checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

              # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.9400
# Epoch 1 Batch 100 Loss 1.0251
# Epoch 1 Batch 200 Loss 0.9490
# Epoch 1 Batch 300 Loss 0.8032
# Epoch 1 Batch 400 Loss 0.8004
# Epoch 1 Batch 500 Loss 0.7203
# Epoch 1 Batch 600 Loss 0.7059
# Epoch 1 Batch 700 Loss 0.7514
# Epoch 1 Batch 800 Loss 0.7058
# Epoch 1 Batch 900 Loss 0.7565
# Epoch 1 Batch 1000 Loss 0.7120
# Epoch 1 Batch 1100 Loss 0.7006
# Epoch 1 Batch 1200 Loss 0.6543
# Epoch 1 Batch 1300 Loss 0.6463
# Epoch 1 Batch 1400 Loss 0.5956
# Epoch 1 Batch 1500 Loss 0.6808
# Epoch 1 Batch 1600 Loss 0.6799
# Epoch 1 Batch 1700 Loss 0.6451
# Epoch 1 Batch 1800 Loss 0.6303
# Epoch 1 Batch 1900 Loss 0.6344
# Epoch 1 Batch 2000 Loss 0.6935
# Epoch 1 Batch 2100 Loss 0.6248
# Epoch 1 Batch 2200 Loss 0.5944
# Epoch 1 Batch 2300 Loss 0.7175
# Epoch 1 Batch 2400 Loss 0.6430
# Epoch 1 Batch 2500 Loss 0.6174
# Epoch 1 Batch 2600 Loss 0.6257
# Epoch 1 Batch 2700 Loss 0.6001
# Epoch 1 Batch 2800 Loss 0.6283
# Epoch 1 Batch 2900 Loss 0.5928
# Epoch 1 Batch 3000 Loss 0.6600
# Epoch 1 Batch 3100 Loss 0.6212
# Epoch 1 Batch 3200 Loss 0.6138
# Epoch 1 Batch 3300 Loss 0.6961
# Epoch 1 Batch 3400 Loss 0.6467
# Epoch 1 Batch 3500 Loss 0.6106
# Epoch 1 Batch 3600 Loss 0.6622
# Epoch 1 Batch 3700 Loss 0.6453
# Epoch 1 Batch 3800 Loss 0.6686
# Epoch 1 Batch 3900 Loss 0.5811
# Epoch 1 Batch 4000 Loss 0.6128
# Epoch 1 Loss 0.690362
# Time taken for 1 epoch 2737.9214611053467 sec
#
# Epoch 2 Batch 0 Loss 0.6450
# Epoch 2 Batch 100 Loss 0.5844
# Epoch 2 Batch 200 Loss 0.5912
# Epoch 2 Batch 300 Loss 0.6201
# Epoch 2 Batch 400 Loss 0.6473
# Epoch 2 Batch 500 Loss 0.6263
# Epoch 2 Batch 600 Loss 0.5821
# Epoch 2 Batch 700 Loss 0.6365
# Epoch 2 Batch 800 Loss 0.5986
# Epoch 2 Batch 900 Loss 0.6034
# Epoch 2 Batch 1000 Loss 0.6602
# Epoch 2 Batch 1100 Loss 0.6337
# Epoch 2 Batch 1200 Loss 0.5786
# Epoch 2 Batch 1300 Loss 0.6346
# Epoch 2 Batch 1400 Loss 0.6320
# Epoch 2 Batch 1500 Loss 0.6097
# Epoch 2 Batch 1600 Loss 0.6606
# Epoch 2 Batch 1700 Loss 0.5763
# Epoch 2 Batch 1800 Loss 0.5661
# Epoch 2 Batch 1900 Loss 0.5777
# Epoch 2 Batch 2000 Loss 0.6266
# Epoch 2 Batch 2100 Loss 0.5722
# Epoch 2 Batch 2200 Loss 0.6304
# Epoch 2 Batch 2300 Loss 0.6172
# Epoch 2 Batch 2400 Loss 0.6246
# Epoch 2 Batch 2500 Loss 0.5724
# Epoch 2 Batch 2600 Loss 0.6112
# Epoch 2 Batch 2700 Loss 0.5577
# Epoch 2 Batch 2800 Loss 0.5693
# Epoch 2 Batch 2900 Loss 0.6625
# Epoch 2 Batch 3000 Loss 0.6173
# Epoch 2 Batch 3100 Loss 0.6010
# Epoch 2 Batch 3200 Loss 0.5446
# Epoch 2 Batch 3300 Loss 0.6216
# Epoch 2 Batch 3400 Loss 0.5916
# Epoch 2 Batch 3500 Loss 0.6488
# Epoch 2 Batch 3600 Loss 0.6009
# Epoch 2 Batch 3700 Loss 0.5727
# Epoch 2 Batch 3800 Loss 0.6117
# Epoch 2 Batch 3900 Loss 0.6088
# Epoch 2 Batch 4000 Loss 0.6210
# Epoch 2 Loss 0.599035
# Time taken for 1 epoch 3490.910071849823 sec
#
# Epoch 3 Batch 0 Loss 0.6085
# Epoch 3 Batch 100 Loss 0.5993
# Epoch 3 Batch 200 Loss 0.5688
# Epoch 3 Batch 300 Loss 0.5927
# Epoch 3 Batch 400 Loss 0.5797
# Epoch 3 Batch 500 Loss 0.6031
# Epoch 3 Batch 600 Loss 0.5875
# Epoch 3 Batch 700 Loss 0.5775
# Epoch 3 Batch 800 Loss 0.5816
# Epoch 3 Batch 900 Loss 0.5783
# Epoch 3 Batch 1000 Loss 0.5498
# Epoch 3 Batch 1100 Loss 0.5457
# Epoch 3 Batch 1200 Loss 0.6803
# Epoch 3 Batch 1300 Loss 0.5534
# Epoch 3 Batch 1400 Loss 0.6212
# Epoch 3 Batch 1500 Loss 0.6123
# Epoch 3 Batch 1600 Loss 0.5647
# Epoch 3 Batch 1700 Loss 0.5761
# Epoch 3 Batch 1800 Loss 0.5892
# Epoch 3 Batch 1900 Loss 0.5234
# Epoch 3 Batch 2000 Loss 0.5169
# Epoch 3 Batch 2100 Loss 0.5722
# Epoch 3 Batch 2200 Loss 0.5974
# Epoch 3 Batch 2300 Loss 0.5977
# Epoch 3 Batch 2400 Loss 0.5029
# Epoch 3 Batch 2500 Loss 0.5938
# Epoch 3 Batch 2600 Loss 0.5146
# Epoch 3 Batch 2700 Loss 0.5620
# Epoch 3 Batch 2800 Loss 0.5627
# Epoch 3 Batch 2900 Loss 0.5724
# Epoch 3 Batch 3000 Loss 0.5946
# Epoch 3 Batch 3100 Loss 0.5578
# Epoch 3 Batch 3200 Loss 0.5203
# Epoch 3 Batch 3300 Loss 0.5851
# Epoch 3 Batch 3400 Loss 0.5916
# Epoch 3 Batch 3500 Loss 0.5844
# Epoch 3 Batch 3600 Loss 0.5125
# Epoch 3 Batch 3700 Loss 0.5724
# Epoch 3 Batch 3800 Loss 0.6091
# Epoch 3 Batch 3900 Loss 0.5401
# Epoch 3 Batch 4000 Loss 0.5743
# Epoch 3 Loss 0.571328
# Time taken for 1 epoch 2004.5608999729156 sec
#
# Epoch 4 Batch 0 Loss 0.5721
# Epoch 4 Batch 100 Loss 0.5739
# Epoch 4 Batch 200 Loss 0.5188
# Epoch 4 Batch 300 Loss 0.5434
# Epoch 4 Batch 400 Loss 0.5678
# Epoch 4 Batch 500 Loss 0.5238
# Epoch 4 Batch 600 Loss 0.5381
# Epoch 4 Batch 700 Loss 0.5685
# Epoch 4 Batch 800 Loss 0.5642
# Epoch 4 Batch 900 Loss 0.5275
# Epoch 4 Batch 1000 Loss 0.5420
# Epoch 4 Batch 1100 Loss 0.5765
# Epoch 4 Batch 1200 Loss 0.5933
# Epoch 4 Batch 1300 Loss 0.5417
# Epoch 4 Batch 1400 Loss 0.5265
# Epoch 4 Batch 1500 Loss 0.5441
# Epoch 4 Batch 1600 Loss 0.6584
# Epoch 4 Batch 1700 Loss 0.5656
# Epoch 4 Batch 1800 Loss 0.5268
# Epoch 4 Batch 1900 Loss 0.5180
# Epoch 4 Batch 2000 Loss 0.5341
# Epoch 4 Batch 2100 Loss 0.5893
# Epoch 4 Batch 2200 Loss 0.5547
# Epoch 4 Batch 2300 Loss 0.6085
# Epoch 4 Batch 2400 Loss 0.6048
# Epoch 4 Batch 2500 Loss 0.5327
# Epoch 4 Batch 2600 Loss 0.5539
# Epoch 4 Batch 2700 Loss 0.5700
# Epoch 4 Batch 2800 Loss 0.5773
# Epoch 4 Batch 2900 Loss 0.5452
# Epoch 4 Batch 3000 Loss 0.5588
# Epoch 4 Batch 3100 Loss 0.5450
# Epoch 4 Batch 3200 Loss 0.5384
# Epoch 4 Batch 3300 Loss 0.5565
# Epoch 4 Batch 3400 Loss 0.5316
# Epoch 4 Batch 3500 Loss 0.5018
# Epoch 4 Batch 3600 Loss 0.5767
# Epoch 4 Batch 3700 Loss 0.5208
# Epoch 4 Batch 3800 Loss 0.5612
# Epoch 4 Batch 3900 Loss 0.5898
# Epoch 4 Batch 4000 Loss 0.6324
# Epoch 4 Loss 0.553177
# Time taken for 1 epoch 2616.0898864269257 sec
#
# Epoch 5 Batch 0 Loss 0.5379
# Epoch 5 Batch 100 Loss 0.5773
# Epoch 5 Batch 200 Loss 0.5094
# Epoch 5 Batch 300 Loss 0.5235
# Epoch 5 Batch 400 Loss 0.4995
# Epoch 5 Batch 500 Loss 0.5671
# Epoch 5 Batch 600 Loss 0.5686
# Epoch 5 Batch 700 Loss 0.5407
# Epoch 5 Batch 800 Loss 0.5187
# Epoch 5 Batch 900 Loss 0.5206
# Epoch 5 Batch 1000 Loss 0.5888
# Epoch 5 Batch 1100 Loss 0.5420
# Epoch 5 Batch 1200 Loss 0.5948
# Epoch 5 Batch 1300 Loss 0.4789
# Epoch 5 Batch 1400 Loss 0.5121
# Epoch 5 Batch 1500 Loss 0.5009
# Epoch 5 Batch 1600 Loss 0.4940
# Epoch 5 Batch 1700 Loss 0.4970
# Epoch 5 Batch 1800 Loss 0.5613
# Epoch 5 Batch 1900 Loss 0.5100
# Epoch 5 Batch 2000 Loss 0.4984
# Epoch 5 Batch 2100 Loss 0.5515
# Epoch 5 Batch 2200 Loss 0.5597
# Epoch 5 Batch 2300 Loss 0.5408
# Epoch 5 Batch 2400 Loss 0.5566
# Epoch 5 Batch 2500 Loss 0.5710
# Epoch 5 Batch 2600 Loss 0.5117
# Epoch 5 Batch 2700 Loss 0.5170
# Epoch 5 Batch 2800 Loss 0.5520
# Epoch 5 Batch 2900 Loss 0.5343
# Epoch 5 Batch 3000 Loss 0.5359
# Epoch 5 Batch 3100 Loss 0.4721
# Epoch 5 Batch 3200 Loss 0.5102
# Epoch 5 Batch 3300 Loss 0.4969
# Epoch 5 Batch 3400 Loss 0.5069
# Epoch 5 Batch 3500 Loss 0.5337
# Epoch 5 Batch 3600 Loss 0.5193
# Epoch 5 Batch 3700 Loss 0.5150
# Epoch 5 Batch 3800 Loss 0.5055
# Epoch 5 Batch 3900 Loss 0.5120
# Epoch 5 Batch 4000 Loss 0.5565
# Epoch 5 Loss 0.537317
# Time taken for 1 epoch 2985.4955723285675 sec
#
# Epoch 6 Batch 0 Loss 0.6299
# Epoch 6 Batch 100 Loss 0.5042
# Epoch 6 Batch 200 Loss 0.5095
# Epoch 6 Batch 300 Loss 0.4710
# Epoch 6 Batch 400 Loss 0.4511
# Epoch 6 Batch 500 Loss 0.5353
# Epoch 6 Batch 600 Loss 0.5310
# Epoch 6 Batch 700 Loss 0.5410
# Epoch 6 Batch 800 Loss 0.5078
# Epoch 6 Batch 900 Loss 0.5313
# Epoch 6 Batch 1000 Loss 0.5309
# Epoch 6 Batch 1100 Loss 0.5025
# Epoch 6 Batch 1200 Loss 0.5023
# Epoch 6 Batch 1300 Loss 0.4882
# Epoch 6 Batch 1400 Loss 0.5003
# Epoch 6 Batch 1500 Loss 0.5286
# Epoch 6 Batch 1600 Loss 0.5182
# Epoch 6 Batch 1700 Loss 0.5476
# Epoch 6 Batch 1800 Loss 0.5401
# Epoch 6 Batch 1900 Loss 0.4808
# Epoch 6 Batch 2000 Loss 0.5495
# Epoch 6 Batch 2100 Loss 0.5476
# Epoch 6 Batch 2200 Loss 0.4874
# Epoch 6 Batch 2300 Loss 0.5252
# Epoch 6 Batch 2400 Loss 0.5244
# Epoch 6 Batch 2500 Loss 0.4839
# Epoch 6 Batch 2600 Loss 0.5055
# Epoch 6 Batch 2700 Loss 0.5038
# Epoch 6 Batch 2800 Loss 0.5211
# Epoch 6 Batch 2900 Loss 0.4752
# Epoch 6 Batch 3000 Loss 0.5009
# Epoch 6 Batch 3100 Loss 0.5299
# Epoch 6 Batch 3200 Loss 0.4925
# Epoch 6 Batch 3300 Loss 0.5400
# Epoch 6 Batch 3400 Loss 0.4978
# Epoch 6 Batch 3500 Loss 0.5106
# Epoch 6 Batch 3600 Loss 0.5438
# Epoch 6 Batch 3700 Loss 0.5369
# Epoch 6 Batch 3800 Loss 0.5353
# Epoch 6 Batch 3900 Loss 0.4976
# Epoch 6 Batch 4000 Loss 0.4973
# Epoch 6 Loss 0.524377
# Time taken for 1 epoch 2727.272356748581 sec
#
# Epoch 7 Batch 0 Loss 0.5800
# Epoch 7 Batch 100 Loss 0.5064
# Epoch 7 Batch 200 Loss 0.4646
# Epoch 7 Batch 300 Loss 0.5088
# Epoch 7 Batch 400 Loss 0.5269
# Epoch 7 Batch 500 Loss 0.4883
# Epoch 7 Batch 600 Loss 0.5031
# Epoch 7 Batch 700 Loss 0.5653
# Epoch 7 Batch 800 Loss 0.4877
# Epoch 7 Batch 900 Loss 0.5056
# Epoch 7 Batch 1000 Loss 0.5453
# Epoch 7 Batch 1100 Loss 0.5117
# Epoch 7 Batch 1200 Loss 0.5024
# Epoch 7 Batch 1300 Loss 0.4928
# Epoch 7 Batch 1400 Loss 0.5181
# Epoch 7 Batch 1500 Loss 0.5095
# Epoch 7 Batch 1600 Loss 0.5158
# Epoch 7 Batch 1700 Loss 0.4922
# Epoch 7 Batch 1800 Loss 0.5027
# Epoch 7 Batch 1900 Loss 0.5537
# Epoch 7 Batch 2000 Loss 0.5280
# Epoch 7 Batch 2100 Loss 0.5597
# Epoch 7 Batch 2200 Loss 0.5077
# Epoch 7 Batch 2300 Loss 0.5244
# Epoch 7 Batch 2400 Loss 0.5318
# Epoch 7 Batch 2500 Loss 0.5303
# Epoch 7 Batch 2600 Loss 0.5160
# Epoch 7 Batch 2700 Loss 0.4395
# Epoch 7 Batch 2800 Loss 0.4825
# Epoch 7 Batch 2900 Loss 0.4789
# Epoch 7 Batch 3000 Loss 0.5264
# Epoch 7 Batch 3100 Loss 0.5242
# Epoch 7 Batch 3200 Loss 0.4677
# Epoch 7 Batch 3300 Loss 0.4647
# Epoch 7 Batch 3400 Loss 0.4932
# Epoch 7 Batch 3500 Loss 0.5317
# Epoch 7 Batch 3600 Loss 0.5281
# Epoch 7 Batch 3700 Loss 0.4603
# Epoch 7 Batch 3800 Loss 0.5427
# Epoch 7 Batch 3900 Loss 0.5173
# Epoch 7 Batch 4000 Loss 0.5029
# Epoch 7 Loss 0.513194
# Time taken for 1 epoch 3563.4055280685425 sec
#
# Epoch 8 Batch 0 Loss 0.4594
# Epoch 8 Batch 100 Loss 0.4963
# Epoch 8 Batch 200 Loss 0.5062
# Epoch 8 Batch 300 Loss 0.5056
# Epoch 8 Batch 400 Loss 0.5135
# Epoch 8 Batch 500 Loss 0.4654
# Epoch 8 Batch 600 Loss 0.5214
# Epoch 8 Batch 700 Loss 0.5367
# Epoch 8 Batch 800 Loss 0.5195
# Epoch 8 Batch 900 Loss 0.4787
# Epoch 8 Batch 1000 Loss 0.5125
# Epoch 8 Batch 1100 Loss 0.4739
# Epoch 8 Batch 1200 Loss 0.4953
# Epoch 8 Batch 1300 Loss 0.5160
# Epoch 8 Batch 1400 Loss 0.5281
# Epoch 8 Batch 1500 Loss 0.4710
# Epoch 8 Batch 1600 Loss 0.5384
# Epoch 8 Batch 1700 Loss 0.5445
# Epoch 8 Batch 1800 Loss 0.5288
# Epoch 8 Batch 1900 Loss 0.4988
# Epoch 8 Batch 2000 Loss 0.5299
# Epoch 8 Batch 2100 Loss 0.4902
# Epoch 8 Batch 2200 Loss 0.4928
# Epoch 8 Batch 2300 Loss 0.5089
# Epoch 8 Batch 2400 Loss 0.4738
# Epoch 8 Batch 2500 Loss 0.4960
# Epoch 8 Batch 2600 Loss 0.5590
# Epoch 8 Batch 2700 Loss 0.4988
# Epoch 8 Batch 2800 Loss 0.4883
# Epoch 8 Batch 2900 Loss 0.5176
# Epoch 8 Batch 3000 Loss 0.5090
# Epoch 8 Batch 3100 Loss 0.4729
# Epoch 8 Batch 3200 Loss 0.4891
# Epoch 8 Batch 3300 Loss 0.4728
# Epoch 8 Batch 3400 Loss 0.4990
# Epoch 8 Batch 3500 Loss 0.5155
# Epoch 8 Batch 3600 Loss 0.4690
# Epoch 8 Batch 3700 Loss 0.5157
# Epoch 8 Batch 3800 Loss 0.5181
# Epoch 8 Batch 3900 Loss 0.4580
# Epoch 8 Batch 4000 Loss 0.4418
# Epoch 8 Loss 0.502691
# Time taken for 1 epoch 2040.8279552459717 sec
#
# Epoch 9 Batch 0 Loss 0.4894
# Epoch 9 Batch 100 Loss 0.5100
# Epoch 9 Batch 200 Loss 0.4989
# Epoch 9 Batch 300 Loss 0.4759
# Epoch 9 Batch 400 Loss 0.4994
# Epoch 9 Batch 500 Loss 0.4919
# Epoch 9 Batch 600 Loss 0.5253
# Epoch 9 Batch 700 Loss 0.5229
# Epoch 9 Batch 800 Loss 0.4461
# Epoch 9 Batch 900 Loss 0.5201
# Epoch 9 Batch 1000 Loss 0.5487
# Epoch 9 Batch 1100 Loss 0.4857
# Epoch 9 Batch 1200 Loss 0.4953
# Epoch 9 Batch 1300 Loss 0.4617
# Epoch 9 Batch 1400 Loss 0.5648
# Epoch 9 Batch 1500 Loss 0.4668
# Epoch 9 Batch 1600 Loss 0.4789
# Epoch 9 Batch 1700 Loss 0.5188
# Epoch 9 Batch 1800 Loss 0.4367
# Epoch 9 Batch 1900 Loss 0.5543
# Epoch 9 Batch 2000 Loss 0.4554
# Epoch 9 Batch 2100 Loss 0.5601
# Epoch 9 Batch 2200 Loss 0.4685
# Epoch 9 Batch 2300 Loss 0.5371
# Epoch 9 Batch 2400 Loss 0.4717
# Epoch 9 Batch 2500 Loss 0.5056
# Epoch 9 Batch 2600 Loss 0.4755
# Epoch 9 Batch 2700 Loss 0.5459
# Epoch 9 Batch 2800 Loss 0.5055
# Epoch 9 Batch 2900 Loss 0.4971
# Epoch 9 Batch 3000 Loss 0.4294
# Epoch 9 Batch 3100 Loss 0.5162
# Epoch 9 Batch 3200 Loss 0.4849
# Epoch 9 Batch 3300 Loss 0.5051
# Epoch 9 Batch 3400 Loss 0.4671
# Epoch 9 Batch 3500 Loss 0.5001
# Epoch 9 Batch 3600 Loss 0.5816
# Epoch 9 Batch 3700 Loss 0.4451
# Epoch 9 Batch 3800 Loss 0.5062
# Epoch 9 Batch 3900 Loss 0.4703
# Epoch 9 Batch 4000 Loss 0.4767
# Epoch 9 Loss 0.493284
# Time taken for 1 epoch 3633.256344795227 sec
#
# Epoch 10 Batch 0 Loss 0.4641
# Epoch 10 Batch 100 Loss 0.5105
# Epoch 10 Batch 200 Loss 0.4856
# Epoch 10 Batch 300 Loss 0.4757
# Epoch 10 Batch 400 Loss 0.4437
# Epoch 10 Batch 500 Loss 0.4684
# Epoch 10 Batch 600 Loss 0.4706
# Epoch 10 Batch 700 Loss 0.5028
# Epoch 10 Batch 800 Loss 0.4405
# Epoch 10 Batch 900 Loss 0.4627
# Epoch 10 Batch 1000 Loss 0.5512
# Epoch 10 Batch 1100 Loss 0.4523
# Epoch 10 Batch 1200 Loss 0.5095
# Epoch 10 Batch 1300 Loss 0.4449
# Epoch 10 Batch 1400 Loss 0.5271
# Epoch 10 Batch 1500 Loss 0.5363
# Epoch 10 Batch 1600 Loss 0.5338
# Epoch 10 Batch 1700 Loss 0.4614
# Epoch 10 Batch 1800 Loss 0.4704
# Epoch 10 Batch 1900 Loss 0.4708
# Epoch 10 Batch 2000 Loss 0.4916
# Epoch 10 Batch 2100 Loss 0.4617
# Epoch 10 Batch 2200 Loss 0.5296
# Epoch 10 Batch 2300 Loss 0.4701
# Epoch 10 Batch 2400 Loss 0.4371
# Epoch 10 Batch 2500 Loss 0.5138
# Epoch 10 Batch 2600 Loss 0.4652
# Epoch 10 Batch 2700 Loss 0.4436
# Epoch 10 Batch 2800 Loss 0.5056
# Epoch 10 Batch 2900 Loss 0.4854
# Epoch 10 Batch 3000 Loss 0.5421
# Epoch 10 Batch 3100 Loss 0.5175
# Epoch 10 Batch 3200 Loss 0.4532
# Epoch 10 Batch 3300 Loss 0.5532
# Epoch 10 Batch 3400 Loss 0.4584
# Epoch 10 Batch 3500 Loss 0.4449
# Epoch 10 Batch 3600 Loss 0.4661
# Epoch 10 Batch 3700 Loss 0.4240
# Epoch 10 Batch 3800 Loss 0.4929
# Epoch 10 Batch 3900 Loss 0.5016
# Epoch 10 Batch 4000 Loss 0.5056
# Epoch 10 Loss 0.484577
# Time taken for 1 epoch 2291.841486930847 sec
#
# Epoch 11 Batch 0 Loss 0.4807
# Epoch 11 Batch 100 Loss 0.4402
# Epoch 11 Batch 200 Loss 0.4411
# Epoch 11 Batch 300 Loss 0.4918
# Epoch 11 Batch 400 Loss 0.5056
# Epoch 11 Batch 500 Loss 0.4730
# Epoch 11 Batch 600 Loss 0.4821
# Epoch 11 Batch 700 Loss 0.4557
# Epoch 11 Batch 800 Loss 0.4844
# Epoch 11 Batch 900 Loss 0.5092
# Epoch 11 Batch 1000 Loss 0.4563
# Epoch 11 Batch 1100 Loss 0.4754
# Epoch 11 Batch 1200 Loss 0.4884
# Epoch 11 Batch 1300 Loss 0.4607
# Epoch 11 Batch 1400 Loss 0.4988
# Epoch 11 Batch 1500 Loss 0.4911
# Epoch 11 Batch 1600 Loss 0.4623
# Epoch 11 Batch 1700 Loss 0.4778
# Epoch 11 Batch 1800 Loss 0.4609
# Epoch 11 Batch 1900 Loss 0.4473
# Epoch 11 Batch 2000 Loss 0.4583
# Epoch 11 Batch 2100 Loss 0.4734
# Epoch 11 Batch 2200 Loss 0.4833
# Epoch 11 Batch 2300 Loss 0.4790
# Epoch 11 Batch 2400 Loss 0.5032
# Epoch 11 Batch 2500 Loss 0.4648
# Epoch 11 Batch 2600 Loss 0.4875
# Epoch 11 Batch 2700 Loss 0.4549
# Epoch 11 Batch 2800 Loss 0.4565
# Epoch 11 Batch 2900 Loss 0.4636
# Epoch 11 Batch 3000 Loss 0.4836
# Epoch 11 Batch 3100 Loss 0.5296
# Epoch 11 Batch 3200 Loss 0.4407
# Epoch 11 Batch 3300 Loss 0.4189
# Epoch 11 Batch 3400 Loss 0.4351
# Epoch 11 Batch 3500 Loss 0.4939
# Epoch 11 Batch 3600 Loss 0.4933
# Epoch 11 Batch 3700 Loss 0.4693
# Epoch 11 Batch 3800 Loss 0.4819
# Epoch 11 Batch 3900 Loss 0.4484
# Epoch 11 Batch 4000 Loss 0.4585
# Epoch 11 Loss 0.476438
# Time taken for 1 epoch 2402.549864768982 sec
#
# Epoch 12 Batch 0 Loss 0.4871
# Epoch 12 Batch 100 Loss 0.4547
# Epoch 12 Batch 200 Loss 0.4311
# Epoch 12 Batch 300 Loss 0.5059
# Epoch 12 Batch 400 Loss 0.4807
# Epoch 12 Batch 500 Loss 0.4686
# Epoch 12 Batch 600 Loss 0.4584
# Epoch 12 Batch 700 Loss 0.4761
# Epoch 12 Batch 800 Loss 0.4423
# Epoch 12 Batch 900 Loss 0.4380
# Epoch 12 Batch 1000 Loss 0.4689
# Epoch 12 Batch 1100 Loss 0.5073
# Epoch 12 Batch 1200 Loss 0.4651
# Epoch 12 Batch 1300 Loss 0.4841
# Epoch 12 Batch 1400 Loss 0.4598
# Epoch 12 Batch 1500 Loss 0.4368
# Epoch 12 Batch 1600 Loss 0.4721
# Epoch 12 Batch 1700 Loss 0.4307
# Epoch 12 Batch 1800 Loss 0.5083
# Epoch 12 Batch 1900 Loss 0.4803
# Epoch 12 Batch 2000 Loss 0.4398
# Epoch 12 Batch 2100 Loss 0.5134
# Epoch 12 Batch 2200 Loss 0.4519
# Epoch 12 Batch 2300 Loss 0.4532
# Epoch 12 Batch 2400 Loss 0.4235
# Epoch 12 Batch 2500 Loss 0.4550
# Epoch 12 Batch 2600 Loss 0.4370
# Epoch 12 Batch 2700 Loss 0.4726
# Epoch 12 Batch 2800 Loss 0.5111
# Epoch 12 Batch 2900 Loss 0.5350
# Epoch 12 Batch 3000 Loss 0.4268
# Epoch 12 Batch 3100 Loss 0.4649
# Epoch 12 Batch 3200 Loss 0.5098
# Epoch 12 Batch 3300 Loss 0.4668
# Epoch 12 Batch 3400 Loss 0.4907
# Epoch 12 Batch 3500 Loss 0.4877
# Epoch 12 Batch 3600 Loss 0.4622
# Epoch 12 Batch 3700 Loss 0.4635
# Epoch 12 Batch 3800 Loss 0.4492
# Epoch 12 Batch 3900 Loss 0.4772
# Epoch 12 Batch 4000 Loss 0.4912
# Epoch 12 Loss 0.469564
# Time taken for 1 epoch 3151.9794409275055 sec
#
# Epoch 13 Batch 0 Loss 0.4486
# Epoch 13 Batch 100 Loss 0.4595
# Epoch 13 Batch 200 Loss 0.4562
# Epoch 13 Batch 300 Loss 0.4821
# Epoch 13 Batch 400 Loss 0.4874
# Epoch 13 Batch 500 Loss 0.5042
# Epoch 13 Batch 600 Loss 0.4578
# Epoch 13 Batch 700 Loss 0.4831
# Epoch 13 Batch 800 Loss 0.4814
# Epoch 13 Batch 900 Loss 0.4808
# Epoch 13 Batch 1000 Loss 0.4975
# Epoch 13 Batch 1100 Loss 0.4739
# Epoch 13 Batch 1200 Loss 0.4894
# Epoch 13 Batch 1300 Loss 0.4510
# Epoch 13 Batch 1400 Loss 0.5026
# Epoch 13 Batch 1500 Loss 0.4749
# Epoch 13 Batch 1600 Loss 0.4431
# Epoch 13 Batch 1700 Loss 0.4658
# Epoch 13 Batch 1800 Loss 0.4178
# Epoch 13 Batch 1900 Loss 0.4064
# Epoch 13 Batch 2000 Loss 0.4802
# Epoch 13 Batch 2100 Loss 0.4596
# Epoch 13 Batch 2200 Loss 0.4968
# Epoch 13 Batch 2300 Loss 0.4553
# Epoch 13 Batch 2400 Loss 0.4694
# Epoch 13 Batch 2500 Loss 0.5000
# Epoch 13 Batch 2600 Loss 0.4592
# Epoch 13 Batch 2700 Loss 0.4809
# Epoch 13 Batch 2800 Loss 0.4847
# Epoch 13 Batch 2900 Loss 0.4543
# Epoch 13 Batch 3000 Loss 0.4935
# Epoch 13 Batch 3100 Loss 0.4583
# Epoch 13 Batch 3200 Loss 0.4940
# Epoch 13 Batch 3300 Loss 0.4857
# Epoch 13 Batch 3400 Loss 0.4432
# Epoch 13 Batch 3500 Loss 0.4736
# Epoch 13 Batch 3600 Loss 0.4132
# Epoch 13 Batch 3700 Loss 0.4678
# Epoch 13 Batch 3800 Loss 0.4819
# Epoch 13 Batch 3900 Loss 0.5063
# Epoch 13 Batch 4000 Loss 0.4636
# Epoch 13 Loss 0.462538
# Time taken for 1 epoch 2451.9287445545197 sec
#
# Epoch 14 Batch 0 Loss 0.4775
# Epoch 14 Batch 100 Loss 0.4560
# Epoch 14 Batch 200 Loss 0.4460
# Epoch 14 Batch 300 Loss 0.4671
# Epoch 14 Batch 400 Loss 0.4702
# Epoch 14 Batch 500 Loss 0.4698
# Epoch 14 Batch 600 Loss 0.4688
# Epoch 14 Batch 700 Loss 0.4668
# Epoch 14 Batch 800 Loss 0.4936
# Epoch 14 Batch 900 Loss 0.4450
# Epoch 14 Batch 1000 Loss 0.4450
# Epoch 14 Batch 1100 Loss 0.4157
# Epoch 14 Batch 1200 Loss 0.5036
# Epoch 14 Batch 1300 Loss 0.4688
# Epoch 14 Batch 1400 Loss 0.4772
# Epoch 14 Batch 1500 Loss 0.4307
# Epoch 14 Batch 1600 Loss 0.4670
# Epoch 14 Batch 1700 Loss 0.4533
# Epoch 14 Batch 1800 Loss 0.4515
# Epoch 14 Batch 1900 Loss 0.5074
# Epoch 14 Batch 2000 Loss 0.4834
# Epoch 14 Batch 2100 Loss 0.4572
# Epoch 14 Batch 2200 Loss 0.4836
# Epoch 14 Batch 2300 Loss 0.4851
# Epoch 14 Batch 2400 Loss 0.4590
# Epoch 14 Batch 2500 Loss 0.4117
# Epoch 14 Batch 2600 Loss 0.4409
# Epoch 14 Batch 2700 Loss 0.4694
# Epoch 14 Batch 2800 Loss 0.4587
# Epoch 14 Batch 2900 Loss 0.4256
# Epoch 14 Batch 3000 Loss 0.4779
# Epoch 14 Batch 3100 Loss 0.4362
# Epoch 14 Batch 3200 Loss 0.4314
# Epoch 14 Batch 3300 Loss 0.4684
# Epoch 14 Batch 3400 Loss 0.4320
# Epoch 14 Batch 3500 Loss 0.4313
# Epoch 14 Batch 3600 Loss 0.4352
# Epoch 14 Batch 3700 Loss 0.4321
# Epoch 14 Batch 3800 Loss 0.4670
# Epoch 14 Batch 3900 Loss 0.4219
# Epoch 14 Batch 4000 Loss 0.4807
# Epoch 14 Loss 0.456115
# Time taken for 1 epoch 2320.5109164714813 sec
#
# Epoch 15 Batch 0 Loss 0.4192
# Epoch 15 Batch 100 Loss 0.4543
# Epoch 15 Batch 200 Loss 0.4437
# Epoch 15 Batch 300 Loss 0.4564
# Epoch 15 Batch 400 Loss 0.4409
# Epoch 15 Batch 500 Loss 0.4537
# Epoch 15 Batch 600 Loss 0.4674
# Epoch 15 Batch 700 Loss 0.4800
# Epoch 15 Batch 800 Loss 0.4691
# Epoch 15 Batch 900 Loss 0.4150
# Epoch 15 Batch 1000 Loss 0.5118
# Epoch 15 Batch 1100 Loss 0.4384
# Epoch 15 Batch 1200 Loss 0.4801
# Epoch 15 Batch 1300 Loss 0.4335
# Epoch 15 Batch 1400 Loss 0.4348
# Epoch 15 Batch 1500 Loss 0.4709
# Epoch 15 Batch 1600 Loss 0.4402
# Epoch 15 Batch 1700 Loss 0.4565
# Epoch 15 Batch 1800 Loss 0.4527
# Epoch 15 Batch 1900 Loss 0.4128
# Epoch 15 Batch 2000 Loss 0.4502
# Epoch 15 Batch 2100 Loss 0.4469
# Epoch 15 Batch 2200 Loss 0.4558
# Epoch 15 Batch 2300 Loss 0.4563
# Epoch 15 Batch 2400 Loss 0.4118
# Epoch 15 Batch 2500 Loss 0.4235
# Epoch 15 Batch 2600 Loss 0.4184
# Epoch 15 Batch 2700 Loss 0.4011
# Epoch 15 Batch 2800 Loss 0.4682
# Epoch 15 Batch 2900 Loss 0.4099
# Epoch 15 Batch 3000 Loss 0.4372
# Epoch 15 Batch 3100 Loss 0.4584
# Epoch 15 Batch 3200 Loss 0.4488
# Epoch 15 Batch 3300 Loss 0.4173
# Epoch 15 Batch 3400 Loss 0.4384
# Epoch 15 Batch 3500 Loss 0.4818
# Epoch 15 Batch 3600 Loss 0.4189
# Epoch 15 Batch 3700 Loss 0.4089
# Epoch 15 Batch 3800 Loss 0.4427
# Epoch 15 Batch 3900 Loss 0.4619
# Epoch 15 Batch 4000 Loss 0.4445
# Epoch 15 Loss 0.450258
# Time taken for 1 epoch 3355.4006974697113 sec
#
# Epoch 16 Batch 0 Loss 0.4380
# Epoch 16 Batch 100 Loss 0.4215
# Epoch 16 Batch 200 Loss 0.4846
# Epoch 16 Batch 300 Loss 0.3996
# Epoch 16 Batch 400 Loss 0.4208
# Epoch 16 Batch 500 Loss 0.4821
# Epoch 16 Batch 600 Loss 0.4412
# Epoch 16 Batch 700 Loss 0.5122
# Epoch 16 Batch 800 Loss 0.4180
# Epoch 16 Batch 900 Loss 0.4553
# Epoch 16 Batch 1000 Loss 0.4520
# Epoch 16 Batch 1100 Loss 0.4472
# Epoch 16 Batch 1200 Loss 0.4573
# Epoch 16 Batch 1300 Loss 0.4718
# Epoch 16 Batch 1400 Loss 0.3954
# Epoch 16 Batch 1500 Loss 0.4122
# Epoch 16 Batch 1600 Loss 0.4730
# Epoch 16 Batch 1700 Loss 0.4619
# Epoch 16 Batch 1800 Loss 0.4639
# Epoch 16 Batch 1900 Loss 0.4514
# Epoch 16 Batch 2000 Loss 0.4310
# Epoch 16 Batch 2100 Loss 0.4433
# Epoch 16 Batch 2200 Loss 0.4869
# Epoch 16 Batch 2300 Loss 0.4469
# Epoch 16 Batch 2400 Loss 0.4504
# Epoch 16 Batch 2500 Loss 0.4451
# Epoch 16 Batch 2600 Loss 0.4516
# Epoch 16 Batch 2700 Loss 0.4974
# Epoch 16 Batch 2800 Loss 0.4340
# Epoch 16 Batch 2900 Loss 0.4327
# Epoch 16 Batch 3000 Loss 0.4565
# Epoch 16 Batch 3100 Loss 0.5098
# Epoch 16 Batch 3200 Loss 0.4347
# Epoch 16 Batch 3300 Loss 0.4244
# Epoch 16 Batch 3400 Loss 0.4066
# Epoch 16 Batch 3500 Loss 0.4097
# Epoch 16 Batch 3600 Loss 0.4545
# Epoch 16 Batch 3700 Loss 0.4219
# Epoch 16 Batch 3800 Loss 0.4768
# Epoch 16 Batch 3900 Loss 0.4523
# Epoch 16 Batch 4000 Loss 0.4583
# Epoch 16 Loss 0.445358
# Time taken for 1 epoch 2356.6902511119843 sec
#
# Epoch 17 Batch 0 Loss 0.4530
# Epoch 17 Batch 100 Loss 0.4103
# Epoch 17 Batch 200 Loss 0.4288
# Epoch 17 Batch 300 Loss 0.4502
# Epoch 17 Batch 400 Loss 0.4158
# Epoch 17 Batch 500 Loss 0.4445
# Epoch 17 Batch 600 Loss 0.4465
# Epoch 17 Batch 700 Loss 0.4553
# Epoch 17 Batch 800 Loss 0.3854
# Epoch 17 Batch 900 Loss 0.4185
# Epoch 17 Batch 1000 Loss 0.4453
# Epoch 17 Batch 1100 Loss 0.4614
# Epoch 17 Batch 1200 Loss 0.4204
# Epoch 17 Batch 1300 Loss 0.4296
# Epoch 17 Batch 1400 Loss 0.4241
# Epoch 17 Batch 1500 Loss 0.4074
# Epoch 17 Batch 1600 Loss 0.4647
# Epoch 17 Batch 1700 Loss 0.4271
# Epoch 17 Batch 1800 Loss 0.4088
# Epoch 17 Batch 1900 Loss 0.4668
# Epoch 17 Batch 2000 Loss 0.4801
# Epoch 17 Batch 2100 Loss 0.4753
# Epoch 17 Batch 2200 Loss 0.4128
# Epoch 17 Batch 2300 Loss 0.4201
# Epoch 17 Batch 2400 Loss 0.4319
# Epoch 17 Batch 2500 Loss 0.4008
# Epoch 17 Batch 2600 Loss 0.4535
# Epoch 17 Batch 2700 Loss 0.4096
# Epoch 17 Batch 2800 Loss 0.4573
# Epoch 17 Batch 2900 Loss 0.4104
# Epoch 17 Batch 3000 Loss 0.4496
# Epoch 17 Batch 3100 Loss 0.4224
# Epoch 17 Batch 3200 Loss 0.4423
# Epoch 17 Batch 3300 Loss 0.4311
# Epoch 17 Batch 3400 Loss 0.4295
# Epoch 17 Batch 3500 Loss 0.4453
# Epoch 17 Batch 3600 Loss 0.4237
# Epoch 17 Batch 3700 Loss 0.4329
# Epoch 17 Batch 3800 Loss 0.4200
# Epoch 17 Batch 3900 Loss 0.4294
# Epoch 17 Batch 4000 Loss 0.4203
# Epoch 17 Loss 0.440767
# Time taken for 1 epoch 2452.5030031204224 sec
#
# Epoch 18 Batch 0 Loss 0.4301
# Epoch 18 Batch 100 Loss 0.4190
# Epoch 18 Batch 200 Loss 0.4257
# Epoch 18 Batch 300 Loss 0.4521
# Epoch 18 Batch 400 Loss 0.4655
# Epoch 18 Batch 500 Loss 0.4185
# Epoch 18 Batch 600 Loss 0.3849
# Epoch 18 Batch 700 Loss 0.4813
# Epoch 18 Batch 800 Loss 0.4469
# Epoch 18 Batch 900 Loss 0.4662
# Epoch 18 Batch 1000 Loss 0.4485
# Epoch 18 Batch 1100 Loss 0.4473
# Epoch 18 Batch 1200 Loss 0.4560
# Epoch 18 Batch 1300 Loss 0.4530
# Epoch 18 Batch 1400 Loss 0.4816
# Epoch 18 Batch 1500 Loss 0.4817
# Epoch 18 Batch 1600 Loss 0.4427
# Epoch 18 Batch 1700 Loss 0.4257
# Epoch 18 Batch 1800 Loss 0.4646
# Epoch 18 Batch 1900 Loss 0.4438
# Epoch 18 Batch 2000 Loss 0.4213
# Epoch 18 Batch 2100 Loss 0.4331
# Epoch 18 Batch 2200 Loss 0.4678
# Epoch 18 Batch 2300 Loss 0.4186
# Epoch 18 Batch 2400 Loss 0.4052
# Epoch 18 Batch 2500 Loss 0.4149
# Epoch 18 Batch 2600 Loss 0.4491
# Epoch 18 Batch 2700 Loss 0.4424
# Epoch 18 Batch 2800 Loss 0.4080
# Epoch 18 Batch 2900 Loss 0.4255
# Epoch 18 Batch 3000 Loss 0.4365
# Epoch 18 Batch 3100 Loss 0.4162
# Epoch 18 Batch 3200 Loss 0.4347
# Epoch 18 Batch 3300 Loss 0.4600
# Epoch 18 Batch 3400 Loss 0.4378
# Epoch 18 Batch 3500 Loss 0.4254
# Epoch 18 Batch 3600 Loss 0.4616
# Epoch 18 Batch 3700 Loss 0.4494
# Epoch 18 Batch 3800 Loss 0.4381
# Epoch 18 Batch 3900 Loss 0.4191
# Epoch 18 Batch 4000 Loss 0.4331
# Epoch 18 Loss 0.436045
# Time taken for 1 epoch 3012.806106567383 sec
#
# Epoch 19 Batch 0 Loss 0.4496
# Epoch 19 Batch 100 Loss 0.3748
# Epoch 19 Batch 200 Loss 0.4399
# Epoch 19 Batch 300 Loss 0.4372
# Epoch 19 Batch 400 Loss 0.4764
# Epoch 19 Batch 500 Loss 0.4242
# Epoch 19 Batch 600 Loss 0.4350
# Epoch 19 Batch 700 Loss 0.4289
# Epoch 19 Batch 800 Loss 0.4542
# Epoch 19 Batch 900 Loss 0.4193
# Epoch 19 Batch 1000 Loss 0.5032
# Epoch 19 Batch 1100 Loss 0.4371
# Epoch 19 Batch 1200 Loss 0.4567
# Epoch 19 Batch 1300 Loss 0.4258
# Epoch 19 Batch 1400 Loss 0.4105
# Epoch 19 Batch 1500 Loss 0.4197
# Epoch 19 Batch 1600 Loss 0.4554
# Epoch 19 Batch 1700 Loss 0.5067
# Epoch 19 Batch 1800 Loss 0.4613
# Epoch 19 Batch 1900 Loss 0.4455
# Epoch 19 Batch 2000 Loss 0.4435
# Epoch 19 Batch 2100 Loss 0.4328
# Epoch 19 Batch 2200 Loss 0.4179
# Epoch 19 Batch 2300 Loss 0.4282
# Epoch 19 Batch 2400 Loss 0.3846
# Epoch 19 Batch 2500 Loss 0.4693
# Epoch 19 Batch 2600 Loss 0.3983
# Epoch 19 Batch 2700 Loss 0.4110
# Epoch 19 Batch 2800 Loss 0.4127
# Epoch 19 Batch 2900 Loss 0.4256
# Epoch 19 Batch 3000 Loss 0.4187
# Epoch 19 Batch 3100 Loss 0.4179
# Epoch 19 Batch 3200 Loss 0.4670
# Epoch 19 Batch 3300 Loss 0.4420
# Epoch 19 Batch 3400 Loss 0.4248
# Epoch 19 Batch 3500 Loss 0.4027
# Epoch 19 Batch 3600 Loss 0.4341
# Epoch 19 Batch 3700 Loss 0.4512
# Epoch 19 Batch 3800 Loss 0.4134
# Epoch 19 Batch 3900 Loss 0.4143
# Epoch 19 Batch 4000 Loss 0.4125
# Epoch 19 Loss 0.431651
# Time taken for 1 epoch 2512.7877864837646 sec
#
# Epoch 20 Batch 0 Loss 0.4343
# Epoch 20 Batch 100 Loss 0.4141
# Epoch 20 Batch 200 Loss 0.4242
# Epoch 20 Batch 300 Loss 0.4334
# Epoch 20 Batch 400 Loss 0.4246
# Epoch 20 Batch 500 Loss 0.4122
# Epoch 20 Batch 600 Loss 0.4210
# Epoch 20 Batch 700 Loss 0.3940
# Epoch 20 Batch 800 Loss 0.4536
# Epoch 20 Batch 900 Loss 0.4643
# Epoch 20 Batch 1000 Loss 0.4555
# Epoch 20 Batch 1100 Loss 0.4402
# Epoch 20 Batch 1200 Loss 0.5051
# Epoch 20 Batch 1300 Loss 0.4364
# Epoch 20 Batch 1400 Loss 0.4388
# Epoch 20 Batch 1500 Loss 0.4009
# Epoch 20 Batch 1600 Loss 0.4346
# Epoch 20 Batch 1700 Loss 0.4323
# Epoch 20 Batch 1800 Loss 0.4369
# Epoch 20 Batch 1900 Loss 0.4263
# Epoch 20 Batch 2000 Loss 0.4242
# Epoch 20 Batch 2100 Loss 0.4144
# Epoch 20 Batch 2200 Loss 0.4311
# Epoch 20 Batch 2300 Loss 0.4644
# Epoch 20 Batch 2400 Loss 0.4095
# Epoch 20 Batch 2500 Loss 0.4436
# Epoch 20 Batch 2600 Loss 0.4236
# Epoch 20 Batch 2700 Loss 0.4661
# Epoch 20 Batch 2800 Loss 0.4097
# Epoch 20 Batch 2900 Loss 0.4491
# Epoch 20 Batch 3000 Loss 0.4247
# Epoch 20 Batch 3100 Loss 0.4267
# Epoch 20 Batch 3200 Loss 0.4420
# Epoch 20 Batch 3300 Loss 0.4150
# Epoch 20 Batch 3400 Loss 0.4271
# Epoch 20 Batch 3500 Loss 0.4050
# Epoch 20 Batch 3600 Loss 0.4582
# Epoch 20 Batch 3700 Loss 0.3979
# Epoch 20 Batch 3800 Loss 0.4433
# Epoch 20 Batch 3900 Loss 0.4161
# Epoch 20 Batch 4000 Loss 0.4109
# Epoch 20 Loss 0.428133
# Time taken for 1 epoch 2399.701751947403 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (8, 8))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print ('Real Caption:', real_caption)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a baseball pitcher winding up to deliver a <unk> <end>
# Prediction Caption: a professional baseball uniform after an almost empty preparing for ball <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a surfer in black shirt on large surfboard walks behind him <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x1E5FC27CF40>
